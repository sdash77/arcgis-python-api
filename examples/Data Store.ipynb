# %%
gis = GIS("https://dev06999.esri.com/portal", "admin", "changeit")

# %%
gis.datastore.config = { "blockDataCopy" : False }

# %%
gis.datastore.config
# Out:
# {'blockDataCopy': False}

# %%
items = gis.datastore.search()
# Out:
# https://dev06999.esri.com/portal/portaladmin/federation/servers?f=json

# %%
items
# Out:
# [<DatastoreItem title:"/bigDataFileShares/bigdata" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/flooddata" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/flooddata3" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae2" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae3" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae6" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae666" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae7" type:"bigDataFileShare">,
#  <DatastoreItem title:"/enterpriseDatabases/AGSDataStore_ds_b2be1k4c" type:"egdb">,
#  <DatastoreItem title:"/fileShares/cdrive" type:"folder">,
#  <DatastoreItem title:"/fileShares/folder_shared" type:"folder">,
#  <DatastoreItem title:"/fileShares/_rasterStore" type:"folder">,
# ...

# %%
print(items[1])
# Out:
#    datapath='/bigDataFileShares/flooddata'
#    id='314c7252-ffab-47b9-918b-d6a918f4a7df'
#    _datastore=<arcgis.gis.DatastoreManager object at 0x0000000007ABB978>
#    info={'path': '\\\\dev06999\\bigdata\\Chennai\\flooddata'}
#    _admin_url='https://Dev06999.esri.com:6443/arcgis/admin'
#    path='/bigDataFileShares/flooddata'
#    _portal=<arcgis._impl.portalpy.Portal object at 0x0000000007A8ACF8>
#    type='bigDataFileShare'

# %%
rootitems = gis.datastore.search('/')

# %%
rootitems
# Out:
# [<DatastoreItem title:"/bigDataFileShares" type:"datadir">,
#  <DatastoreItem title:"/enterpriseDatabases" type:"datadir">,
#  <DatastoreItem title:"/fileShares" type:"datadir">]

# %%
bigDataFileShares = gis.datastore.search(types = 'bigDataFileShare')

# %%
bigDataFileShares
# Out:
# [<DatastoreItem title:"/bigDataFileShares/bigdata" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/flooddata" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/flooddata3" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae2" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae3" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae6" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae666" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae7" type:"bigDataFileShare">]

# %%
enterpriseDatabases = gis.datastore.search('/enterpriseDatabases')

# %%
enterpriseDatabases
# Out:
# [<DatastoreItem title:"/enterpriseDatabases/AGSDataStore_ds_b2be1k4c" type:"egdb">]

# %%
enterpriseDatabases[0]
# Out:
# <DatastoreItem title:"/enterpriseDatabases/AGSDataStore_ds_b2be1k4c" type:"egdb">

# %%
print(enterpriseDatabases[0])
# Out:
#    id='a4f51997-28bc-4abb-b9d4-16d5f1058b23'
#    type='egdb'
#    _admin_url='https://Dev06999.esri.com:6443/arcgis/admin'
#    totalRefCount=0
#    path='/enterpriseDatabases/AGSDataStore_ds_b2be1k4c'
#    datapath='/enterpriseDatabases/AGSDataStore_ds_b2be1k4c'
#    _datastore=<arcgis.gis.DatastoreManager object at 0x0000000007ABB978>
# ...

# %%
enterpriseDatabases[0].info
# Out:
# {'JDBCConnection': {'driverClassName': 'org.postgresql.Driver',
#   'factory': 'org.apache.tomcat.jdbc.pool.DataSourceFactory',
#   'initialSize': 0,
#   'minEvictableIdleTimeMillis': 20000,
#   'minIdle': 0,
#   'name': 'PostgreSQLonDEV06999.ESRI.COM',
#   'password': '{crypt}HBPEAY+cqa+glyNE6xWBxA==',
#   'testOnBorrow': True,
#   'timeBetweenEvictionRunsMillis': 10000,
#   'url': 'jdbc:postgresql://DEV06999.ESRI.COM:9876/db_bpafh',
#   'username': 'hsu_rdd3s',
#   'validationQuery': 'SELECT 1'},
#  'connectionString': 'ENCRYPTED_PASSWORD=00022e68673944485944626f44743862774c333055434d635843502f75316177786468686841446c594a7849432b553d2a00;SERVER=DEV06999.ESRI.COM;INSTANCE=sde:postgresql:DEV06999.ESRI.COM,9876;DBCLIENT=postgresql;DB_CONNECTION_PROPERTIES=DEV06999.ESRI.COM,9876;DATABASE=db_bpafh;USER=hsu_rdd3s;VERSION=sde.DEFAULT;AUTHENTICATION_MODE=DBMS',
# ...

# %%
enterpriseDatabases[0].info['machines'][0]['role']
# Out:
# 'PRIMARY'

# %%
gis.datastore.get('/bigDataFileShares/bigdata')
# Out:
# <DatastoreItem title:"/bigDataFileShares/bigdata" type:"bigDataFileShare">

# %%
res = gis.datastore.get('/bigDataFileShares2')
# Out:
# ["Server machine 'https://DEV06999.ESRI.COM:7443/arcgis/sharing/rest/community/self' returned an error. 'Invalid token.'"]

# %%
print(res)
# Out:
# None

# %%
gis.datastore.validate()
# Out:
# https://dev06999.esri.com/portal/portaladmin/federation/servers?f=json
# True

# %%
a = gis.datastore.register({
	"path": "/fileShares/folder_shared", #a unique path on the server
	"type": "folder", #as this is a file share
	"clientPath": None, #not needed as this is a shared folder
	"info": {
		"path": "\\\\server\\data\\rest_data", #path to the share
		"dataStoreConnectionType": "shared" #this is a shared folder     
	}
})

# %%
f = gis.datastore.add_folder('testShare6', '\\\\yoda\\abc')

# %%
print(f)
# Out:
#    _admin_url='https://Dev06999.esri.com:6443/arcgis/admin'
#    id='ae500923-8ac1-48ba-84dc-e75bc34a9b30'
#    path='/fileShares/testShare6'
#    type='folder'
#    _portal=<arcgis._impl.portalpy.Portal object at 0x0000000007A6BCC0>
#    info={'dataStoreConnectionType': 'shared', 'path': '\\\\yoda\\abc'}
#    _datastore=<arcgis.gis.DatastoreManager object at 0x0000000007A9D6A0>
#    datapath='/fileShares/testShare6'

# %%
f2 = gis.datastore.add_folder('replicated_folder2', 'c:\\data', 'c:\\data')

# %%
f2
# Out:
# <DatastoreItem title:"/fileShares/replicated_folder2" type:"folder">

# %%
print(f2)
# Out:
#    _admin_url='https://Dev06999.esri.com:6443/arcgis/admin'
#    clientPath='c:\\data'
#    info={'dataStoreConnectionType': 'replicated', 'path': 'c:\\data'}
#    datapath='/fileShares/replicated_folder2'
#    type='folder'
#    id='c0551e95-2898-44af-ac49-c92c01ba3aab'
#    path='/fileShares/replicated_folder2'
#    _portal=<arcgis._impl.portalpy.Portal object at 0x0000000007A6BCC0>
#    _datastore=<arcgis.gis.DatastoreManager object at 0x0000000007A9D6A0>

# %%
bd = gis.datastore.add_bigdata("ChennaiF_rrrs", '\\\\dev06999\\bigdata\\Chennai\\flooddata', 'c:\\bigdata\\Chennai\\flooddata')
# Out:
# Created Big Data file shares data directory
# Created Big Data file share for ChennaiF_rrrs
# Executing (Generate Manifest): GenerateManifest c:\bigdata\Chennai\flooddata #
# Start Time: Mon May 02 07:20:45 2016
# file:/c:/bigdata/Chennai/flooddata/Enriched_Chennai_Population            shapefile   shp
# file:/c:/bigdata/Chennai/flooddata/LS8_20151014_PreFlood                  shapefile   shp
# file:/c:/bigdata/Chennai/flooddata/LS8_20151014_PreFlood_Analysis_Extent  shapefile   shp
# file:/c:/bigdata/Chennai/flooddata/S1_20150901_PreFlood_Analysis_Extent   shapefile   shp
# file:/c:/bigdata/Chennai/flooddata/S1_20151112_Flood                      shapefile   shp
# file:/c:/bigdata/Chennai/flooddata/S1_20151112_Flood_Analysis_Extent      shapefile   shp
# Succeeded at Mon May 02 07:20:45 2016 (Elapsed Time: 0.50 seconds)
# Uploaded/updated manifest
# file:/c:/bigdata/Chennai/flooddata/S1_20150901_PreFlood

# %% [markdown]
# ### Example—Enterprise database where the publisher and server use the same database

# %%
conn_str = """"ENCRYPTED_PASSWORD=00022e686f66464c762b6e2b31732b675a4e35667832547070513d3d2a00;
                SERVER=dbserver;INSTANCE=sde:sqlserver:dbserver;DBCLIENT=sqlserver;
                DB_CONNECTION_PROPERTIES=dbserver;DATABASE=vtest;
                USER=map;VERSION=sde.DEFAULT;AUTHENTICATION_MODE=DBMS"""

# %%
egdb_shared = gis.datastore.add_database("egdb_shared", conn_str)

# %%
egdb_shared
# Out:
# <DatastoreItem title:"/enterpriseDatabases/egdb_shared" type:"egdb">

# %% [markdown]
# ### Example—Server-managed enterprise database (such as ArcGIS Server's Managed Database)

# %%
egdb_managed = gis.datastore.add_database("egdb_managed", conn_str, "serverOnly")

# %%
egdb_managed
# Out:
# <DatastoreItem title:"/enterpriseDatabases/egdb_managed" type:"egdb">

# %% [markdown]
# ### Example—Enterprise database where the publisher and server use different databases

# %%
client_conn_str = """ENCRYPTED_PASSWORD=00022e686255754d75395162382f704c726a4d4d6456364b56673d3d2a00;
                    SERVER=dbserver;INSTANCE=sde:sqlserver:dbserver;DBCLIENT=sqlserver;
                    DB_CONNECTION_PROPERTIES=dbserver;DATABASE=vtest;USER=map;VERSION=sde.DEFAULT;
                    AUTHENTICATION_MODE=DBMS""" # an encrypted connection string for client to connect the database

# %%
egdb_replicated = gis.datastore.add_database("egdb_replicated", conn_str, client_conn_str, "replicated")

# %%
items = gis.datastore.list()

# %%
items
# Out:
# [<DatastoreItem title:"/bigDataFileShares/bigdata" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF-3" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF2" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF3" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF5" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF6" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF_gig" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF_rrrs" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/flooddata" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/flooddata3" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae2" type:"bigDataFileShare">,
# ...

# %%
gis.datastore.validate()
# Out:
# True

# %%
gis.datastore.search(None, '/')
# Out:
# [<DatastoreItem title:"/bigDataFileShares/bigdata" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF-3" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF2" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF3" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF5" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF6" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF_gig" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/ChennaiF_rrrs" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/flooddata" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/flooddata3" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae" type:"bigDataFileShare">,
#  <DatastoreItem title:"/bigDataFileShares/gae2" type:"bigDataFileShare">,
# ...

# %%
gis.datastore.search('/')
# Out:
# [<DatastoreItem title:"/bigDataFileShares" type:"datadir">,
#  <DatastoreItem title:"/enterpriseDatabases" type:"datadir">,
#  <DatastoreItem title:"/fileShares" type:"datadir">]

# %%
items[0]
# Out:
# <DatastoreItem title:"/bigDataFileShares/bigdata" type:"bigDataFileShare">

# %%
item = items[0]

# %%
item.manifest
# Out:
# {'datasets': [{'extension': 'shp',
#    'name': 'blockchains',
#    'path': 'blockchains',
#    'type': 'shapefile'},
#   {'extension': 'shp',
#    'name': 'chicago',
#    'path': 'chicago',
#    'type': 'shapefile'},
#   {'extension': 'csv',
#    'format': {'fieldDelimiter': ',',
#     'hasHeaderRow': True,
#     'recordTerminator': '\n'},
#    'geometryField': 'geometry_',
#    'name': 'chicago-accidents',
#    'path': 'chicago-accidents',
#    'pseudoFields': [{'fields': [{'formats': ['x'], 'name': 'longitude'},
#       {'formats': ['y'], 'name': 'latitude'}],
#      'keepSourceFields': True,
#      'name': 'geometry_',
#      'reference': {'wkid': 4326},
#      'subType': 'point',
#      'type': 'geometry'},
#     {'fields': [{'formats': ['yyyy-MM-dd'], 'name': 'date'}],
#      'keepSourceFields': True,
#      'name': 'time_',
#      'subType': 'instant',
#      'type': 'time'}],
#    'schema': {'fields': [{'name': 'date', 'type': 'string'},
# ...

# %%
item.list_datasets()
# Out:
# /server/datastores/bigDataFileShares/bigdata/blockgroups (shapefile)
# /server/datastores/bigDataFileShares/bigdata/chicago (shapefile)
# /server/datastores/bigDataFileShares/bigdata/chicago-accidents (delimited)
# /server/datastores/bigDataFileShares/bigdata/chicago-crimes (delimited)
# /server/datastores/bigDataFileShares/bigdata/countries (shapefile)
# /server/datastores/bigDataFileShares/bigdata/earthquakes (delimited)
# /server/datastores/bigDataFileShares/bigdata/epa (shapefile)
# /server/datastores/bigDataFileShares/bigdata/eruptions (shapefile)
# /server/datastores/bigDataFileShares/bigdata/faa (delimited)
# /server/datastores/bigDataFileShares/bigdata/faasmall (delimited)
# /server/datastores/bigDataFileShares/bigdata/faultlines (shapefile)
# /server/datastores/bigDataFileShares/bigdata/hurricanes (shapefile)
# /server/datastores/bigDataFileShares/bigdata/lightning (shapefile)
# /server/datastores/bigDataFileShares/bigdata/mineplant (shapefile)
# ...

# %%
item.manifest = {'datasets': [{'extension': 'shp',
   'name': 'blockchains',
   'path': 'blockchains',
   'type': 'shapefile'},
  {'extension': 'shp',
   'name': 'chicago',
   'path': 'chicago',
   'type': 'shapefile'},
  {'extension': 'csv',
   'format': {'fieldDelimiter': ',',
    'hasHeaderRow': True,
    'recordTerminator': '\n'},
   'geometryField': 'geometry_',
   'name': 'chicago-accidents',
   'path': 'chicago-accidents',
   'pseudoFields': [{'fields': [{'formats': ['x'], 'name': 'longitude'},
      {'formats': ['y'], 'name': 'latitude'}],
     'keepSourceFields': True,
     'name': 'geometry_',
     'reference': {'wkid': 4326},
     'subType': 'point',
     'type': 'geometry'},
    {'fields': [{'formats': ['yyyy-MM-dd'], 'name': 'date'}],
     'keepSourceFields': True,
     'name': 'time_',
     'subType': 'instant',
     'type': 'time'}],
   'schema': {'fields': [{'name': 'date', 'type': 'string'},
     {'name': 'year', 'type': 'integer'},
     {'name': 'day_o_week', 'type': 'integer'},
     {'name': 'num_veh', 'type': 'integer'},
     {'name': 'injuries', 'type': 'integer'},
     {'name': 'fatalities', 'type': 'integer'},
     {'name': 'coll_type', 'type': 'integer'},
     {'name': 'weather', 'type': 'integer'},
     {'name': 'lighting', 'type': 'integer'},
     {'name': 'surf_cond', 'type': 'integer'},
     {'name': 'rd_defect', 'type': 'integer'},
     {'name': 'veh1_type', 'type': 'integer'},
     {'name': 'veh1_specl', 'type': 'integer'},
     {'name': 'veh1_dir', 'type': 'integer'},
     {'name': 'veh1_manuv', 'type': 'integer'},
     {'name': 'veh1_loc1', 'type': 'integer'},
     {'name': 'veh2_type', 'type': 'integer'},
     {'name': 'veh2_specl', 'type': 'integer'},
     {'name': 'veh2_dir', 'type': 'integer'},
     {'name': 'veh2_manuv', 'type': 'integer'},
     {'name': 'veh2_loc1', 'type': 'integer'},
     {'name': 'longitude', 'type': 'double'},
     {'name': 'latitude', 'type': 'double'},
     {'name': 'intersection', 'type': 'integer'}]},
   'timeField': 'time_',
   'type': 'delimited'},
  {'extension': 'csv',
   'format': {'fieldDelimiter': ',',
    'hasHeaderRow': True,
    'recordTerminator': '\n'},
   'geometryField': 'geometry_',
   'name': 'chicago-crimes',
   'path': 'chicago-crimes',
   'pseudoFields': [{'fields': [{'formats': ['x'], 'name': 'Longitude'},
      {'formats': ['y'], 'name': 'Latitude'}],
     'keepSourceFields': True,
     'name': 'geometry_',
     'reference': {'wkid': 4326},
     'subType': 'point',
     'type': 'geometry'},
    {'fields': [{'formats': ['MM/dd/yyyy hh:mm:ss a'], 'name': 'Date'}],
     'keepSourceFields': True,
     'name': 'time_',
     'subType': 'instant',
     'type': 'time'}],
   'schema': {'fields': [{'name': 'ID', 'type': 'integer'},
     {'name': 'Case Number', 'type': 'string'},
     {'name': 'Date', 'type': 'string'},
     {'name': 'Block', 'type': 'string'},
     {'name': 'IUCR', 'type': 'string'},
     {'name': 'Primary Type', 'type': 'string'},
     {'name': 'Description', 'type': 'string'},
     {'name': 'Location Description', 'type': 'string'},
     {'name': 'Arrest', 'type': 'string'},
     {'name': 'Domestic', 'type': 'string'},
     {'name': 'Beat', 'type': 'integer'},
     {'name': 'District', 'type': 'integer'},
     {'name': 'Ward', 'type': 'integer'},
     {'name': 'Community Area', 'type': 'integer'},
     {'name': 'FBI Code', 'type': 'string'},
     {'name': 'X Coordinate', 'type': 'integer'},
     {'name': 'Y Coordinate', 'type': 'integer'},
     {'name': 'Year', 'type': 'integer'},
     {'name': 'Updated On', 'type': 'string'},
     {'name': 'Latitude', 'type': 'double'},
     {'name': 'Longitude', 'type': 'double'},
     {'name': 'Location', 'type': 'string'}]},
   'timeField': 'time_',
   'type': 'delimited'},
  {'extension': 'shp',
   'name': 'countries',
   'path': 'countries',
   'type': 'shapefile'},
  {'extension': 'csv',
   'format': {'fieldDelimiter': ',',
    'hasHeaderRow': True,
    'recordTerminator': '\n'},
   'geometryField': 'geometry_',
   'name': 'earthquakes',
   'path': 'earthquakes',
   'pseudoFields': [{'fields': [{'formats': ['yyyy/MM/dd HH:mm:ss.SSS'],
       'name': 'datetime'}],
     'name': 'time_',
     'reference': {'timeZone': 'UTC'},
     'subType': 'instant',
     'type': 'time'},
    {'fields': [{'formats': ['x'], 'name': 'longitude'},
      {'formats': ['y'], 'name': 'latitude'}],
     'name': 'geometry_',
     'reference': {'wkid': 4326},
     'subType': 'point',
     'type': 'geometry'}],
   'schema': {'fields': [{'name': 'datetime', 'type': 'string'},
     {'name': 'latitude', 'type': 'double'},
     {'name': 'longitude', 'type': 'double'},
     {'name': 'depth', 'type': 'double'},
     {'name': 'magnitude', 'type': 'double'},
     {'name': 'magtype', 'type': 'string'},
     {'name': 'nbstations', 'type': 'string'},
     {'name': 'gap', 'type': 'string'},
     {'name': 'distance', 'type': 'string'},
     {'name': 'rms', 'type': 'string'},
     {'name': 'source', 'type': 'string'},
     {'name': 'eventid', 'type': 'string'}]},
   'timeField': 'time_',
   'type': 'delimited'},
  {'extension': 'shp', 'name': 'epa', 'path': 'epa', 'type': 'shapefile'},
  {'name': 'eruptions',
   'path': 'eruptions',
   'pseudoFields': [{'fields': [{'formats': ['yyyy'], 'name': 'YEAR'},
      {'formats': ['MM'], 'name': 'MO'},
      {'formats': ['dd'], 'name': 'DAY'}],
     'keepSourceFields': True,
     'name': 'time_',
     'reference': {'timeZone': 'UTC'},
     'subType': 'interval',
     'type': 'time'}],
   'timeField': 'time_',
   'type': 'shapefile'},
  {'extension': 'tsv',
   'format': {'fieldDelimiter': '\t',
    'hasHeaderRow': False,
    'recordTerminator': '\n'},
   'name': 'faa',
   'path': 'faa',
   'pseudoFields': [],
   'schema': {'fields': [{'name': 'col_1', 'type': 'integer'},
     {'name': 'col_2', 'type': 'string'},
     {'name': 'col_3', 'type': 'string'},
     {'name': 'col_4', 'type': 'string'},
     {'name': 'col_5', 'type': 'double'},
     {'name': 'col_6', 'type': 'double'},
     {'name': 'col_7', 'type': 'double'},
     {'name': 'col_8', 'type': 'integer'},
     {'name': 'col_9', 'type': 'integer'},
     {'name': 'col_10', 'type': 'string'},
     {'name': 'col_11', 'type': 'string'},
     {'name': 'col_12', 'type': 'string'},
     {'name': 'col_13', 'type': 'string'},
     {'name': 'col_14', 'type': 'string'},
     {'name': 'col_15', 'type': 'string'},
     {'name': 'col_16', 'type': 'string'},
     {'name': 'col_17', 'type': 'string'},
     {'name': 'col_18', 'type': 'string'},
     {'name': 'col_19', 'type': 'string'},
     {'name': 'col_20', 'type': 'string'},
     {'name': 'col_21', 'type': 'string'}]},
   'type': 'delimited'},
  {'extension': 'tsv',
   'format': {'fieldDelimiter': '\t',
    'hasHeaderRow': True,
    'recordTerminator': '\n'},
   'geometryField': 'geometry_',
   'name': 'faasmall',
   'path': 'faasmall',
   'pseudoFields': [{'fields': [{'formats': ['x'], 'name': 'longitude'},
      {'formats': ['y'], 'name': 'latitude'}],
     'keepSourceFields': True,
     'name': 'geometry_',
     'reference': {'wkid': 4326},
     'subType': 'point',
     'type': 'geometry'},
    {'fields': [{'formats': ['MM/dd/yyyy HH:mm:ss'], 'name': 'datetimestamp'}],
     'keepSourceFields': True,
     'name': 'time_',
     'subType': 'instant',
     'type': 'time'}],
   'schema': {'fields': [{'name': 'id', 'type': 'integer'},
     {'name': 'flightid', 'type': 'string'},
     {'name': 'acid', 'type': 'string'},
     {'name': 'datetimestamp', 'type': 'string'},
     {'name': 'longitude', 'type': 'double'},
     {'name': 'latitude', 'type': 'double'},
     {'name': 'heading', 'type': 'double'},
     {'name': 'groundspeedknots', 'type': 'integer'},
     {'name': 'altitudefeet', 'type': 'integer'},
     {'name': 'actype', 'type': 'string'},
     {'name': 'airlineid', 'type': 'string'},
     {'name': 'originid', 'type': 'string'},
     {'name': 'destinationid', 'type': 'string'},
     {'name': 'aircraftcategory', 'type': 'string'},
     {'name': 'usercategory', 'type': 'string'},
     {'name': 'flightplanstatus', 'type': 'string'},
     {'name': 'departuretime', 'type': 'string'},
     {'name': 'arrivaltime', 'type': 'string'},
     {'name': 'estdeparturetime', 'type': 'string'},
     {'name': 'estarrivaltime', 'type': 'string'},
     {'name': 'flightclass', 'type': 'string'}]},
   'timeField': 'time_',
   'type': 'delimited'},
  {'extension': 'shp',
   'name': 'faultlines',
   'path': 'faultlines',
   'type': 'shapefile'},
  {'extension': 'shp',
   'name': 'hurricanes',
   'path': 'hurricanes',
   'pseudoFields': [{'fields': [{'formats': ['yyyy-MM-dd HH:mm:ss'],
       'name': 'iso_time'}],
     'keepSourceFields': True,
     'name': 'time_',
     'subType': 'instant',
     'type': 'time'}],
   'timeField': 'time_',
   'type': 'shapefile'},
  {'extension': 'shp',
   'name': 'lightning',
   'path': 'lightning',
   'pseudoFields': [{'fields': [{'formats': ['MM/dd/yyyy HH:mm:ss'],
       'name': 'UTC_DATE'}],
     'keepSourceFields': True,
     'name': 'time_',
     'subType': 'instant',
     'type': 'time'}],
   'timeField': 'time_',
   'type': 'shapefile'},
  {'extension': 'shp',
   'name': 'mineplant',
   'path': 'mineplant',
   'type': 'shapefile'},
  {'extension': 'shp',
   'name': 'rivers',
   'path': 'rivers',
   'type': 'shapefile'},
  {'extension': 'shp', 'name': 'sf', 'path': 'sf', 'type': 'shapefile'},
  {'extension': 'shp', 'name': 'taxi', 'path': 'taxi', 'type': 'shapefile'}]}

# %%
item.manifest
# Out:
# {'datasets': [{'extension': 'shp',
#    'name': 'blockchains',
#    'path': 'blockchains',
#    'type': 'shapefile'},
#   {'extension': 'shp',
#    'name': 'chicago',
#    'path': 'chicago',
#    'type': 'shapefile'},
#   {'extension': 'csv',
#    'format': {'fieldDelimiter': ',',
#     'hasHeaderRow': True,
#     'recordTerminator': '\n'},
#    'geometryField': 'geometry_',
#    'name': 'chicago-accidents',
#    'path': 'chicago-accidents',
#    'pseudoFields': [{'fields': [{'formats': ['x'], 'name': 'longitude'},
#       {'formats': ['y'], 'name': 'latitude'}],
#      'keepSourceFields': True,
#      'name': 'geometry_',
#      'reference': {'wkid': 4326},
#      'subType': 'point',
#      'type': 'geometry'},
#     {'fields': [{'formats': ['yyyy-MM-dd'], 'name': 'date'}],
#      'keepSourceFields': True,
#      'name': 'time_',
#      'subType': 'instant',
#      'type': 'time'}],
#    'schema': {'fields': [{'name': 'date', 'type': 'string'},
# ...

# %%
item.list_datasets()
# Out:
# /server/datastores/bigDataFileShares/bigdata/blockchains (shapefile)
# /server/datastores/bigDataFileShares/bigdata/chicago (shapefile)
# /server/datastores/bigDataFileShares/bigdata/chicago-accidents (delimited)
# /server/datastores/bigDataFileShares/bigdata/chicago-crimes (delimited)
# /server/datastores/bigDataFileShares/bigdata/countries (shapefile)
# /server/datastores/bigDataFileShares/bigdata/earthquakes (delimited)
# /server/datastores/bigDataFileShares/bigdata/epa (shapefile)
# /server/datastores/bigDataFileShares/bigdata/eruptions (shapefile)
# /server/datastores/bigDataFileShares/bigdata/faa (delimited)
# /server/datastores/bigDataFileShares/bigdata/faasmall (delimited)
# /server/datastores/bigDataFileShares/bigdata/faultlines (shapefile)
# /server/datastores/bigDataFileShares/bigdata/hurricanes (shapefile)
# /server/datastores/bigDataFileShares/bigdata/lightning (shapefile)
# /server/datastores/bigDataFileShares/bigdata/mineplant (shapefile)
# ...

# %%
item.validate()
# Out:
# True

# %%
item.ref_count
# Out:
# 0

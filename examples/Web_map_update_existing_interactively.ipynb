# %% [markdown]
# # Updating existing web maps interactively using map widget
# Notebook demonstrating various capabilities of the new web map API

# %%
from arcgis.gis import *
from arcgis.mapping import WebMap
from arcgis.raster import apply
from arcgis.features import FeatureLayer
from arcgis.geocoding import geocode
from arcgis.features import Feature, FeatureSet, FeatureCollection
from arcgis.mapping import MapImageLayer
import json
from arcgis.geometry import Point, Polyline, Polygon, Envelope
from arcgis.widgets import MapView

# %%
gis = GIS("https://www.arcgis.com","arcgis_python", "amazing_arcgis_123")

# %% [markdown]
# Some regular layers

# %%
point_flc_item = gis.content.get('415cda28e2614f1d82cb5822bf3c5c3d')
# point_flc_item = gis.content.get('f482f5c329984eac9a524024f9737607')
point_flc_item
# Out:
# <Item title:"Kindness" type:Feature Layer Collection owner:Community_Geography>

# %%
flc_item = gis.content.get('8d29d4a521f34ebba40dd918ac8322c3')
flc_item
# Out:
# <Item title:"Census Blocks 2010 (with 2017 and 2022 Data)" type:Feature Layer Collection owner:JohnsCreekGA>

# %%
mil_item = gis.content.get('c6719c88770f402690c0ca25afe8c405')
mil_item
# Out:
# <Item title:"GAWeatherStations" type:Map Image Layer owner:rbagby_gema>

# %%
mil = MapImageLayer("https://sampleserver6.arcgisonline.com/arcgis/rest/services/Census/MapServer")
mil
# Out:
# <MapImageLayer url:"https://sampleserver6.arcgisonline.com/arcgis/rest/services/Census/MapServer">

# %% [markdown]
# ## Read an existing web map object

# %%
sr = gis.content.search("","Web Map", max_items=40)
sr
# Out:
# [<Item title:"USA median age map" type:Web Map owner:arcgis_python>,
#  <Item title:"pyAPI 8-plp" type:Web Map owner:amani_geosaurus>,
#  <Item title:"Braidburn Valley" type:Web Map owner:arcgis_python>,
#  <Item title:"Ebola treatment locations - badlayer-original" type:Web Map owner:arcgis_python>,
#  <Item title:"Virginia Counties" type:Web Map owner:arcgis_python>,
#  <Item title:"Duluth blue polygons3" type:Web Map owner:arcgis_python>,
#  <Item title:"OCHA_Pittsburg" type:Web Map owner:arcgis_python>,
#  <Item title:"WM with def Expressions" type:Web Map owner:arcgis_python>,
#  <Item title:"TestAnalysis" type:Web Map owner:arcgis_python>,
#  <Item title:"Restaurants near Esri 4 - popup" type:Web Map owner:amani_geosaurus>,
#  <Item title:"Ebola treatment locations" type:Web Map owner:arcgis_python>,
#  <Item title:"Crime_subset1" type:Web Map owner:amani_geosaurus>,
#  <Item title:"campos_clss" type:Web Map owner:arcgis_python>,
#  <Item title:"WM with def Expressions 2" type:Web Map owner:arcgis_python>,
#  <Item title:"USA median age map" type:Web Map owner:arcgis_python>,
#  <Item title:"washington map" type:Web Map owner:arcgis_python>,
#  <Item title:"Ebola treatment locations" type:Web Map owner:arcgis_python>,
#  <Item title:"Ebola treatment locations - badlayer" type:Web Map owner:arcgis_python>,
#  <Item title:"Sample Result DBSCAN Map" type:Web Map owner:andrew887>,
#  <Item title:"better ebola map" type:Web Map owner:arcgis_python>,
#  <Item title:"pyAPI webmap 6 - plp" type:Web Map owner:amani_geosaurus>,
#  <Item title:"washington map" type:Web Map owner:arcgis_python>,
#  <Item title:"washington map" type:Web Map owner:arcgis_python>]

# %%
wm_item = sr[5]
wm_item
# Out:
# <Item title:"Duluth blue polygons3" type:Web Map owner:arcgis_python>

# %% [markdown]
# ## Change the basemap of this map and save as new item

# %%
wm = WebMap(wm_item)
wm_map = MapView(item=wm)
wm_map

# %%
wm_map.draw("freehandpolyline")

# %%
wm_map.clear_graphics()

# %%
wm_map.basemap
# Out:
# 'topo'

# %%
wm_map.basemap = 'dark-gray'

# %%
wm_map._js_basemap
# Out:
# '[{"url":"http://services.arcgisonline.com/ArcGIS/rest/services/Canvas/World_Dark_Gray_Base/MapServer","title":"Canvas Base"},{"url":"http://services.arcgisonline.com/ArcGIS/rest/services/Canvas/World_Dark_Gray_Reference/MapServer","title":"Canvas Reference"}]'

# %%
len(wm_map.layers)
# Out:
# 3

# %%
type(wm_map.layers[0])
# Out:
# arcgis._impl.common._mixins.PropertyMap

# %%
wm_map.remove_layers(wm_map.layers[0])
# Out:
# False

# %%
wm_map._js_layer_list
# Out:
# ''

# %%
wm_map._webmap_added_layer_list
# Out:
# ['4a331eb8-19b7-4eb6-9617-037efab4f0b8']

# %%
wm_map._widget_layer_list
# Out:
# [{
#    "id": "4a331eb8-19b7-4eb6-9617-037efab4f0b8",
#    "layerType": "ArcGISFeatureLayer",
#    "url": "https://sampleserver6.arcgisonline.com/arcgis/rest/services/Census/MapServer/2",
#    "visibility": true,
#    "opacity": 0.7,
#    "mode": 1,
#    "title": "Detailed Counties",
#    "layerDefinition": {
#      "drawingInfo": {
#        "renderer": {
#          "type": "classBreaks",
#          "field": "POP2007",
#          "defaultSymbol": {
#            "color": [
#              170,
#              170,
#              170,
#              255
#            ],
#            "outline": {
#              "color": [
#                153,
#                153,
#                153,
#                255
#              ],
#              "width": 0.375,
#              "type": "esriSLS",
#              "style": "esriSLSSolid"
#            },
#            "type": "esriSFS",
#            "style": "esriSFSSolid"
#          },
#          "minValue": 2384,
#          "classBreakInfos": [
#            {
#              "symbol": {
#                "color": [
#                  230,
#                  238,
#                  207,
#                  255
#                ],
#                "outline": {
#                  "color": [
#                    153,
#                    153,
#                    153,
#                    255
#                  ],
#                  "width": 0.375,
#                  "type": "esriSLS",
#                  "style": "esriSLSSolid"
#                },
#                "type": "esriSFS",
#                "style": "esriSFSSolid"
#              },
#              "label": "2,384 to 15,944",
#              "classMaxValue": 15944
#            },
#            {
#              "symbol": {
#                "color": [
#                  155,
#                  196,
#                  193,
#                  255
#                ],
#                "outline": {
#                  "color": [
#                    153,
#                    153,
#                    153,
#                    255
#                  ],
#                  "width": 0.375,
#                  "type": "esriSLS",
#                  "style": "esriSLSSolid"
#                },
#                "type": "esriSFS",
#                "style": "esriSFSSolid"
#              },
#              "label": "> 15,944 to 41,225",
#              "classMaxValue": 41225
#            },
#            {
#              "symbol": {
#                "color": [
#                  105,
#                  168,
#                  183,
#                  255
#                ],
#                "outline": {
#                  "color": [
#                    153,
#                    153,
#                    153,
#                    255
#                  ],
#                  "width": 0.375,
#                  "type": "esriSLS",
#                  "style": "esriSLSSolid"
#                },
#                "type": "esriSFS",
#                "style": "esriSFSSolid"
#              },
#              "label": "> 41,225 to 71,939",
#              "classMaxValue": 71939
#            },
#            {
#              "symbol": {
#                "color": [
#                  75,
#                  126,
#                  152,
#                  255
#                ],
#                "outline": {
#                  "color": [
#                    153,
#                    153,
#                    153,
#                    255
#                  ],
#                  "width": 0.375,
#                  "type": "esriSLS",
#                  "style": "esriSLSSolid"
#                },
#                "type": "esriSFS",
#                "style": "esriSFSSolid"
#              },
#              "label": "> 71,939 to 236,325",
#              "classMaxValue": 236325
#            },
#            {
#              "symbol": {
#                "color": [
#                  46,
#                  85,
#                  122,
#                  255
#                ],
#                "outline": {
#                  "color": [
#                    153,
#                    153,
#                    153,
#                    255
#                  ],
#                  "width": 0.375,
#                  "type": "esriSLS",
#                  "style": "esriSLSSolid"
#                },
#                "type": "esriSFS",
#                "style": "esriSFSSolid"
#              },
#              "label": "> 236,325 to 1,859,574",
#              "classMaxValue": 1859574
#            }
#          ],
#          "defaultLabel": "Other",
#          "classificationMethod": "esriClassifyQuantile"
#        }
#      },
#      "definitionExpression": "STATE_NAME = 'Washington'"
#    },
#    "popupInfo": {
#      "title": "Detailed Counties",
#      "fieldInfos": [
#        {
#          "fieldName": "OBJECTID",
#          "label": "OBJECTID",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "Shape",
#          "label": "Shape",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "NAME",
#          "label": "NAME",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "STATE_NAME",
#          "label": "STATE_NAME",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "STATE_FIPS",
#          "label": "STATE_FIPS",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "CNTY_FIPS",
#          "label": "CNTY_FIPS",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "FIPS",
#          "label": "FIPS",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "POP2000",
#          "label": "POP2000",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "POP2007",
#          "label": "POP2007",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "POP00_SQMI",
#          "label": "POP00_SQMI",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "POP07_SQMI",
#          "label": "POP07_SQMI",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "WHITE",
#          "label": "WHITE",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "BLACK",
#          "label": "BLACK",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AMERI_ES",
#          "label": "AMERI_ES",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "ASIAN",
#          "label": "ASIAN",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "HAWN_PI",
#          "label": "HAWN_PI",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "OTHER",
#          "label": "OTHER",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "MULT_RACE",
#          "label": "MULT_RACE",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "HISPANIC",
#          "label": "HISPANIC",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "MALES",
#          "label": "MALES",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "FEMALES",
#          "label": "FEMALES",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AGE_UNDER5",
#          "label": "AGE_UNDER5",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AGE_5_17",
#          "label": "AGE_5_17",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AGE_18_21",
#          "label": "AGE_18_21",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AGE_22_29",
#          "label": "AGE_22_29",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AGE_30_39",
#          "label": "AGE_30_39",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AGE_40_49",
#          "label": "AGE_40_49",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AGE_50_64",
#          "label": "AGE_50_64",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AGE_65_UP",
#          "label": "AGE_65_UP",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "MED_AGE",
#          "label": "MED_AGE",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "MED_AGE_M",
#          "label": "MED_AGE_M",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "MED_AGE_F",
#          "label": "MED_AGE_F",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "HOUSEHOLDS",
#          "label": "HOUSEHOLDS",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AVE_HH_SZ",
#          "label": "AVE_HH_SZ",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "HSEHLD_1_M",
#          "label": "HSEHLD_1_M",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "HSEHLD_1_F",
#          "label": "HSEHLD_1_F",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "MARHH_CHD",
#          "label": "MARHH_CHD",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "MARHH_NO_C",
#          "label": "MARHH_NO_C",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "MHH_CHILD",
#          "label": "MHH_CHILD",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "FHH_CHILD",
#          "label": "FHH_CHILD",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "FAMILIES",
#          "label": "FAMILIES",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AVE_FAM_SZ",
#          "label": "AVE_FAM_SZ",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "HSE_UNITS",
#          "label": "HSE_UNITS",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "VACANT",
#          "label": "VACANT",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "OWNER_OCC",
#          "label": "OWNER_OCC",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "RENTER_OCC",
#          "label": "RENTER_OCC",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "NO_FARMS97",
#          "label": "NO_FARMS97",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AVG_SIZE97",
#          "label": "AVG_SIZE97",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "CROP_ACR97",
#          "label": "CROP_ACR97",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "AVG_SALE97",
#          "label": "AVG_SALE97",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "SQMI",
#          "label": "SQMI",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "Shape_Length",
#          "label": "Shape_Length",
#          "isEditable": true,
#          "visible": true
#        },
#        {
#          "fieldName": "Shape_Area",
#          "label": "Shape_Area",
#          "isEditable": true,
#          "visible": true
#        }
#      ],
#      "description": null,
#      "showAttachments": true,
#      "mediaInfos": []
#    }
#  }]

# %%
wm_map.basemap = 'topo'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-a841df996c51> in <module>()
# ----> 1 wm_map.basemap = 'topo'
#
# /Users/atma6951/anaconda/envs/geosaurus_gold/lib/python3.6/site-packages/arcgis/widgets/__init__.py in basemap(self, value)
#     414             else:
#     415                 print("Basemap '" + str(value) + "' is not a valid basemap name.")
# --> 416         self._update_webmap_basemap()
#     417
#     418     def _update_webmap_basemap(self):
#
# /Users/atma6951/anaconda/envs/geosaurus_gold/lib/python3.6/site-packages/arcgis/widgets/__init__.py in _update_webmap_basemap(self)
#     444
#     445             #update basemap in internal web map
# --> 446             self._webmap._basemap['baseMapLayers'] = basemap_layers
#     447             self._webmap._basemap['title'] = layer['title']
#     448             self._webmap._webmapdict['baseMap'] = self._webmap._basemap
#
# TypeError: 'NoneType' object does not support item assignment

# %%
wm_map.basemaps
# Out:
# ['dark-gray',
#  'dark-gray-vector',
#  'gray',
#  'gray-vector',
#  'hybrid',
#  'national-geographic',
#  'oceans',
#  'osm',
#  'satellite',
#  'streets',
#  'streets-navigation-vector',
#  'streets-night-vector',
#  'streets-relief-vector',
#  'streets-vector',
#  'terrain',
#  'topo',
#  'topo-vector']

# %% [markdown]
# ## Heat map renderer

# %%
hm_map = gis.map("Georgia")
hm_map

# %%
hm_map.add_layer(point_flc_item, {'renderer':'HeatmapRenderer'})

# %%
hm_map._smartmapping_layer_list
# Out:
# []

# %%
json.loads(hm_map._js_layer_list)[0]['renderer']
# Out:
# {'blurRadius': 10,
#  'colorStops': [{'color': [255, 140, 0, 0], 'ratio': 0},
#   {'color': [255, 140, 0, 255], 'ratio': 0.75},
#   {'color': [255, 0, 0, 255], 'ratio': 0.9}],
#  'field': None,
#  'maxPixelIntensity': 100,
#  'minPixelIntensity': 0,
#  'type': 'heatmap'}

# %%
hm_map._process_smart_mapping()

# %%
hm_map._webmap.layers
# Out:
# [{
#    "layerDefinition": {
#      "drawingInfo": {
#        "renderer": {
#          "colorStops": [
#            {
#              "ratio": 0,
#              "color": [
#                255,
#                140,
#                0,
#                0
#              ]
#            },
#            {
#              "ratio": 0.75,
#              "color": [
#                255,
#                140,
#                0,
#                255
#              ]
#            },
#            {
#              "ratio": 0.9,
#              "color": [
#                255,
#                0,
#                0,
#                255
#              ]
#            }
#          ],
#          "maxPixelIntensity": 100,
#          "field": null,
#          "blurRadius": 10,
#          "type": "heatmap",
#          "minPixelIntensity": 0
#        }
#      }
#    },
#    "layerType": "ArcGISFeatureLayer",
#    "title": "Map Acts of Kindness",
#    "url": "https://services1.arcgis.com/7Csm4eKNP8xsiEc1/arcgis/rest/services/Kindness/FeatureServer/0",
#    "visibility": true,
#    "opacity": 1,
#    "itemId": "415cda28e2614f1d82cb5822bf3c5c3d",
#    "id": "5ab9d11d-2d9e-4bf0-9c4b-8c375c16b5e9",
#    "popupInfo": {
#      "title": "Map Acts of Kindness",
#      "description": null,
#      "fieldInfos": [
#        {
#          "fieldName": "OBJECTID",
#          "visible": true,
#          "label": "OBJECTID",
#          "isEditable": false
#        },
#        {
#          "fieldName": "DESCRIPTION",
#          "visible": true,
#          "label": "Please type a short description of the act of kindness.",
#          "isEditable": true
#        },
#        {
#          "fieldName": "SCHOOLNAME",
#          "visible": true,
#          "label": "Name of school you are most associated with?",
#          "isEditable": true
#        },
#        {
#          "fieldName": "INVOLVEMENT",
#          "visible": true,
#          "label": "Was it an individual act of kindness or group act of kindness?",
#          "isEditable": true
#        },
#        {
#          "fieldName": "State",
#          "visible": true,
#          "label": "In which U.S. state do you live?",
#          "isEditable": true
#        }
#      ],
#      "mediaInfos": [],
#      "showAttachments": true
#    }
#  }]

# %% [markdown]
# ### Save the web map with heatmap

# %%
wm_item1 = hm_map.save("GA WM with heatmap3", "Created using Notebooks", ['automation', 'science'])
wm_item1
# Out:
# <Item title:"GA WM with heatmap3" type:Web Map owner:arcgis_python>

# %%
wm = WebMap(wm_item1)
wm

# %% [markdown]
# ## ClassedColorRenderer

# %%
cc_map = gis.map("Duluth, GA")
cc_map

# %%
cc_map.add_layer(point_flc_item)

# %%
cc_map.layers
# Out:
# [<FeatureLayer url:"https://services1.arcgis.com/7Csm4eKNP8xsiEc1/arcgis/rest/services/Kindness/FeatureServer/0">]

# %%
json.loads(cc_map._js_layer_list)[1]['renderer'].keys()
# Out:
# dict_keys(['type', 'field', 'defaultSymbol', 'minValue', 'classBreakInfos', 'defaultLabel', 'classificationMethod'])

# %%
json.loads(cc_map._js_layer_list)[1]['renderer']['type']
# Out:
# 'classBreaks'

# %%
json.loads(cc_map._js_layer_list)[1]['renderer']['field']
# Out:
# 'POP20_CY'

# %%
json.loads(cc_map._js_layer_list)[1]['renderer']['defaultSymbol']
# Out:
# {'color': [170, 170, 170, 255],
#  'outline': {'color': [153, 153, 153, 255],
#   'style': 'esriSLSSolid',
#   'type': 'esriSLS',
#   'width': 0.375},
#  'style': 'esriSFSSolid',
#  'type': 'esriSFS'}

# %%
json.loads(cc_map._js_layer_list)[1]['renderer']['minValue']
# Out:
# 0

# %%
json.loads(cc_map._js_layer_list)[1]['renderer']['defaultLabel']
# Out:
# 'Other'

# %%
json.loads(cc_map._js_layer_list)[1]['renderer']['classificationMethod']
# Out:
# 'esriClassifyQuantile'

# %%
json.loads(cc_map._js_layer_list)[1]['renderer']['classBreakInfos']
# Out:
# [{'classMaxValue': 0,
#   'label': '0 to 0',
#   'symbol': {'color': [230, 238, 207, 255],
#    'outline': {'color': [153, 153, 153, 255],
#     'style': 'esriSLSSolid',
#     'type': 'esriSLS',
#     'width': 0.375},
#    'style': 'esriSFSSolid',
#    'type': 'esriSFS'}},
#  {'classMaxValue': 2,
#   'label': '> 0 to 2',
#   'symbol': {'color': [155, 196, 193, 255],
#    'outline': {'color': [153, 153, 153, 255],
#     'style': 'esriSLSSolid',
#     'type': 'esriSLS',
#     'width': 0.375},
#    'style': 'esriSFSSolid',
#    'type': 'esriSFS'}},
#  {'classMaxValue': 6,
#   'label': '> 2 to 6',
#   'symbol': {'color': [105, 168, 183, 255],
#    'outline': {'color': [153, 153, 153, 255],
#     'style': 'esriSLSSolid',
#     'type': 'esriSLS',
#     'width': 0.375},
#    'style': 'esriSFSSolid',
#    'type': 'esriSFS'}},
#  {'classMaxValue': 15,
#   'label': '> 6 to 15',
#   'symbol': {'color': [75, 126, 152, 255],
#    'outline': {'color': [153, 153, 153, 255],
#     'style': 'esriSLSSolid',
#     'type': 'esriSLS',
#     'width': 0.375},
#    'style': 'esriSFSSolid',
#    'type': 'esriSFS'}},
#  {'classMaxValue': 187,
#   'label': '> 15 to 187',
#   'symbol': {'color': [46, 85, 122, 255],
#    'outline': {'color': [153, 153, 153, 255],
#     'style': 'esriSLSSolid',
#     'type': 'esriSLS',
#     'width': 0.375},
#    'style': 'esriSFSSolid',
#    'type': 'esriSFS'}}]

# %%
cc_map.add_layer(flc_item,{'renderer':'ClassedColorRenderer','field_name':'POP20_CY'})

# %% [markdown]
# ### Save as web map - with CCR

# %%
ccwm = cc_map.save("WM with CCR - NB", "Web map with ClassedColorRenderer", ['Automation'])
ccwm
# Out:
# <Item title:"WM with CCR - NB" type:Web Map owner:arcgis_python>

# %%
wm = WebMap(ccwm)
wm

# %% [markdown]
# ## ClassedSizeRenderer

# %%
cs_map = gis.map("Duluth, GA", zoomlevel=8)
cs_map

# %%
cs_map.add_layer(point_flc_item)

# %%
cs_map.add_layer(flc_item, {'renderer':'ClassedSizeRenderer', 'field_name':'POP20_CY'})

# %%
json.loads(cs_map._js_layer_list)[1]['renderer']
# Out:
# {'backgroundFillSymbol': {'color': [0, 0, 0, 0],
#   'outline': {'color': [166, 166, 166, 255],
#    'style': 'esriSLSSolid',
#    'type': 'esriSLS',
#    'width': 0.75},
#   'style': 'esriSFSSolid',
#   'type': 'esriSFS'},
#  'classBreakInfos': [{'classMaxValue': 0,
#    'label': '0 to 0',
#    'symbol': {'angle': 0,
#     'color': [227, 139, 79, 255],
#     'outline': {'color': [255, 255, 255, 255],
#      'style': 'esriSLSSolid',
#      'type': 'esriSLS',
#      'width': 0.75},
#     'size': 6,
#     'style': 'esriSMSCircle',
#     'type': 'esriSMS',
#     'xoffset': 0,
#     'yoffset': 0}},
#   {'classMaxValue': 2,
#    'label': '> 0 to 2',
#    'symbol': {'angle': 0,
#     'color': [227, 139, 79, 255],
#     'outline': {'color': [255, 255, 255, 255],
#      'style': 'esriSLSSolid',
#      'type': 'esriSLS',
#      'width': 0.75},
#     'size': 13.875,
#     'style': 'esriSMSCircle',
#     'type': 'esriSMS',
#     'xoffset': 0,
#     'yoffset': 0}},
#   {'classMaxValue': 6,
#    'label': '> 2 to 6',
#    'symbol': {'angle': 0,
#     'color': [227, 139, 79, 255],
#     'outline': {'color': [255, 255, 255, 255],
#      'style': 'esriSLSSolid',
#      'type': 'esriSLS',
#      'width': 0.75},
#     'size': 21.75,
#     'style': 'esriSMSCircle',
#     'type': 'esriSMS',
#     'xoffset': 0,
#     'yoffset': 0}},
#   {'classMaxValue': 15,
#    'label': '> 6 to 15',
#    'symbol': {'angle': 0,
#     'color': [227, 139, 79, 255],
#     'outline': {'color': [255, 255, 255, 255],
#      'style': 'esriSLSSolid',
#      'type': 'esriSLS',
#      'width': 0.75},
#     'size': 29.625,
#     'style': 'esriSMSCircle',
#     'type': 'esriSMS',
#     'xoffset': 0,
#     'yoffset': 0}},
#   {'classMaxValue': 187,
#    'label': '> 15 to 187',
#    'symbol': {'angle': 0,
#     'color': [227, 139, 79, 255],
#     'outline': {'color': [255, 255, 255, 255],
#      'style': 'esriSLSSolid',
#      'type': 'esriSLS',
#      'width': 0.75},
#     'size': 37.5,
#     'style': 'esriSMSCircle',
#     'type': 'esriSMS',
#     'xoffset': 0,
#     'yoffset': 0}}],
#  'classificationMethod': 'esriClassifyQuantile',
#  'defaultLabel': 'Other',
#  'defaultSymbol': {'angle': 0,
#   'color': [128, 128, 128, 255],
#   'outline': {'color': [255, 255, 255, 255],
#    'style': 'esriSLSSolid',
#    'type': 'esriSLS',
#    'width': 0.75},
#   'size': 9,
#   'style': 'esriSMSCircle',
#   'type': 'esriSMS',
#   'xoffset': 0,
#   'yoffset': 0},
#  'field': 'POP20_CY',
#  'minValue': 0,
#  'type': 'classBreaks'}

# %%
cs_map._smartmapping_layer_list
# Out:
# [{<FeatureLayer url:"https://services1.arcgis.com/bqfNVPUK3HOnCFmA/arcgis/rest/services/Census_Blocks_2010_(with_2017_and_2022_Data)/FeatureServer/0">: {'extent': {'spatialReference': {'wkid': 102100},
#     'type': 'extent',
#     'xmax': -9357366.226605723,
#     'xmin': -9376666.576247705,
#     'ymax': 4033115.196275241,
#     'ymin': 4025471.4934467343},
#    'field_name': 'POP20_CY',
#    'renderer': 'ClassedSizeRenderer'}}]

# %% [markdown]
# #### Save ClassedSizeRederer

# %%
csmap_item = cs_map.save("WM CSR polygon 2", 
                         "ClassedSizeRenderer with 2 layers",
                        ['automation'])
csmap_item
# Out:
# <Item title:"WM CSR polygon 2" type:Web Map owner:arcgis_python>

# %%
wm = WebMap(csmap_item)
wm

# %%
search_result = gis.content.search('title:USA freeway system AND owner:esri', 
                                  item_type = 'Feature Layer', outside_org=True)[0]
search_result
# Out:
# <Item title:"USA Freeway System" type:Feature Layer Collection owner:esri>

# %%
fw_map = gis.map("Atlanta, GA")
fw_map

# %%
fw_map.extent
# Out:
# {'spatialReference': {'latestWkid': 4326, 'wkid': 4326},
#  'xmax': -84.26510999999996,
#  'xmin': -84.51710999999997,
#  'ymax': 33.87431000000006,
#  'ymin': 33.62231000000006}

# %%
freeway_feature_layer = search_result.layers[0]
fw_map.add_layer(freeway_feature_layer, {"renderer":"ClassedSizeRenderer", 
                                         "field_name": "DIST_MILES"})

# %%
json.loads(fw_map._js_layer_list)
# Out:
# [{'id': 'graphicsLayer6',
#   'normalization': True,
#   'refreshInterval': 0,
#   'renderer': {'classBreakInfos': [{'classMaxValue': 3.87596,
#      'label': '0 to 3.8',
#      'symbol': {'color': [226, 119, 40, 255],
#       'style': 'esriSLSSolid',
#       'type': 'esriSLS',
#       'width': 0.75}},
#     {'classMaxValue': 8.95041,
#      'label': '> 3.8 to 8.9',
#      'symbol': {'color': [226, 119, 40, 255],
#       'style': 'esriSLSSolid',
#       'type': 'esriSLS',
#       'width': 3.9375}},
#     {'classMaxValue': 20.51156,
#      'label': '> 8.9 to 20.5',
#      'symbol': {'color': [226, 119, 40, 255],
#       'style': 'esriSLSSolid',
#       'type': 'esriSLS',
#       'width': 7.125}},
#     {'classMaxValue': 63.89144,
#      'label': '> 20.5 to 63',
#      'symbol': {'color': [226, 119, 40, 255],
#       'style': 'esriSLSSolid',
#       'type': 'esriSLS',
#       'width': 10.3125}},
#     {'classMaxValue': 2747.27247,
#      'label': '> 63 to 2,747',
#      'symbol': {'color': [226, 119, 40, 255],
#       'style': 'esriSLSSolid',
#       'type': 'esriSLS',
#       'width': 13.5}}],
#    'classificationMethod': 'esriClassifyQuantile',
#    'defaultLabel': 'Other',
#    'defaultSymbol': {'color': [128, 128, 128, 255],
#     'style': 'esriSLSSolid',
#     'type': 'esriSLS',
#     'width': 0.75},
#    'field': 'DIST_MILES',
#    'minValue': 0.03079,
#    'type': 'classBreaks'},
#   'rendererType': 'esri.renderer.ClassBreaksRenderer',
#   'url': 'https://services.arcgis.com/P3ePLMYs2RVChkJx/arcgis/rest/services/USA_Freeway_System/FeatureServer/1?token=oUv_epsy_Mr6CX6NuHQ_zqcayRbku_oMS6nP2F4B0wmDYzu08MYTIJF_30T9zctkrtWNai9w2gwsqZivNotTAPo5R_lH5ZsO_AUUVhZzSaYmrHyVQAfqTR2llYTgFWtdQJ2ajumcZ8q3gSaXL3ASIBEdL_Hd3s9He9ZuvEYQIRU.'}]

# %%
fw_map.save("Freeway ClassedSizeRenderer", "Smartmapping with Python api", ['Automation'])
# Out:
# <Item title:"Freeway ClassedSizeRenderer" type:Web Map owner:arcgis_python>

# %% [markdown]
# ## Definition queries

# %%
fl = FeatureLayer('https://sampleserver6.arcgisonline.com/arcgis/rest/services/Census/MapServer/2')
fl
# Out:
# <FeatureLayer url:"https://sampleserver6.arcgisonline.com/arcgis/rest/services/Census/MapServer/2">

# %%
fl.properties.fields
# Out:
# [{
#    "name": "OBJECTID",
#    "type": "esriFieldTypeOID",
#    "alias": "OBJECTID",
#    "domain": null
#  }, {
#    "name": "Shape",
#    "type": "esriFieldTypeGeometry",
#    "alias": "Shape",
#    "domain": null
#  }, {
#    "name": "NAME",
#    "type": "esriFieldTypeString",
#    "alias": "NAME",
#    "length": 32,
#    "domain": null
#  }, {
#    "name": "STATE_NAME",
#    "type": "esriFieldTypeString",
#    "alias": "STATE_NAME",
#    "length": 25,
#    "domain": null
#  }, {
#    "name": "STATE_FIPS",
#    "type": "esriFieldTypeString",
#    "alias": "STATE_FIPS",
#    "length": 2,
#    "domain": null
#  }, {
#    "name": "CNTY_FIPS",
#    "type": "esriFieldTypeString",
#    "alias": "CNTY_FIPS",
#    "length": 3,
#    "domain": null
#  }, {
#    "name": "FIPS",
#    "type": "esriFieldTypeString",
#    "alias": "FIPS",
#    "length": 5,
#    "domain": null
#  }, {
#    "name": "POP2000",
#    "type": "esriFieldTypeInteger",
#    "alias": "POP2000",
#    "domain": null
#  }, {
#    "name": "POP2007",
#    "type": "esriFieldTypeInteger",
#    "alias": "POP2007",
#    "domain": null
#  }, {
#    "name": "POP00_SQMI",
#    "type": "esriFieldTypeDouble",
#    "alias": "POP00_SQMI",
#    "domain": null
#  }, {
#    "name": "POP07_SQMI",
#    "type": "esriFieldTypeDouble",
#    "alias": "POP07_SQMI",
#    "domain": null
#  }, {
#    "name": "WHITE",
#    "type": "esriFieldTypeInteger",
#    "alias": "WHITE",
#    "domain": null
#  }, {
#    "name": "BLACK",
#    "type": "esriFieldTypeInteger",
#    "alias": "BLACK",
#    "domain": null
#  }, {
#    "name": "AMERI_ES",
#    "type": "esriFieldTypeInteger",
#    "alias": "AMERI_ES",
#    "domain": null
#  }, {
#    "name": "ASIAN",
#    "type": "esriFieldTypeInteger",
#    "alias": "ASIAN",
#    "domain": null
#  }, {
#    "name": "HAWN_PI",
#    "type": "esriFieldTypeInteger",
#    "alias": "HAWN_PI",
#    "domain": null
#  }, {
#    "name": "OTHER",
#    "type": "esriFieldTypeInteger",
#    "alias": "OTHER",
#    "domain": null
#  }, {
#    "name": "MULT_RACE",
#    "type": "esriFieldTypeInteger",
#    "alias": "MULT_RACE",
#    "domain": null
#  }, {
#    "name": "HISPANIC",
#    "type": "esriFieldTypeInteger",
#    "alias": "HISPANIC",
#    "domain": null
#  }, {
#    "name": "MALES",
#    "type": "esriFieldTypeInteger",
#    "alias": "MALES",
#    "domain": null
#  }, {
#    "name": "FEMALES",
#    "type": "esriFieldTypeInteger",
#    "alias": "FEMALES",
#    "domain": null
#  }, {
#    "name": "AGE_UNDER5",
#    "type": "esriFieldTypeInteger",
#    "alias": "AGE_UNDER5",
#    "domain": null
#  }, {
#    "name": "AGE_5_17",
#    "type": "esriFieldTypeInteger",
#    "alias": "AGE_5_17",
#    "domain": null
#  }, {
#    "name": "AGE_18_21",
#    "type": "esriFieldTypeInteger",
#    "alias": "AGE_18_21",
#    "domain": null
#  }, {
#    "name": "AGE_22_29",
#    "type": "esriFieldTypeInteger",
#    "alias": "AGE_22_29",
#    "domain": null
#  }, {
#    "name": "AGE_30_39",
#    "type": "esriFieldTypeInteger",
#    "alias": "AGE_30_39",
#    "domain": null
#  }, {
#    "name": "AGE_40_49",
#    "type": "esriFieldTypeInteger",
#    "alias": "AGE_40_49",
#    "domain": null
#  }, {
#    "name": "AGE_50_64",
#    "type": "esriFieldTypeInteger",
#    "alias": "AGE_50_64",
#    "domain": null
#  }, {
#    "name": "AGE_65_UP",
#    "type": "esriFieldTypeInteger",
#    "alias": "AGE_65_UP",
#    "domain": null
#  }, {
#    "name": "MED_AGE",
#    "type": "esriFieldTypeDouble",
#    "alias": "MED_AGE",
#    "domain": null
#  }, {
#    "name": "MED_AGE_M",
#    "type": "esriFieldTypeDouble",
#    "alias": "MED_AGE_M",
#    "domain": null
#  }, {
#    "name": "MED_AGE_F",
#    "type": "esriFieldTypeDouble",
#    "alias": "MED_AGE_F",
#    "domain": null
#  }, {
#    "name": "HOUSEHOLDS",
#    "type": "esriFieldTypeInteger",
#    "alias": "HOUSEHOLDS",
#    "domain": null
#  }, {
#    "name": "AVE_HH_SZ",
#    "type": "esriFieldTypeDouble",
#    "alias": "AVE_HH_SZ",
#    "domain": null
#  }, {
#    "name": "HSEHLD_1_M",
#    "type": "esriFieldTypeInteger",
#    "alias": "HSEHLD_1_M",
#    "domain": null
#  }, {
#    "name": "HSEHLD_1_F",
#    "type": "esriFieldTypeInteger",
#    "alias": "HSEHLD_1_F",
#    "domain": null
#  }, {
#    "name": "MARHH_CHD",
#    "type": "esriFieldTypeInteger",
#    "alias": "MARHH_CHD",
#    "domain": null
#  }, {
#    "name": "MARHH_NO_C",
#    "type": "esriFieldTypeInteger",
#    "alias": "MARHH_NO_C",
#    "domain": null
#  }, {
#    "name": "MHH_CHILD",
#    "type": "esriFieldTypeInteger",
#    "alias": "MHH_CHILD",
#    "domain": null
#  }, {
#    "name": "FHH_CHILD",
#    "type": "esriFieldTypeInteger",
#    "alias": "FHH_CHILD",
#    "domain": null
#  }, {
#    "name": "FAMILIES",
#    "type": "esriFieldTypeInteger",
#    "alias": "FAMILIES",
#    "domain": null
#  }, {
#    "name": "AVE_FAM_SZ",
#    "type": "esriFieldTypeDouble",
#    "alias": "AVE_FAM_SZ",
#    "domain": null
#  }, {
#    "name": "HSE_UNITS",
#    "type": "esriFieldTypeInteger",
#    "alias": "HSE_UNITS",
#    "domain": null
#  }, {
#    "name": "VACANT",
#    "type": "esriFieldTypeInteger",
#    "alias": "VACANT",
#    "domain": null
#  }, {
#    "name": "OWNER_OCC",
#    "type": "esriFieldTypeInteger",
#    "alias": "OWNER_OCC",
#    "domain": null
#  }, {
#    "name": "RENTER_OCC",
#    "type": "esriFieldTypeInteger",
#    "alias": "RENTER_OCC",
#    "domain": null
#  }, {
#    "name": "NO_FARMS97",
#    "type": "esriFieldTypeDouble",
#    "alias": "NO_FARMS97",
#    "domain": null
#  }, {
#    "name": "AVG_SIZE97",
#    "type": "esriFieldTypeDouble",
#    "alias": "AVG_SIZE97",
#    "domain": null
#  }, {
#    "name": "CROP_ACR97",
#    "type": "esriFieldTypeDouble",
#    "alias": "CROP_ACR97",
#    "domain": null
#  }, {
#    "name": "AVG_SALE97",
#    "type": "esriFieldTypeDouble",
#    "alias": "AVG_SALE97",
#    "domain": null
#  }, {
#    "name": "SQMI",
#    "type": "esriFieldTypeDouble",
#    "alias": "SQMI",
#    "domain": null
#  }, {
#    "name": "Shape_Length",
#    "type": "esriFieldTypeDouble",
#    "alias": "Shape_Length",
#    "domain": null
#  }, {
#    "name": "Shape_Area",
#    "type": "esriFieldTypeDouble",
#    "alias": "Shape_Area",
#    "domain": null
#  }]

# %%
df_map = gis.map("Seattle, WA", zoomlevel=6)
df_map

# %%
df_map.add_layer(fl, {"definition_expression" : "STATE_NAME ='Washington'",
               "renderer":"ClassedColorRenderer",
               "field_name":"POP2007",
               "opacity":0.7
              })

# %%
df_map._webmap._webmapdict['operationalLayers'][0]['layerDefinition'].keys()
# Out:
# dict_keys(['definitionExpression', 'drawingInfo'])

# %%
df_map._process_smart_mapping()

# %%
df_map.extent

# %%
df_map.save("WM with def Expressions 2", "Webmap with definition queries", ['automation'])
# Out:
# <Item title:"WM with def Expressions 2" type:Web Map owner:arcgis_python>

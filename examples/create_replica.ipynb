# %%
from arcgis.lyr import *
from arcgis.gis import *

# %%
gis = GIS("Organization URL", "UserName", "Password")

# %%
fs = FeatureService(url = "URL to Feature Service",gis=gis)

# %%
if fs.properties.syncEnabled == False:
    print("Sync Not Enabled")

# %%
response = fs.replicas.create(replicaName='AllLayers', layers='0,1',dataFormat="filegdb")

# %%
import urllib
urllib.request.urlretrieve (response['responseUrl'], "c://temp//my.zip")

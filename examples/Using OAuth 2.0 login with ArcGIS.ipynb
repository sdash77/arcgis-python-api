# %% [markdown]
# ## Using OAuth 2.0 login with ArcGIS Online organizations
#
# The ArcGIS API for Python acts as a 'serverless native application' when using OAuth 2.0 authorization with ArcGIS.
#
# To be able to log in using OAuth 2.0, you need to follow the workflow described below:
# (This is using "Mobile and Native Named User Login" workflow described at
# https://developers.arcgis.com/documentation/core-concepts/security-and-authentication/mobile-and-native-user-logins/)

# %% [markdown]
# ## Obtaining a client id
#
# If you already have a client id, you can skip these steps and use the code below to log in to your GIS.
#
# The steps below show how a client id can be obtained by registering a new application with your GIS. Only one client id is required, so if your GIS has one already, you may use it instead of creating a new application.
#
# * Log into your web GIS (ArcGIS Online organization or ArcGIS Enterprise)
# * Go to Content tab
# * Click '+ Add Item > An Application' menu
# * Add an application:
#  * Type: Application
#  * Title: Python
#  * Tags: python
# * On the Item details page of this newly created application, navigate to Settings tab
# * Click the Registered Info button. It's towards the bottom of the page.
# * This will show an App ID. This is your client id and needs to be passed in as the client_id parameter when construcing a GIS object. You need this in your Python code to log in
#
# Then you can log in to your org using the Python API using the code shown below:

# %%
client_id = 'OGz1I2eoO8dO0ii2'

# %%
gis = GIS('https://deldev.maps.arcgis.com', client_id=client_id)
# Out:
# Please sign in to your GIS and paste the code that is obtained below.
# If a web browser does not automatically open, please navigate to the URL below yourself instead.
# Opening web browser to navigate to: https://deldev.maps.arcgis.com/sharing/rest/oauth2/authorize?expiration=-1&client_id=OGz1I2eoO8dO0ii2&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code
# Enter code obtained on signing in using SAML: ········

# %%
gis.users.me
# Out:
# <User username:deldev>

# %% [markdown]
# ## Using account credentials with SAML

# %%
gis = GIS('https://deldev.maps.arcgis.com', 'deldev', 'change-this-password', client_id=client_id)
# Out:
# Please sign in to your GIS and paste the code that is obtained below.
# If a web browser does not automatically open, please navigate to the URL below yourself instead.
# Opening web browser to navigate to: https://deldev.maps.arcgis.com/sharing/rest/oauth2/authorize?user_orgkey=&password=change-this-password&oauth_state=S63YNs3w8ctMcEh4Tgsjq8rhZZ6dlXtZ6morrzl1I0m6EbqY_5NN9qTWAiuul43Sg3GVcg_lQAc9S7ipuMYpH1nySWeaxbFGGNTFZOxtQgJo9dEcBXYiFvGg23YrmPcfj9Df7qbZb9I2B7H8iz9dYh-6hD6ZAtCpwr_KSFPdRX0.&username=deldev

# %%
gis.users.me
# Out:
# <User username:deldev>

# %%
enterprise_appid = 'rqmUdWtP7a0eZZBH'

# %%
enterprise = GIS('http://python.playground.esri.com/portal', client_id=enterprise_appid)
# Out:
# Please sign in to your GIS and paste the code that is obtained below.
# If a web browser does not automatically open, please navigate to the URL below yourself instead.
# Opening web browser to navigate to: http://python.playground.esri.com/portal/sharing/rest/oauth2/authorize?expiration=-1&client_id=rqmUdWtP7a0eZZBH&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code
# Enter code obtained on signing in using SAML: ········

# %%
enterprise.users.me
# Out:
# <User username:arcgis_python>

# %%
2+2
# Out:
# 4

# %%
4+4
# Out:
# 8

# %%
5+5
# Out:
# 10

# %%
from arcgis.gis import GIS
gis = GIS()
map = gis.map()
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-51f62cf0-187d-44f9-99ba-21e95dc30e61"><img src=""></img></div>

# %%
map.zoom=4

# %%
33+33
# Out:
# 66

# %%
2+2
# Out:
# 4

# %%
4+4
# Out:
# 8

# %%
5+5
# Out:
# 10

# %%
import time
time.sleep(15)

# %%
from arcgis.gis import GIS
gis = GIS()
map = gis.map()
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-5dc0d2a7-a53a-451d-848e-6ff50725ee9a"><img src="data:image/png;base64,..."></img></div>

# %%
15+15
# Out:
# 30

# %%
33+33
# Out:
# 66

# %%
from arcgis.gis import GIS
from arcgis.features import FeatureLayer
hurricane_layer = FeatureLayer(
    url="https://sampleserver6.arcgisonline.com/arcgis/rest/services/Hurricanes/MapServer/0")
gis = GIS()
hurricane_map = gis.map('Atlantic Ocean', 3)
hurricane_map.add_layer(hurricane_layer)
hurricane_map.add_layer(hurricane_layer)
hurricane_map.add_layer(hurricane_layer)
hurricane_map.add_layer(hurricane_layer)
hurricane_map.add_layer(hurricane_layer)
hurricane_map.add_layer(hurricane_layer)
hurricane_map.add_layer(hurricane_layer)
hurricane_map.add_layer(hurricane_layer)
hurricane_map
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=3.0)

# %%
hurricane_map.layers
# Out:
# [{'type': 'FeatureLayer',
#   'url': 'https://sampleserver6.arcgisonline.com/arcgis/rest/services/Hurricanes/MapServer/0',
#   'options': {},
#   '_hashFromPython': '-9223372036572604861'}]

# %%
hurricane_map.remove_layers(hurricane_map.layers[0])
# Out:
# True

# %%
hurricane_map.add_layer(hurricane_layer)

# %%
hurricane_map.remove_layers(hurricane_map.layers[0])
# Out:
# True

# %%
hurricane_map.add_layer(hurricane_layer)

# %%
hurricane_map.remove_layers()
# Out:
# True

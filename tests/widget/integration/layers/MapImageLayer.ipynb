# %%
from arcgis import *
from arcgis.mapping import MapImageLayer
gis = GIS()
postflood = MapImageLayer('https://tiles.arcgis.com/tiles/DO4gTjwJVIJ7O9Ca/arcgis/rest/services/Missouri_Flood_Imagery/MapServer')
location = 'Eureka High School, Eureka, MO 63025'
satmap1 = gis.map(location)
satmap1.add_layer(postflood)
satmap1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))

# %%
assert 'ArcGISTiledMapServiceLayer' == \
    satmap1._draw_these_notype_layers_on_widget_load[0]['type']

# %% [markdown]
# # SHOULD LOOK LIKE THIS
# <img src=" data:image/png;base64,...">

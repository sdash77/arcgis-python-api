# %%
from arcgis.gis import GIS
map = GIS().map()
map

# %%
import time
time.sleep(10)

# %%
f = display("ok", display_id="ok")
def handler(change):
    f.update("ok23333")
    map.take_screenshot();

map.observe(handler, names=["ready",])

# %%
# %%javascript
# console.log("Did this run?")

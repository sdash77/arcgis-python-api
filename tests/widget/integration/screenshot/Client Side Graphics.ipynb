# %%
import time
from arcgis.gis import GIS
from arcgis.features import SpatialDataFrame
from arcgis.geometry import Polygon, Point, Polyline
gis = GIS()
item = gis.content.get("85d0ca4ea1ca4b9abf0c51b9bd34de2e")
item
sdf = SpatialDataFrame.from_layer(item.layers[0])
wm = gis.map('North America', 3)
sdf.plot(kind='map', map_widget=wm)
wm
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=3.0)
# <div class="map-static-img-preview-9332ce38-0e87-45cc-875a-d400e74d10eb"><img src="data:image/png;base64,..."></img></div>

# %%
#2D mode doesn't work at the moment, so this behavior is expected
wm.take_screenshot()
# Out:
# <img src=data:image/png;base64,...></img>

# %% [markdown]
# ## 2D mode SeDF and client side graphics don't appear to be working as of Nov 2018, so this is the expected behavior
#
# <img src="data:image/png;base64,...">

# %%
import time
from arcgis.gis import GIS
from arcgis.features import SpatialDataFrame
from arcgis.geometry import Polygon, Point, Polyline
gis2 = GIS()
item2 = gis2.content.get("85d0ca4ea1ca4b9abf0c51b9bd34de2e")
item2
sdf2 = SpatialDataFrame.from_layer(item2.layers[0])
wm2 = gis.map('San Francisco', mode="3D")
sdf.plot(kind='map', map_widget=wm2)
wm2
# Out:
# MapView(layout=Layout(height='400px', width='100%'), mode='3D')
# <div class="map-static-img-preview-390be7a4-533e-4479-8845-bf53a6283179"><img src="data:image/jpeg;base64,..."></img></div>

# %%
wm2.take_screenshot()
# Out:
# <img src=data:image/jpeg;base64,...></img>

# %% [markdown]
# ## But 3D mode works OK, so this is what the above screenshot should look like:
#
# <img src="data:image/jpeg;base64,...">

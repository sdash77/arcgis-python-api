# %%
from arcgis.gis import GIS
g = GIS()
map = g.map()
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-0a0b37bd-cb4b-4f0c-8d9f-ed758e12d90c"><img src=""></img></div>

# %%
#RUN THESE CELLS ONE AT A TIME,
#DRAW ALL OF THESE SHAPES FOR EACH CELL
map.draw("circle")

# %%
map.draw("ellipse")

# %%
map.draw("polygon")

# %%
map.draw("polyline")

# %%
map.draw("multipoint")

# %%
map.draw("point")

# %%
map.draw("rectangle")

# %%
map.draw("triangle")

# %% [markdown]
# # SHAPES SHOULD LOOK LIKE THIS
# <img src=" data:image/png;base64,...">

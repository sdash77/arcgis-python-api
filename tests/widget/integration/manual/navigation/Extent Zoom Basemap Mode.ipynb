# %%
from arcgis.gis import GIS
gis = GIS()
m = gis.map("Elk Grove Village, IL", 13)
m.mode = "3D"
m.tilt = 50
m.heading = 87
m
# Out:
# MapView(heading=87.0, layout=Layout(height='400px', width='100%'), mode='3D', tilt=50.0, zoom=13.0)

# %% [markdown]
# # SHOULD LOOK LIKE THIS:
# <img src=" data:image/png;base64,...">

# %%
from arcgis.gis import GIS
gis = GIS()
m = gis.map("Elk Grove Village, IL", 13)
m.mode = "2D"
m.rotation = 180
m.zoom = 12
m
# Out:
# MapView(layout=Layout(height='400px', width='100%'), rotation=180.0, zoom=12.0)

# %% [markdown]
# # SHOULD LOOK LIKE THIS:
# <img src=" data:image/png;base64,...">

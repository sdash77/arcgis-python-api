# %%
from arcgis.gis import GIS
gis = GIS()
map = gis.map("Chicago, IL", 2)
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-b02846a4-6257-41db-a797-a2a1a3a63e84"><img src=""></img></div>

# %%
map.snap_to_zoom = False

# %%
map.scale = 24500

# %%
map.scale
# Out:
# 24500.0

# %%
map.zoom
# Out:
# 14.643106928330079

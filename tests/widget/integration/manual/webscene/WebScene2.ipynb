# %%
from arcgis.gis import GIS
from arcgis.mapping import WebScene
g = GIS()
webscene = WebScene(g.content.get('19dcff93eeb64f208d09d328656dd492'))
webscene
# Out:
# MapView(hide_mode_switch=True, layout=Layout(height='400px', width='100%'), mode='3D')

# %%
from arcgis.widgets import MapView
map = MapView(gis=g,item=g.content.get('19dcff93eeb64f208d09d328656dd492'),
             mode="3D")
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'), mode='3D')

# %%
map.extent
# Out:
# {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#  'xmin': -13657380.38923254,
#  'ymin': 5705948.899356349,
#  'xmax': -13657375.288966963,
#  'ymax': 5705952.238319081}

# %%
map.center
# Out:
# {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#  'x': -13657378.70761934,
#  'y': 5705945.16526826,
#  'z': 33.83574438653886}

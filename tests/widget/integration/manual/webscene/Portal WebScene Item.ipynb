# %%
from arcgis.gis import GIS
g = GIS()
webscene_item = g.content.get("421433baeb8d487b903d4a89df79149b")
from arcgis.mapping import WebScene
webscene = WebScene(webscene_item)
webscene
# Out:
# MapView(hide_mode_switch=True, layout=Layout(height='400px', width='100%'), mode='3D')

# %% [markdown]
# # INITIAL VIEW SHOULD BE LIKE THIS:
# Note that you should NOT see a 2D/3D switch button
#
# <img src=" data:image/png;base64,..." >
#
# ## And, upon navigation, you should be able to see elevation and click on  trails
#
# <img src=" data:image/png;base64,...">

# %%
g.users.me

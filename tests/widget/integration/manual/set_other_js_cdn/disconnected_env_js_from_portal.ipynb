# %%
#Run this command in your notebook when you are in a disconnected environment
#It should automatically use the JS API associated with that portal
from arcgis.gis import GIS
g = GIS("https://yourportal.com/portal", "username", "password")
g.map()

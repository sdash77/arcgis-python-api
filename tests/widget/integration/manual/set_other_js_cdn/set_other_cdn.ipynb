# %%
#NOTE: RUN THIS NOTEBOOK TEST IN A PRIVATE BROWSER WINDOW
#WITH A FRESH KERNEL/NOTEBOOK INSTANCE!
from arcgis.widgets import MapView
MapView.set_js_cdn('https://js.arcgis.com/4.7/')

# %%
from arcgis.gis import GIS
g = GIS()
g.map()
# Out:
# MapView(layout=Layout(height='400px', width='100%'))

# %% [markdown]
# # SHOULD LOOK LIKE THIS
# <img src=" data:image/png;base64,...">

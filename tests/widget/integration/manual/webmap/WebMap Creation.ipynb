# %%
from IPython.display import display
import arcgis
from arcgis.gis import GIS

# connect to your GIS
gis = GIS("https://www.arcgis.com","arcgis_python","amazing_arcgis_123")
webmap_search = gis.content.search("Ebola maps", item_type="Web Map")
webmap_search
ebola_map_item = webmap_search[1]
ebola_map_item
from arcgis.mapping import WebMap
empty_webmap = WebMap()
#ebola_map = WebMap(ebola_map_item)
#ebola_map
empty_webmap
# Out:
# MapView(layout=Layout(height='400px', width='100%'))

# %%
ebola_map.basemap = "national-geographic"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-7e0d99a427a6> in <module>()
# ----> 1 ebola_map.basemap = "national-geographic"
#
# AttributeError: can't set attribute

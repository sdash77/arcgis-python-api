# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # Widget test - Kubernetes portal - Consume web map shared to org
# Make a widget, load a web map with public and private layers

# %% [markdown]
# ######## change this cell to code and run this if you get login errors
#
# g = GIS('https://dev0014889.esri.com/gis/home/',
#         'siteadmin', 'esri.agp1', verify_cert=False,
#         profile='your_kubernetes_profile')

# %%
from arcgis.gis import GIS
from arcgis.mapping import WebMap

from IPython.display import Image
# Out:
# /Users/atma6951/Documents/code/geosurus/geosaurus/src/arcgis/geoprocessing/_job.py:377: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if value is "":

# %%
g = GIS(profile='your_kubernetes_profile', verify_cert=False)

# %%
try:
    wm_item = g.content.get('027a76c0b5e74c74a23094a9e40339a6')
except:
    wm_item=None

# %%
if wm_item:
    w = WebMap(wm_item)
else:
    w=None

# %%
w
# Out:
# MapView(hide_mode_switch=True, layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-d65750c4-a070-4a49-8086-e9f50935bf68"><img src="data:image/png;base64,..."></img></div>
# <div class="map-html-embed-preview-d65750c4-a070-4a49-8086-e9f50935bf68"></div>

# %%
w._mapview.take_screenshot(output_in_cell=True)
# Out:
# <img src=data:image/png;base64,...></img>

# %% [markdown]
# **Should look like below:**
# <img src="data:image/png;base64,...">

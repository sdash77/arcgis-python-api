# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#web-map-with-tile-layer" data-toc-modified-id="web-map-with-tile-layer-1">web map with tile layer</a></span></li></ul></div>

# %% [markdown]
# # Widget test - Kubernetes portal - Consume private web map
# Make a widget, load a web map with public and private layers

# %% [markdown]
# ######## change this cell to code and run this if you get login errors
#
# g = GIS('https://dev0014889.esri.com/gis/home/',
#         'siteadmin', 'esri.agp1', verify_cert=False,
#         profile='your_kubernetes_profile')

# %%
from arcgis.gis import GIS
from arcgis.mapping import WebMap

from IPython.display import Image

# %%
g = GIS(profile='your_kubernetes_profile', verify_cert=False)

# %%
try:
    wm_item = g.content.get('4e06e28e51ee4716b6b3d78c9b293002')
except:
    wm_item=None

# %%
if wm_item:
    w = WebMap(wm_item)
else:
    w=None

# %%
w
# Out:
# MapView(hide_mode_switch=True, layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-6ffb4dd2-90f3-404e-b873-076d41e230c3"><img src="data:image/png;base64,..."></img></div>
# <div class="map-html-embed-preview-6ffb4dd2-90f3-404e-b873-076d41e230c3"></div>

# %%
w._mapview.take_screenshot(output_in_cell=True)
# Out:
# <img src=data:image/png;base64,...></img>

# %% [markdown]
# **Should look like below:**
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### web map with tile layer

# %%
wm_tile_layer = g.content.get('fa9f656272984ffbbe5574e6d7d40752')
wm_tile_layer
# Out:
# <Item title:"webmap with tile layer" type:Web Map owner:siteadmin>

# %%
w_tile = WebMap(wm_tile_layer)
w_tile
# Out:
# MapView(hide_mode_switch=True, layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-51986878-fbcd-4a79-a7e4-ec452821a373"><img src=""></img></div>
# <div class="map-html-embed-preview-51986878-fbcd-4a79-a7e4-ec452821a373"></div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Get-Tile-and-Feature-layers" data-toc-modified-id="Get-Tile-and-Feature-layers-1">Get Tile and Feature layers</a></span></li><li><span><a href="#Consume-feature-layers" data-toc-modified-id="Consume-feature-layers-2">Consume feature layers</a></span></li><li><span><a href="#Consume-tile-layer" data-toc-modified-id="Consume-tile-layer-3">Consume tile layer</a></span></li></ul></div>

# %% [markdown]
# # Tests if you can consume private Hosted Tile and Feature layers from a Kubernetes portal

# %% [markdown]
# ######## change this cell to code and run this if you get login errors
#
# g = GIS('https://dev0014889.esri.com/gis/home/',
#         'siteadmin', 'esri.agp1', verify_cert=False,
#         profile='your_kubernetes_profile')

# %%
from arcgis.gis import GIS
from datetime import datetime
import time

# %%
anon_gis = GIS()
gis = GIS(profile='your_kubernetes_profile', verify_cert=False)

# %%
timestamp = datetime.now().strftime('%Y%m%dT%H%M%S')
timestamp
# Out:
# '20210226T153128'

# %% [markdown]
# ## Get Tile and Feature layers

# %%
tile_item = gis.content.get('a59e31e2d09e447eae091e6f46a69963')
tile_item
# Out:
# <Item title:"equakes_tilepkg" type:Map Image Layer owner:siteadmin>

# %%
flayer_item = gis.content.get('d4f66574f26041c695211a9f11a4faf2')
flayer_item
# Out:
# <Item title:"equakes_flayer" type:Feature Layer Collection owner:siteadmin>

# %%
flayer= flayer_item.layers[0]
flayer
# Out:
# <FeatureLayer url:"https://dev0014889.esri.com/gis/rest/services/Hosted/equakes_flayer/FeatureServer/0">

# %%
tile_layer_public = anon_gis.content.get('d77abcdc3f04488f84ad22bc7afdfcad')
tile_layer_public
# Out:
# <Item title:"Landfall density 2" type:Map Image Layer owner:amani_geosaurus>

# %% [markdown]
# ## Consume feature layers

# %%
feature_map = gis.map('Nevada, USA')
feature_map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-738a82e2-c237-4baa-952b-30e096ba8297"><img src=""></img></div>
# <div class="map-html-embed-preview-738a82e2-c237-4baa-952b-30e096ba8297"></div>

# %%
feature_map.add_layer(flayer)

# %% [markdown]
# ## Consume tile layer

# %%
tile_map = gis.map('Nevada, USA')
tile_map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-658a31bf-6f43-4c94-9a23-d28048313c4b"><img src=""></img></div>
# <div class="map-html-embed-preview-658a31bf-6f43-4c94-9a23-d28048313c4b"></div>

# %%
tile_map.add_layer(tile_item)
# Out:
# Item.layers is a 'NoneType' object: nothing to be added to map
# 'PropertyMap' instance has no attribute 'tables'
# 'PropertyMap' instance has no attribute 'tables'

# %%
tile_item.type
# Out:
# 'Map Service'

# %%
tile_item.url
# Out:
# 'https://dev0014889.esri.com/gis/rest/services/Hosted/equakes_tilepkg/MapServer'

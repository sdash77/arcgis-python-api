# %%
# --------------
# TEST WMS LAYER
# --------------
from arcgis.gis import GIS
from arcgis.mapping.ogc import WMSLayer
gis = GIS(profile="DavidJVitale")
map1 = gis.map()
wms_layer = WMSLayer("https://ows.terrestris.de/osm/service")
wms_layer2 = WMSLayer("http://wms.chartbundle.com/wms")
map1.add_layer(wms_layer)
map1.add_layer(wms_layer2)
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-85cfa413-fc46-49ea-af2d-90356a8ca4e4"><img src=""></img></div>

# %% [markdown]
# ### Should look like this:
# <img src="data:image/png;base64,..."></img>

# %%
# ASSERT THAT THE SAVED WEBMAP HAS BOTH OF THE WMS LAYERS ON IT
map1.save({"title": "My two WMS layers",
           "snippet": "Adsf",
           "tags":["1","2"]})
# Out:
# <Item title:"My two WMS layers2" type:Web Map owner:DavidJVitale>

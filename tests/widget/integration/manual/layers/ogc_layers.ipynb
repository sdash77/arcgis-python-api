# %%
from arcgis.gis import GIS
gis = GIS(profile="DavidJVitale")
map1 = gis.map()
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-0c1e0a8d-8dfb-4883-988b-7a5e1c8a748c"><img src=""></img></div>

# %%
from arcgis.mapping.ogc import WMSLayer
wms_layer = WMSLayer("http://wms.chartbundle.com/wms")
map1.add_layer(wms_layer)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-5a320d1f802f> in <module>
#       1 from arcgis.mapping.ogc import WMSLayer
#       2 wms_layer = WMSLayer("http://wms.chartbundle.com/wms")
# ----> 3 map1.add_layer(wms_layer)
#
# ~/devel/geofork/src/arcgis/widgets/_mapview/_mapview.py in add_layer(self, item, options)
#    1051              _is_geoenabled(item):
#    1052             item = item.spatial.to_feature_collection()
# -> 1053         self._add_layer_to_widget(item, options)
#    1054
#    1055     def _add_layer_to_webmap(self, item, options):
#
# ~/devel/geofork/src/arcgis/widgets/_mapview/_mapview.py in _add_layer_to_widget(self, item, options)
#    1153                     self._add_layer_to_widget(item_, options)
#    1154         else:
# -> 1155             raise RuntimeError("Cannot infer layer: will not be added to map")
#    1156
#    1157     def _add_notype_layer(self, item, lyr_json):
#
# RuntimeError: Cannot infer layer: will not be added to map

# %%
wms_layer = gis.content.search("*", item_type="WMS", max_items=50)[2]
wms_layer

# %%
wm_data = gis.content.get("1168624d041b47af91783d970c2a1448").get_data()
layer = wm_data['operationalLayers'][0]
layer

# %%
layer["url"]

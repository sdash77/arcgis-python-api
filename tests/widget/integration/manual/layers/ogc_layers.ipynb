# %%
# --------------
# TEST WMS LAYER
# --------------
from arcgis.gis import GIS
from arcgis.mapping.ogc import *
gis = GIS(profile="DavidJVitale")
map1 = gis.map()
wms_layer2 = WMSLayer("http://wms.chartbundle.com/wms")
map1.add_layer(wms_layer2)
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-08c4731d-8fb0-4fd0-b491-c881c1e57715"><img src=""></img></div>

# %% [markdown]
# ### Should look like this:
# <img src="data:image/png;base64,..."></img>

# %%
# ASSERT THAT THE SAVED WEBMAP HAS BOTH OF THE WMS LAYERS ON IT
map1.save({"title": "WMS Layer from MapView",
           "snippet": "Adsf",
           "tags":["1","2"]})

# %%
wmts_layer.properties
# Out:
# {
#   "html": {
#     "head": "",
#     "body": ""
#   }
# }

# %%
# --------------
# TEST WMTS LAYER
# --------------
map2 = gis.map()
wmts_layer = WMTSLayer("https://wayback.maptiles.arcgis.com/arcgis/rest/services/World_Imagery/WMTS/1.0.0/default028mm/MapServer/tile/8249/{level}/{row}/{col}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f989d98365fb> in <module>
#       4 map2 = gis.map()
#       5 wmts_layer = WMTSLayer("https://gibs.earthdata.nasa.gov/wmts/epsg4326/best")
# ----> 6 map2.add_layer(wmts_layer)
#       7 map2
#
# ~/devel/geofork/src/arcgis/widgets/_mapview/_mapview.py in add_layer(self, item, options)
#    1051              _is_geoenabled(item):
#    1052             item = item.spatial.to_feature_collection()
# -> 1053         self._add_layer_to_widget(item, options)
#    1054
#    1055     def _add_layer_to_webmap(self, item, options):
#
# ~/devel/geofork/src/arcgis/widgets/_mapview/_mapview.py in _add_layer_to_widget(self, item, options)
#    1146                     self._add_notype_layer(item, item)
#    1147         elif isinstance(item, BaseOGC):
# -> 1148             self._add_layer_to_webmap(item, options)
# ...

# %%
map2.save({"title": "WMTS Layer from MapView",
           "snippet": "Adsf",
           "tags":["1","2"]})
# Out:
# <Item title:"WMTS Layer from MapView" type:Web Map owner:DavidJVitale>

# %%
for item in gis.content.search("*",item_type="WMTS", outside_org=True):
    display(item)
# Out:
# <Item title:"2017 LARIAC Pict." type:WMTS owner:RRodriguez3@isd.lacounty.gov_lacounty>
# <Item title:"World Imagery (Wayback 2018-06-06)" type:WMTS owner:esri_imagery>
# <Item title:"基準点・測地観測_干渉SAR_火山_口永良部島_2009/01/16～2009/03/03_AR（地理院タイル）" type:WMTS owner:Esri_JP_Content>
# <Item title:"基準点・測地観測_干渉SAR_地盤沈下_大阪平野_2008/02/26～2010/10/19_AR（地理院タイル）" type:WMTS owner:Esri_JP_Content>
# <Item title:"基準点・測地観測 干渉SAR だいち2号（ALOS-2）  火山 択捉阿登佐岳 2014/11/07～2015/02/27 AR（地理院タイル）" type:WMTS owner:Esri_JP_Content>
# <Item title:"基準点・測地観測_干渉SAR_火山_岩木山_2007/10/02～2010/05/25_DR（地理院タイル）" type:WMTS owner:Esri_JP_Content>
# <Item title:"基準点・測地観測_干渉SAR_火山_阿蘇山_2010/03/02～2010/04/17_DR（地理院タイル）" type:WMTS owner:Esri_JP_Content>
# <Item title:"基準点・測地観測_干渉SAR_火山_伊豆大島_2007/01/28～2009/08/05_DR（地理院タイル）" type:WMTS owner:Esri_JP_Content>
# <Item title:"基準点・測地観測 干渉SAR だいち2号（ALOS-2）  火山 西之島 2017/09/11～2017/12/04 DR（地理院タイル）" type:WMTS owner:Esri_JP_Content>
# ...

# %%
map2.webmap._webmapdict['operationalLayers'][0]['tileInfo']['lods']

# %%
wmts_webmap_item = gis.content.get("8bbde908ecc742419006e9c2d61ad768")
wm_data = wmts_webmap_item.get_data()
del wm_data['operationalLayers'][0]['itemId']

# %%
wmts_webmap_item.update(wm_data)

# %%
wmts_webmap_item

# %%
from ipywidgets import HBox
HBox([wm_data['operationalLayers'][0], map2.webmap._webmapdict['operationalLayers'][0]])

# %%
item = gis.content.search

# %%
type(wm._webmapdict['operationalLayers'][0]['extent'][0][0])

# %%
wmts_layer._type

# %%
items= gis.content.search("*", item_type="WMTS", outside_org=True)
for item in items:
    display(item)

# %%
item2 = items[1]
item2

# %%
from arcgis.mapping.ogc import *

# %%
item1 = items[1]
item1

# %%
from arcgis.mapping import WebMap

wm = WebMap()
wms_layer = WMSLayer("https://ows.terrestris.de/osm/service")
wm.add_layer(wms_layer)
wm.save({"title": "WMS Layer from WebMap",
           "snippet": "Adsf",
           "tags":["1","2"]})

# %%
item1.url

# %%
wmts_wm_mapviewer = gis.content.get("8bbde908ecc742419006e9c2d61ad768")
wm_data = wmts_wm_mapviewer.get_data()
from_wm = wm_data['operationalLayers'][0]
from_wm

# %%
wmts_layer.properties

# %%
wmts_layer.__text__

# %%
from_wm

# %%
wmts_layer.properties.Capabilities.Contents.TileMatrixSet[0].TileMatrix

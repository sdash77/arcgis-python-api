# %%
# Test in memory dictionary, no specified renderer
from arcgis.gis import GIS
from arcgis.mapping.ogc import GeoJSONLayer
gis = GIS()

map5 = gis.map("Singapore")
data = {
    "type": "FeatureCollection",
    "features": [
      {
        "type": "Feature",
        "geometry": {
          "type": "Polygon",
          "coordinates": [
            [
              [100.0, 0.0],
              [101.0, 0.0],
              [101.0, 1.0],
              [100.0, 1.0],
              [100.0, 0.0]
            ]
          ]
        },
      }
    ]
  }
map5.extent = {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
 'xmin': 10962109.197477657,
 'ymin': -61801.93569151109,
 'xmax': 11442745.23133482,
 'ymax': 182796.55482104077}
geojson_layer = GeoJSONLayer(data=data)
map5.add_layer(geojson_layer)
map5
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-2797b3bc-0117-4c45-94fe-a7d18fc0843f"><img src=""></img></div>
# <div class="map-html-embed-preview-2797b3bc-0117-4c45-94fe-a7d18fc0843f"></div>

# %% [markdown]
# ### Should look like this:
# <img src="data:image/png;base64,..."/>

# %%
# Test a large local geojson file with specified renderer
from arcgis.gis import GIS
from arcgis.mapping.ogc import GeoJSONLayer
from arcgis.mapping import generate_renderer
gis = GIS()
map6 = gis.map("Cottonwood Pass, CA")
map6.extent = {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
 'xmin': -13174663.498939022,
 'ymin': 4355488.778540364,
 'xmax': -13144623.74682299,
 'ymax': 4370776.184197377}
geojson_layer = GeoJSONLayer(
    data="./data/hike.geojson",
    renderer=generate_renderer("polyline", colors="brg", cstep=100))
map6.add_layer(geojson_layer)
map6
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-2e2b1494-50d2-41eb-b2b6-ab19d05cce23"><img src=""></img></div>
# <div class="map-html-embed-preview-2e2b1494-50d2-41eb-b2b6-ab19d05cce23"></div>

# %% [markdown]
# ### Should look like this:
# <img src="data:image/png;base64,..."/>

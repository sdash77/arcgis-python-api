# %%
from arcgis.gis import GIS
gis = GIS()
landsat_item = gis.content.get("d9b466d6a9e647ce8d1dd5fe12eb434b")
landsat = landsat_item.layers[0]
landsat_item
prefire = landsat.filter_by('OBJECTID=668630') # 2017-11-23 
midfire = landsat.filter_by('OBJECTID=681950') # 2017-12-09 
no_mosaic = { 'type': 'ImageryLayer',
 'url': 'http://landsat2.arcgis.com/arcgis/rest/services/Landsat/MS/ImageServer',
 'uses_gbl': False }

# %%
landsat_item.id
# Out:
# 'd9b466d6a9e647ce8d1dd5fe12eb434b'

# %%
map1 = gis.map("los angeles")
map1.add_layer(no_mosaic)
map1.extent = {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
 'xmin': -13469299.238570858,
 'ymin': 4041672.8742652563,
 'xmax': -13281569.897102557,
 'ymax': 4163972.119521479}
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-595de52e-0f03-407d-bbac-f6f580442829"><img src=""></img></div>

# %%
map2 = gis.map("santa maria")
map2.add_layer(midfire)
map2.extent = {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
 'xmin': -13469299.238570858,
 'ymin': 4041672.8742652563,
 'xmax': -13281569.897102557,
 'ymax': 4163972.119521479}
map2
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-b4225242-b5de-403c-9521-e2c63b0e1e69"><img src=""></img></div>

# %%
# SHOULD LOOK LIKE THIS. Both live maps should be different
# Out:
# <img src=data:image/jpeg;base64,...></img>

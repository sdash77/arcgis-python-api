# %%
from arcgis.gis import GIS
gis = GIS()
map1 = gis.map("India")
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-667d763c-5309-48d5-8e53-bb284f1760d5"><img src="data:image/png;base64,..."></img></div>

# %%
# WAIT FOR MAP TO LOAD
map1.take_screenshot()
# Out:
# <img src=data:image/png;base64,...></img>

# %% [markdown]
# # STATIC IMAGE SCREENSHOT SHOULD LOOK LIKE THIS:
#
# <img src="data:image/png;base64,...">

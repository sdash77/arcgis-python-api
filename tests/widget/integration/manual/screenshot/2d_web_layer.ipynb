# %%
from arcgis.gis import *
gis = GIS()
map = gis.map("USA", 4)
item = gis.content.get('2158ce05955d4c529636b9fa0943193f')
layer = item.layers[0]
map.add_layer(layer, {"renderer" : "ClassedColorRenderer",
                       "field_name" : "TOTPOP10",
                       "opacity": 0.7})
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=4.0)
# <div class="map-static-img-preview-7a4e2cf6-0c71-447f-941f-f3155dac91e1"><img src="data:image/png;base64,..."></img></div>

# %%
map.take_screenshot()
# Out:
# <img src=data:image/png;base64,...></img>

# %% [markdown]
# # SCREENSHOT SHOULD LOOK LIKE THIS:
# <img src="data:image/png;base64,...">

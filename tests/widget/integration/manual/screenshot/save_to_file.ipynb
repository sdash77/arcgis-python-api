# %%
from arcgis.gis import GIS
gis = GIS("https://pythonapi.playground.esri.com/portal",
          "arcgis_python", "amazing_arcgis_123")
map = gis.map("Australia")
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-756fdafd-152d-48fe-8037-716ce64ec2d5"><img src=""></img></div>

# %%
map.take_screenshot(output_in_cell=False, set_as_preview=False,
                   file_path="./australia_test.png")

# %%
# !ls -la .
# Out:
# total 10088
# drwxr-xr-x   9 davi9349  1968095660      288 Nov 20 15:29 .
# drwxr-xr-x  19 davi9349  1968095660      608 Nov 19 17:34 ..
# drwxr-xr-x   6 davi9349  1968095660      192 Nov 20 15:25 .ipynb_checkpoints
# -rw-r--r--@  1 davi9349  1968095660   499274 Nov 20 15:23 HTML_Previews.html
# -rw-r--r--   1 davi9349  1968095660   225933 Nov 20 15:25 HTML_Previews.ipynb
# -rw-r--r--   1 davi9349  1968095660   255129 Nov 20 15:29 australia_test.png
# -rw-r--r--   1 davi9349  1968095660  2629705 Nov 20 15:12 print_service_url_test.ipynb
# -rw-r--r--   1 davi9349  1968095660     1816 Nov 20 15:29 save_to_file.ipynb
# -rw-r--r--   1 davi9349  1968095660  1537642 Nov 20 14:58 take_screenshot No Args.ipynb

# %%
# OPEN THE FILE AND ASSERT YOU SEE AUSTRALIA

# %%
from arcgis.gis import GIS
gis = GIS()
map = gis.map("Iceland")
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-8b7ebd68-cd40-4e19-90c4-33a30da96d9f"><img src="data:image/png;base64,..."></img></div>

# %%
# Wait a bit for this to finish
map.take_screenshot(output_in_cell=False, set_as_preview=True)

# %%
# NOW SAVE THE NOTEBOOK, AND EXPORT AS HTML. IT SHOULD EXPORT A FILE
# WITH THE NAME "HTML_PREVIEWS.html" OPEN THAT FILE AND ASSERT THERE 
# IS A STATICE ICELAND PREVIEW IMAGE

# %%
# Now, copy the downloaded file to this dir
# !cp /Users/davi9349/Downloads/HTML_Previews.html /Users/davi9349/devel/geofork/tests/widget/integration/screenshot/

# %%
# Then, display the HTML in a javascriptless iframe, mimicing the DSX
# preview frame (i.e. asserting it's a pure HTML preview)

# %%
html_file_html_path = "./HTML_Previews.html"
from IPython.display import HTML, IFrame
HTML(f'<iframe src="{html_file_html_path}" sandbox=""></iframe>')
# Out:
# <iframe src="./HTML_Previews.html" sandbox=""></iframe>

# %%
# IMAGE SHOULD BE DISPLAYABLE IN THE ABOVE IFRAME

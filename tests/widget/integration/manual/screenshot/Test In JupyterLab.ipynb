# %%
from arcgis.gis import GIS
gis = GIS()
map = gis.map()
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-37f0f667-6f60-4f83-b08b-605121439fee"><img src="data:image/png;base64,..."></img></div>

# %%
map.take_screenshot()
# Out:
# <img src=data:image/png;base64,...></img>

# %%
#Tests that Item from different portals can be drawn on the same map with add_layer
from arcgis.gis import GIS
g = GIS("https://python.playground.esri.com/portal",
        "arcgis_python",
        "amazing_arcgis_123")
map = g.map("Los Angeles")
item_from_portal = g.groups.search('LA County Emergency Management')[0].content()[1]
map.add_layer(item_from_portal.layers[0])
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-23e9c90a-cc66-4dea-952e-367d4946fbec"><img src=""></img></div>

# %%
map
# Out:
# MapView(jupyter_target='notebook', layout=Layout(height='400px', width='100%'), ready=True, zoom=10.0)
# <div class="map-static-img-preview-23e9c90a-cc66-4dea-952e-367d4946fbec"><img src=""></img></div>

# %%
map
# Out:
# MapView(jupyter_target='notebook', layout=Layout(height='400px', width='100%'), ready=True, zoom=10.0)
# <div class="map-static-img-preview-23e9c90a-cc66-4dea-952e-367d4946fbec"><img src=""></img></div>

# %% [markdown]
# # SHOULD NOT HAVE AN ERROR ABOUT AUTHENTICATING TO PORTAL

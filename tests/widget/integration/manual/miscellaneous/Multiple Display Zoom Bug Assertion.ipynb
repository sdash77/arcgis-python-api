# %%
# ALL MAPS SHOULD BE OF SAN FRANCISCO, NOT THE WORLD
import arcgis
from arcgis.gis import GIS

gis = GIS("https://www.arcgis.com", "arcgis_python", "P@ssword123")

m1 = gis.map("San Francisco", zoomlevel=17)
m1
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=17.0)
# <div class="map-static-img-preview-ba8f0c41-5df3-4702-8f13-0ae2eefc4a0f"><img src=""></img></div>

# %%
m2 = gis.map("San Francisco", zoomlevel=17)
m2
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=17.0)
# <div class="map-static-img-preview-9d7558cc-5aca-42f9-bbfb-1357322c05e5"><img src=""></img></div>

# %%
m3 = gis.map("San Francisco", zoomlevel=17)
m3
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=17.0)
# <div class="map-static-img-preview-6e29ef46-1aac-425a-8c4c-1b5cc663c577"><img src=""></img></div>

# %%
m4 = gis.map("San Francisco", zoomlevel=17)
m4
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=17.0)
# <div class="map-static-img-preview-c2cc18bf-8393-4555-a882-bbe577acbb68"><img src=""></img></div>

# %%
m5 = gis.map("San Francisco", zoomlevel=17)
m5
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=17.0)
# <div class="map-static-img-preview-55423d17-f437-4be5-92f4-c0933a340a00"><img src=""></img></div>

# %%
#RUN THIS CELL, DON'T HAVE YOUR MOUSE RUN OVER THE MAP
from arcgis.gis import GIS
g = GIS()
map = g.map()
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))

# %%
assert map.extent

# %%
assert map.center

# %%
from arcgis.gis import GIS
gis = GIS()
map = gis.map("San Francisco") #notice the no 'zoomlevel' param
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-289a0be7-70d3-488e-ad13-3f574f8d6f3b"><img src="data:image/jpeg;base64,..."></img></div>

# %%
map.take_screenshot()
# Out:
# <img src=data:image/jpeg;base64,...></img>

# %% [markdown]
# # SHOULD LOOK LIKE THIS
#
# <img src='data:image/jpeg;base64,...'>

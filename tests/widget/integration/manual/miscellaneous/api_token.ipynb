# %%
from arcgis.gis import GIS
anon_gis = GIS()
cred_gis = GIS(profile="widget_test_publisher_credentials")

# %%
# SHOULD BE AN OSM MAP
anon_gis_map = anon_gis.map()
anon_gis_map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-7456b387-e7ad-4ce7-86ea-daec9db0e173"><img src=""></img></div>

# %%
# SHOULD BE DEFAULT ESRI BASEMAP
cred_gis_map = cred_gis.map()
cred_gis_map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-f9a19b98-c81b-431d-8915-0915b8d5109c"><img src=""></img></div>

# %%
cred_gis._portal.con.token

# %%
anon_gis._portal.con.token

# %%
anon_gis_map.gis

# %%
#NOTE THIS ONLY WORKS IN JUPYTERLAB AT THE MOMENT
from arcgis.gis import *
gis = GIS()
map = gis.map("Los Angeles", 7)
map.add_layer({"type":"FeatureLayer",
                "url":"http://services1.arcgis.com/hLJbHVT9ZrDIzK0I/arcgis/rest/services/EQMagGt4/FeatureServer/0",
                "renderer":"HeatmapRenderer",
                "opacity":0.75})
map
# Out:
# MapView(layout=Layout(height='500px', width='100%'), zoom=7.0)

# %% [markdown]
# # SHOULD LOOK LIKE THIS
# in Jupyterlab only...
#
# <img src=" data:image/png;base64,...">

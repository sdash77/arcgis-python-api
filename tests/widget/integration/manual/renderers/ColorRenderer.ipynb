# %%
from arcgis.gis import *
gis = GIS()
map = gis.map("USA", 4)
item = gis.content.get('2158ce05955d4c529636b9fa0943193f')
layer = item.layers[0]
map.add_layer(layer, {"renderer" : "ClassedColorRenderer",
                       "field_name" : "TOTPOP10",
                       "opacity": 0.7})
map
# Out:
# MapView(layout=Layout(height='500px', width='100%'), zoom=4.0)

# %% [markdown]
# # SHOULD LOOK LIKE THIS
#
# <img src=" data:image/png;base64,...">

# %%
map.export_to_html("/Users/davi9349/beta17test.html")
# Out:
# True

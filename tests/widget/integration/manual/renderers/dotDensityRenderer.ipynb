# %%
from arcgis.gis import GIS
gis = GIS()
map = gis.map()
map.basemap = 'dark-gray'
map.extent = {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
 'xmin': -13286534.444007466,
 'ymin': 4020765.509787753,
 'xmax': -13098805.102539165,
 'ymax': 4143064.755043976}
from arcgis.features import FeatureLayer
fl = FeatureLayer("http://sampleserver6.arcgisonline.com/arcgis/rest/services/Census/MapServer/3")
map.add_layer(fl, {'renderer': 'dotDensity',
 'attributes': [{'color': [255, 0, 0, 255],
   'field': 'AGE_18_21',
   'label': 'Age 18-21'}],
 'backgroundColor': [0, 0, 0, 0],
 'blendDots': False,
 'dotShape': 'square',
 'dotSize': 1,
 'legendOptions': {'unit': 'Children'},
 'outline': {'type': 'esriSLS',
  'color': [0, 0, 0, 255],
  'width': 0.75,
  'style': 'esriSLSSolid'},
 'referenceDotValue': 100,
 'referenceScale': 577790,
 'seed': 1})
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-e89e8641-5374-440c-ac33-8ec89c2b4a08"><img src=""></img></div>

# %% [markdown]
# ## SHOULD LOOK LIKE THIS:
# <img src=" data:image/png;base64,...">

# %%
renderer_esri_json = map._readonly_webmap_from_js['layers'][0]['renderer']
print(renderer_esri_json)
assert renderer_esri_json['type'] == 'dotDensity'
assert renderer_esri_json['outline']['type'] == 'esriSLS'
# Out:
# {'type': 'dotDensity', 'attributes': [{'color': [255, 0, 0, 255], 'field': 'AGE_18_21', 'label': 'Age 18-21'}], 'backgroundColor': [0, 0, 0, 0], 'blendDots': False, 'dotShape': 'square', 'dotSize': 1, 'legendOptions': {'unit': 'Children'}, 'outline': {'type': 'esriSLS', 'color': [0, 0, 0, 255], 'width': 0.75, 'style': 'esriSLSSolid'}, 'referenceDotValue': 100, 'referenceScale': 577790, 'seed': 1}

# %%
#Yes, this test is different from the previous notebook
#The ordering can matter
from arcgis.gis import GIS
g = GIS(profile="widget_test_publisher_credentials")
map = g.map()
map.mode = "3D"
map.basemap="national-geographic"
map.add_layer(g.content.get('bbf5a6899824407697e114556c213139'))
map
# Out:
# MapView(basemap='national-geographic', layout=Layout(height='400px', width='100%'), mode='3D')

# %%
import datetime
new_item = map.save({'title':'saved webscene {}'.format(datetime.datetime.now()),
                             'snippet':'testing new webscene',
                             'tags':'test'})
new_item
# Out:
# <Item title:"saved webscene 2018-08-07 17:12:26.988892" type:Web Scene owner:DavidJVitale>

# %%
map.mode = "2D"

# %%
import datetime
new_item = map.save({'title':'saved webmap {}'.format(datetime.datetime.now()),
                             'snippet':'testing new webscene',
                             'tags':'test'}, mode="2D")
new_item
# Out:
# <Item title:"saved webmap 2018-08-07 17:12:31.724051" type:Web Map owner:DavidJVitale>

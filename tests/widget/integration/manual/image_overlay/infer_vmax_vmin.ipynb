# %%
from arcgis.gis import GIS
from arcgis.raster import Raster
gis = GIS()
map = gis.map()
map.extent = {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
 'xmin': -12229049.7557831,
 'ymin': 3847153.358627922,
 'xmax': -12224344.101229168,
 'ymax': 3849064.284335102}
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-ea6cf731-7fbf-4c9e-9b87-771367126401"><img src=""></img></div>
# <div class="map-html-embed-preview-ea6cf731-7fbf-4c9e-9b87-771367126401"></div>

# %%
raster = Raster("./data/forest_hgt.tif")
assert int(raster.vmin) == -4
assert int(raster.vmax) == 46
map.add_layer(raster)
# Out:
# C:\Users\davi9349\AppData\Local\ESRI\conda\envs\geosaurus_pro_dev_env\lib\site-packages\matplotlib\colors.py:578: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N

# %% [markdown]
# ### Should look like this
#
# <img src="data:image/png;base64,..."/>

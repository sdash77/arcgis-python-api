# %%
#THIS MAP GETS A SINGLE PRIVATE POINT FROM THE GEOSAURUS.MAPS.ARCGIS GROUP
#RUN THE CELLS, OPEN THE HTML, ENTER CREDNETIALS, ASSERT MAP DRAWS
from arcgis.gis import GIS
g = GIS(profile="widget_test_publisher_credentials")
item_from_agol = g.content.get('e9226259f8c341da8aa5629951a680fe')
m = g.map()
m.add_layer(item_from_agol)
m.hide_mode_switch = True
m
# Out:
# MapView(hide_mode_switch=True, layout=Layout(height='400px', width='100%'))

# %%
m.export_to_html('/Users/davi9349/privatelayertest.html',
                  credentials_prompt=True)
# Out:
# True

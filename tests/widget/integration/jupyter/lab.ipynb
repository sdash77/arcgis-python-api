# %%
#ASSERT 2 MAPS ARE DRAWN IN NEW WINDOWS
#Move them around, make sure the 'new window' UI button works

from arcgis.gis import GIS
from arcgis.widgets import MapView
from arcgis.mapping import WebScene
g = GIS()
webscenes = g.content.search("*", item_type="Web Scene",
                              max_items=3)
map = g.map()
map.toggle_window_view(title="Hello World!",
                       tab_mode="split-bottom")
webscene_item = g.content.get("421433baeb8d487b903d4a89df79149b")
from arcgis.mapping import WebScene
webscene = WebScene(webscene_item)
webscene
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# MapView(hide_mode_switch=True, layout=Layout(height='400px', width='100%'), mode='3D')

# %%
#All maps should display individually
from arcgis.gis import GIS
g = GIS()
map1 = g.map()

# %%
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))

# %%
map2 = g.map()
map2
# Out:
# MapView(layout=Layout(height='400px', width='100%'))

# %%
map1.center = [0,0]

# %%
map2.center = [4,5]

# %%
map1.basemap = "national-geographic"

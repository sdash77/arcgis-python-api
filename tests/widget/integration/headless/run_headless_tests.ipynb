# %%
#EACH CELL WILL RUN THE SCRIPT WITHOUT JUPYTER BEING INVOLVED
#FOLLOW THE INSTRUCTIONS FOR EACH CELL TO ASSERT THAT IT IS WORKING
from _common import run_shell_command

# %%
#Will throw exception on error, print out a url on pass
#If a url is printed out, see if the url has a functional webmap
url = str(run_shell_command('python save_webmap.py')).strip("\n")
print(url)
# Out:
# https://arcgis.com/home/item.html?id=06c4643965084aeeadea0bcfbc3c5b18

# %%
#Should properly export 'exported.html': open in a web browser and assert
str(run_shell_command('python export_html.py'))
# Out:
# './exported.html successfully written\n'

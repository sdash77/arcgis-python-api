# %% [markdown]
# # AWS IoT Feed creation

# %% [markdown]
# ## Connect to a Velocity instance
# For this example, we will connect to `a4iot-dev`

# %%
from arcgis import GIS
from arcgis.realtime.velocity.feeds_manager import Feed

gis = GIS(
    url="https://devext.arcgis.com",
    username="pythontest_a4iot",
    password="v3locity.pyth0n",
)

velocity = gis.velocity

feeds = gis.velocity.feeds
feeds

# %% [markdown]
# ## Configure the AWS IoT Feed
# Configuring a delimited format feed that contains location, time, track id and info about satellite locations.

# %%
from arcgis.realtime.velocity.feeds import AWSIoT
from arcgis.realtime.velocity.feeds.geometry import XYZGeometry, SingleFieldGeometry
from arcgis.realtime.velocity.feeds.time import TimeInterval, TimeInstant

# AWS IoT Properties
name = "aws_feed_1"
description = "some description about the AWS feed"

aws_config = AWSIoT(
    label=name,
    description=description,
    endpoint="ah2hhrmykvalt-ats.iot.us-west-1.amazonaws.com",
    topic="aws/things/+",
    qos_level=0,
    access_key_id="AKIAYTUXJDCLWR773XNR",
    secret_access_key="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",
    data_format=None
)



# # all properties can also be defined right away in the constructor as follows
#data_format = DelimitedFormat("\n", ",", False)
# geometry = XYZGeometry(
#     x_field="LON",
#     y_field="LAT",
#     wkid=4326,
#     z_field="ALT",
#     z_unit="Meters"
# )
#
# time = TimeInterval(
#     interval_start_field="pubDate",
#     interval_end_field="updated"
# )
#
#
# aws_config = AWSIoT(
#     label=name,
#     description=description,
#     endpoint="ah2hhrmykvalt-ats.iot.us-west-1.amazonaws.com",
#     topic="aws/things/+",
#     qos_level=0,
#     access_key_id="AKIAYTUXJDCLWR773XNR",
#     secret_access_key="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",
#     data_format=data_format,
#     geometry=geometry,
#     time=time,
# )
# Out:
# Feature Schema retrieved from the Feed: {'attributes': [{'name': 'MMSI', 'dataType': 'Int64', 'nullable': True, 'tags': [], 'toField': 'MMSI'}, {'name': 'BaseDateTime', 'dataType': 'String', 'nullable': True, 'tags': [], 'toField': 'BaseDateTime'}, {'name': 'LAT', 'dataType': 'Float64', 'nullable': True, 'tags': [], 'toField': 'LAT'}, {'name': 'LON', 'dataType': 'Float64', 'nullable': True, 'tags': [], 'toField': 'LON'}, {'name': 'SOG', 'dataType': 'Float64', 'nullable': True, 'tags': [], 'toField': 'SOG'}, {'name': 'COG', 'dataType': 'Float64', 'nullable': True, 'tags': [], 'toField': 'COG'}, {'name': 'Heading', 'dataType': 'Int64', 'nullable': True, 'tags': [], 'toField': 'Heading'}, {'name': 'VesselName', 'dataType': 'String', 'nullable': True, 'tags': [], 'toField': 'VesselName'}, {'name': 'IMO', 'dataType': 'String', 'nullable': True, 'tags': [], 'toField': 'IMO'}, {'name': 'CallSign', 'dataType': 'String', 'nullable': True, 'tags': [], 'toField': 'CallSign'}, {'name': 'VesselType', 'dataType': 'String', 'nullable': True, 'tags': [], 'toField': 'VesselType'}, {'name': 'Status', 'dataType': 'String', 'nullable': True, 'tags': [], 'toField': 'Status'}, {'name': 'Length', 'dataType': 'Float64', 'nullable': True, 'tags': [], 'toField': 'Length'}, {'name': 'Width', 'dataType': 'Float64', 'nullable': True, 'tags': [], 'toField': 'Width'}, {'name': 'Draft', 'dataType': 'Float64', 'nullable': True, 'tags': [], 'toField': 'Draft'}, {'name': 'Cargo', 'dataType': 'Float64', 'nullable': True, 'tags': [], 'toField': 'Cargo'}]}

# %% [markdown]
# ### Manipulate the schema - rename or remove fields, change field data-type
# Renaming `VesselName` to `VesselName1`

# %%
aws_config.rename_field("VesselName", "VesselName1")
# Out:
# True

# %% [markdown]
# ### Set track id field
# Set `MMSI` (Maritime Mobile Service Identity) as the track-id

# %%
aws_config.set_track_id("MMSI")
# Out:
# True

# %% [markdown]
# Set XY geometry

# %%
xy_geometry = XYZGeometry("LON", "LAT", 4326)
aws_config.set_geometry_config(xy_geometry)
# Out:
# True

# %% [markdown]
# ### Create the Feed (and start it).

# %%
aws_feed = feeds.create(aws_config)
#aws_feed.start()
feeds.items
# Out:
# {'id': '', 'label': 'aws_feed_1', 'description': 'some description about the AWS feed', 'feed': {'schemaTransformation': {'inputSchema': {'attributes': [{'name': 'MMSI', 'dataType': 'Int64', 'nullable': True, 'tags': ['TRACK_ID']}, {'name': 'BaseDateTime', 'dataType': 'String', 'nullable': True, 'tags': []}, {'name': 'LAT', 'dataType': 'Float64', 'nullable': True, 'tags': []}, {'name': 'LON', 'dataType': 'Float64', 'nullable': True, 'tags': []}, {'name': 'SOG', 'dataType': 'Float64', 'nullable': True, 'tags': []}, {'name': 'COG', 'dataType': 'Float64', 'nullable': True, 'tags': []}, {'name': 'Heading', 'dataType': 'Int64', 'nullable': True, 'tags': []}, {'name': 'VesselName', 'dataType': 'String', 'nullable': True, 'tags': []}, {'name': 'IMO', 'dataType': 'String', 'nullable': True, 'tags': []}, {'name': 'CallSign', 'dataType': 'String', 'nullable': True, 'tags': []}, {'name': 'VesselType', 'dataType': 'String', 'nullable': True, 'tags': []}, {'name': 'Status', 'dataType': 'String', 'nullable': True, 'tags': []}, {'name': 'Length', 'dataType': 'Float64', 'nullable': True, 'tags': []}, {'name': 'Width', 'dataType': 'Float64', 'nullable': True, 'tags': []}, {'name': 'Draft', 'dataType': 'Float64', 'nullable': True, 'tags': []}, {'name': 'Cargo', 'dataType': 'Float64', 'nullable': True, 'tags': []}], 'geometry': {'geometryType': 'esriGeometryPoint', 'spatialReference': {'wkid': 4326}, 'hasZ': None}}, 'fieldMappings': [{'fromField': 'MMSI', 'toField': 'MMSI', 'tags': ['TRACK_ID']}, {'fromField': 'BaseDateTime', 'toField': 'BaseDateTime', 'tags': []}, {'fromField': 'LAT', 'toField': 'LAT', 'tags': []}, {'fromField': 'LON', 'toField': 'LON', 'tags': []}, {'fromField': 'SOG', 'toField': 'SOG', 'tags': []}, {'fromField': 'COG', 'toField': 'COG', 'tags': []}, {'fromField': 'Heading', 'toField': 'Heading', 'tags': []}, {'fromField': 'VesselName', 'toField': 'VesselName1', 'tags': []}, {'fromField': 'IMO', 'toField': 'IMO', 'tags': []}, {'fromField': 'CallSign', 'toField': 'CallSign', 'tags': []}, {'fromField': 'VesselType', 'toField': 'VesselType', 'tags': []}, {'fromField': 'Status', 'toField': 'Status', 'tags': []}, {'fromField': 'Length', 'toField': 'Length', 'tags': []}, {'fromField': 'Width', 'toField': 'Width', 'tags': []}, {'fromField': 'Draft', 'toField': 'Draft', 'tags': []}, {'fromField': 'Cargo', 'toField': 'Cargo', 'tags': []}]}, 'name': 'awsiot', 'properties': {'awsiot.endpoint': 'ah2hhrmykvalt-ats.iot.us-west-1.amazonaws.com', 'awsiot.topic': 'aws/things/+', 'awsiot.qos': 0, 'awsiot.accessKeyId': 'AKIAYTUXJDCLWR773XNR', 'awsiot.secretAccessKey': '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', 'json.buildGeometryFromFields': True, 'json.xField': 'LON', 'json.yField': 'LAT'}, 'formatName': 'json'}, 'properties': {'executable': True}}
# [<Feed id:bae6749551104464b8557b944135719a label:yini_test_feed>,
#  <Feed id:b18650717ec24f05a045f0178468cc4c label:rss_feed_yini_format>,
#  <Feed id:bc1e010daaef491b9d772ccccc58ee7c label:rss_feed_yini>,
#  <Feed id:3e4ce23f5d034f84ae3719f8972bd7c8 label:aws_feed_1>,
#  <Feed id:38be90c189fa41559d830bb83903f3e8 label:feature_layer_config_feed_1>]

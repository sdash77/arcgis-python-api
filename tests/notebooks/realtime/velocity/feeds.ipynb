# %%
from arcgis.gis import GIS

# %%
# Enter Url and Credentials
gis = GIS(url="https://devext.arcgis.com", username="pythontest_a4iot", password="v3locity.pyth0n")

# %% [markdown]
# - Get instance of feeds from `velocity`

# %%
velocity = gis.velocity
velocity

# %%
feeds = velocity.feeds
feeds

# %% [markdown]
# - Get list feeds configurations

# %%
all_feeds = feeds.items
all_feeds
# Out:
# [<Feed id:1903bbbb8e3c4568a6087b151962fff2 label:Tiger>,
#  <Feed id:b729882fc7ce4504b6d2248cb8fc1cee label:noaa weather rss feed 3>,
#  <Feed id:ea9849fe60c0465b9361df5f0983cc7a label:rss field with xy geometry>,
#  <Feed id:669801278ce74e52b020bef7aa24c089 label:rss_feed_1>,
#  <Feed id:b4b439a0d1f240949835a79b4e919a6d label:weather_rss_feed_1_DO_NOT_DELETE>,
#  <Feed id:02b0b0af39184c2594637d7e5339e900 label:test_http_format_testing>,
#  <Feed id:4e2431269d3f44aeadff79d0d2480ded label:noaa weather rss feed 2>,
#  <Feed id:e4d3c42193b14b48b912306919617010 label:weather_rss_feed_DO_NOT_DELETE>]

# %% [markdown]
# - Method: `<item>.get(id)`
# - Get Feed by id

# %%
sample_feed = None
try:
    sample_feed = feeds.get("e4d3c42193b14b48b912306919617010")
    print(sample_feed)
except Exception as e:
    print("Error while fetching the feed: " + e.__str__())
# Out:
# <Feed id:e4d3c42193b14b48b912306919617010 label:weather_rss_feed_DO_NOT_DELETE>

# %% [markdown]
# - Property: `<item>.status`
# - Retrieve status of `sample_feed`

# %%
try:
    status = sample_feed.status
    print(status)
except Exception as e:
    print("Error while fetching the feed status: " + e.__str__())
# Out:
# {'label': 'weather_rss_feed_DO_NOT_DELETE', 'id': 'e4d3c42193b14b48b912306919617010', 'status': 'stopped', 'avgRateIn': 0.0, 'executionMode': 'recurring', 'executable': True, 'startTime': 1629483798351, 'lastStartTime': 1629481958851}

# %% [markdown]
# - Method: `<item>.start()`
# - Start Feed

# %%
try:
    print(sample_feed.start())
except Exception as e:
    print("Error while starting the feed: " + e.__str__())
# Out:
# {'status': 'success', 'messages': [{'key': 'ITEM_MANAGER__START_FEED_SUCCESS_QUEUED', 'args': ['weather_rss_feed_DO_NOT_DELETE'], 'englishMessage': 'Feed weather_rss_feed_DO_NOT_DELETE had been queued to run.'}]}

# %% [markdown]
# - Method: `<item>.stop()`
# - Stop Feed

# %%
try:
    print(sample_feed.stop())
except Exception as e:
    print("Error while stopping the feed: " + e.__str__())
# Out:
# True

# %% [markdown]
# - Property: `<item>.metrics`
# - Retrieve metrics of `sample_feed`

# %%
try:
    print(sample_feed.metrics)
except Exception as e:
    print("Error while fetching the feed metrics: " + e.__str__())
# Out:
# {'itemId': 'e4d3c42193b14b48b912306919617010', 'timeInterval': 'uptime', 'nodeName': 'weather_rss_feed_DO_NOT_DELETE', 'percentCompute': 2.3880026745629954, 'avgRateIn': 0.0, 'avgBytesIn': 0.0, 'avgKBytesRateIn': 0.0, 'avgAttributeIn': 0.0, 'numErrors': 0.0}

# %% [markdown]
# - Method: `<item>.delete()`
# - Delete a feed

# %%
try:
    # Note this would result it deleting the feed and is irrevocable once done.
    print("Delete feed: uncomment next line to execute this step.")
    # print(sample_feed.delete())
except Exception as e:
    print("Error while deleting the feed: " + e.__str__())
# Out:
# Delete feed: uncomment next line to execute this step.

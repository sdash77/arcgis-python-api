# %% [markdown]
# # Http Simulator Feed creation

# %% [markdown]
# ## Connect to a Velocity instance
# For this example, we will connect to `a4iot-dev`

# %%
from arcgis import GIS
from arcgis.realtime.velocity.feeds_manager import Feed

gis = GIS(
    url="https://devext.arcgis.com",
    username="pythontest_a4iot",
    password="v3locity.pyth0n",
)

velocity = gis.velocity

feeds = gis.velocity.feeds
feeds

# %% [markdown]
# ## Configure the HTTP Simulator Feed
# Configuring a delimited format feed that contains location, time, track id and info about satellite locations.
#
# Feed Location: http://websats.westus2.cloudapp.azure.com/websats/satellites

# %%
from arcgis.realtime.velocity.feeds import HttpSimulator
from arcgis.realtime.velocity.input.format import DelimitedFormat
from arcgis.realtime.velocity.feeds.geometry import XYZGeometry, SingleFieldGeometry
from arcgis.realtime.velocity.feeds.time import TimeInterval, TimeInstant
from arcgis.realtime.velocity.feeds.run_interval import RunInterval


# HTTP Simulator Properties
name = "http_simulator_feed_1"
description = "some description about the HTTP Simulator feed"
url = "http://websats.westus2.cloudapp.azure.com/websats/satellites?nums=29709,43575"

http_simulator = HttpSimulator(
    label=name,
    description=description,
    url=url,
    data_format=None
)



# # all properties can also be defined right away in the constructor as follows
data_format = DelimitedFormat("\n", ",", False)
# geometry = XYZGeometry(
#     x_field="category_longitude",
#     y_field="category_latitude",
#     wkid=4326,
#     z_field="category_altitude",
#     z_unit="Meters"
# )
#
# time = TimeInterval(
#     interval_start_field="pubDate",
#     interval_end_field="updated"
# )
#
# run_interval = RunInterval(
#     cron_expression="0 * * ? * * *",
#     timezone="America/Los_Angeles"
# )
#
# http_simulator1 = HttpSimulator(
#     label=name,
#     description=description,
#     url=url,
#     http_method="GET",
#     http_auth_type=http_auth,
#     track_id_field="link",
#     data_format=data_format,
#     geometry=geometry,
#     time=time,
#     run_interval=run_interval
# )
# Out:
# Feature Schema retrieved from the Feed: {'attributes': [{'name': 'field1', 'dataType': 'String', 'nullable': True, 'tags': [], 'toField': 'field1'}, {'name': 'field2', 'dataType': 'Int32', 'nullable': True, 'tags': [], 'toField': 'field2'}, {'name': 'field3', 'dataType': 'Int64', 'nullable': True, 'tags': [], 'toField': 'field3'}, {'name': 'field4', 'dataType': 'String', 'nullable': True, 'tags': [], 'toField': 'field4'}, {'name': 'field5', 'dataType': 'Float64', 'nullable': True, 'tags': [], 'toField': 'field5'}, {'name': 'field6', 'dataType': 'Float64', 'nullable': True, 'tags': [], 'toField': 'field6'}, {'name': 'field7', 'dataType': 'Float64', 'nullable': True, 'tags': [], 'toField': 'field7'}]}

# %% [markdown]
# ### Create the Feed!

# %%
feeds.create(http_simulator)

feeds.items
# Out:
# {'id': '', 'label': 'http_simulator_feed_1', 'description': 'some description about the HTTP Simulator feed', 'feed': {'schemaTransformation': {'inputSchema': {'attributes': [{'name': 'field1', 'dataType': 'String', 'nullable': True, 'tags': []}, {'name': 'field2', 'dataType': 'Int32', 'nullable': True, 'tags': []}, {'name': 'field3', 'dataType': 'Int64', 'nullable': True, 'tags': []}, {'name': 'field4', 'dataType': 'String', 'nullable': True, 'tags': []}, {'name': 'field5', 'dataType': 'Float64', 'nullable': True, 'tags': []}, {'name': 'field6', 'dataType': 'Float64', 'nullable': True, 'tags': []}, {'name': 'field7', 'dataType': 'Float64', 'nullable': True, 'tags': []}]}, 'fieldMappings': [{'fromField': 'field1', 'toField': 'field1', 'tags': []}, {'fromField': 'field2', 'toField': 'field2', 'tags': []}, {'fromField': 'field3', 'toField': 'field3', 'tags': []}, {'fromField': 'field4', 'toField': 'field4', 'tags': []}, {'fromField': 'field5', 'toField': 'field5', 'tags': []}, {'fromField': 'field6', 'toField': 'field6', 'tags': []}, {'fromField': 'field7', 'toField': 'field7', 'tags': []}]}, 'name': 'simulator', 'properties': {'simulator.url': 'http://websats.westus2.cloudapp.azure.com/websats/satellites?nums=29709,43575', 'simulator.fieldSeparator': ',', 'simulator.featuresPerTime': 1, 'simulator.repeat': True, 'simulator.intervalInMillis': 1000, 'simulator.timeFieldIndex': 0, 'simulator.setToCurrentTime': True, 'delimited.recordTerminator': '\n', 'delimited.fieldDelimiter': '|', 'delimited.hasHeaderRow': False}, 'formatName': 'delimited'}, 'properties': {'executable': True}}
# [<Feed id:ca2f7513d0ee44a4b01b0fb1205c4ae2 label:http_simulator_feed_1>]

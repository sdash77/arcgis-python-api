# %%
from datetime import datetime

from arcgis.gis import GIS
# gis = GIS(profile="your_online_profile")

# %%
gis = GIS("https://deldev.maps.arcgis.com", "demos_deldev", "DelDevs12")

# %%
from arcgis.features.manage_data import extract_data

# %%
items = gis.content.search('tags:cougar_habitat owner:demos_deldev', 'Feature Layer', outside_org=True)

# %%
highways = gis.content.get('0707fd77e3bf4f0ab443b71425953152')

# %%
highways
# Out:
# <Item title:"cougar_highways" type:Feature Layer Collection owner:demos_deldev>

# %%
state_area_boundary = gis.content.get('a6cb2a0688d841fd803cd82b4d8282b4')

# %%
state_area_boundary
# Out:
# <Item title:"DissolveBoundaries" type:Feature Layer Collection owner:demos_deldev>

# %%
ext_state_highway1 = extract_data(input_layers=[highways.layers[0]],
                                 extent=state_area_boundary.layers[0],
                                 clip=True,
                                 data_format='shapefile',
                                 output_name='piyatesting')
# Out:
# dszmnsd,;gfsd;kl

# %%
ext_state_highway1 = extract_data(input_layers=[highways.layers[0]],
                                 extent=state_area_boundary.layers[0],
                                 clip=True,
                                 data_format='shapefile',
                                 output_name={ "title": "testdghasdfsaderytdfgdfgdfgdf",
                                               "tag": "datascience",
                                               "snippet": "none",
                                               "description": "extract data"})
# Out:
# dszmnsd,;gfsd;kl

# %%
ext_state_highway1
# Out:
# <Item title:"ext_state_highwayabcd" type:Shapefile owner:demos_deldev>

# %%
ext_state_highway2 = extract_data(input_layers=[highways.layers[0]],
                                 extent=state_area_boundary.layers[0],
                                 clip=True,
                                 data_format='shapefile',
                                 output_name={
                                                "title11": "test",
                                                "tag11": "datascience",
                                                "snippet11": "none",
                                                "description11": "extract data"
                                                })

# %%
ext_state_highway2
# Out:
# <Item title:"____.zip" type:Shapefile owner:demos_deldev>

# %%
ext_state_highway3 = extract_data(input_layers=[highways.layers[0]],
                                 extent=state_area_boundary.layers[0],
                                 clip=True,
                                 data_format='shapefile',
                                 output_name={
                                                "title": "test",
                                                "tag1": "datascience",
                                                "snippet": "none",
                                                "description": "extract data"
                                                })

# %%
ext_state_highway3
# Out:
# <Item title:"title_snippetdescription.zip" type:Shapefile owner:demos_deldev>

# %%
ext_state_highway4 = extract_data(input_layers=[highways.layers[0]],
                                 extent=state_area_boundary.layers[0],
                                 clip=True,
                                 data_format='shapefile',
                                 output_name={
                                                "title": "test",
                                                "tag": "datascience",
                                                "snippet": "none",
                                                "description": "extract data"
                                                })

# %%
ext_state_highway4
# Out:
# <Item title:"titletagsnippetdescription.zip" type:Shapefile owner:demos_deldev>

# %%
ext_state_highway1 = extract_data(input_layers=[highways.layers[0]],
                                 extent=state_area_boundary.layers[0],
                                 clip=True,
                                 data_format='CSV',
                                 output_name='csvextracting')
# Out:
# dszmnsd,;gfsd;kl

# %%
ext_state_highway1
# Out:
# <Item title:"cougar_highways20190530044738.csv" type:CSV owner:demos_deldev>

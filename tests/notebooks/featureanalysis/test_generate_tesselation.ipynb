# %%
import sys
import uuid
from arcgis.gis import GIS, Item
from arcgis.features import FeatureCo

# %%
from arcgis.features.manage_data import generate_tesselation

# %%
gis = GIS("https://deldev.maps.arcgis.com", "demos_deldev", "DelDevs12")
item = gis.content.get('0e199091d6b9416b9abb6655e1975d44')
layer = item.layers[0]
uid = uuid.uuid4().hex[:5]

# %%
est = gt1 = generate_tesselation(extent_layer=layer,
                           output_name="thisisatest" +uid,
                           bin_size=100,
                           bin_size_unit="SquareKilometers",
                           bin_type="SQUARE",estimate=True)
assert isinstance(est, dict)
est
# Out:
# {'totalRecords': 12, 'maximumCost': 0.012}

# %%
gpjob = generate_tesselation(extent_layer=layer,
                           output_name="thisisatest" +uid,
                           bin_size=100,
                           bin_size_unit="SquareKilometers",
                           bin_type="SQUARE",future=True)
res = gpjob.result()
assert isinstance(res, Item)
res
# Out:
# <Item title:"thisisatest64091" type:Feature Layer Collection owner:demos_deldev>

# %%
res.delete()
# Out:
# True

# %%
gt = generate_tesselation(extent_layer=layer,
                     bin_size=100,
                     bin_size_unit="SquareKilometers",
                     bin_type="SQUARE",)
print(gt)
# Out:
# <FeatureCollection>

# %%
uid = uuid.uuid4().hex[:5]
gt1 = generate_tesselation(extent_layer=layer,
                           output_name="thisisatest" +uid,
                           bin_size=100,
                           bin_size_unit="SquareKilometers",
                           bin_type="SQUARE",)
gt1
# Out:
# <Item title:"thisisatestc687f" type:Feature Layer Collection owner:demos_deldev>

# %%
gt1.delete()
# Out:
# True

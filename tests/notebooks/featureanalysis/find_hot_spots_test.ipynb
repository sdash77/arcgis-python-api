# %%
from datetime import datetime
from arcgis.features import FeatureCollection, FeatureSet
from arcgis.gis import Item
from arcgis.geoprocessing._job import GPJob

# %%
from arcgis.gis import GIS
gis = GIS("https://deldev.maps.arcgis.com", "demos_deldev", "DelDevs.123")

# %%
from arcgis.features.analyze_patterns import find_hot_spots

# %%
item = gis.content.get('5183636f099c48789628226e5730fb13')

# %%
collisions = item.layers[0]

# %%
from arcgis.features.feature import FeatureCollection

# %%
d = {"layerDefinition":{"currentVersion":10.2,"copyrightText":"","defaultVisibility":True,"relationships":[],"isDataVersioned":False,"supportsRollbackOnFailureParameter":True,"supportsStatistics":True,"supportsAdvancedQueries":True,"geometryType":"esriGeometryPolygon","minScale":0,"maxScale":0,"objectIdField":"OBJECTID","templates":[],"type":"Feature Layer","displayField":"TITLE","visibilityField":"VISIBLE","name":"Drawn Boundaries","hasAttachments":False,"typeIdField":"TYPEID","capabilities":"Query","allowGeometryUpdates":True,"htmlPopupType":"","hasM":False,"hasZ":False,"globalIdField":"","supportedQueryFormats":"JSON","hasStaticData":False,"maxRecordCount":-1,"indexes":[],"types":[],"drawingInfo":{"renderer":{"type":"simple","symbol":{"color":[0,0,0,255],"outline":{"color":[0,0,0,255],"width":3,"type":"esriSLS","style":"esriSLSSolid"},"type":"esriSFS","style":"esriSFSNull"},"label":"","description":""},"transparency":0,"labelingInfo":None,"fixedSymbols":True},"fields":[{"alias":"OBJECTID","name":"OBJECTID","type":"esriFieldTypeOID","editable":False},{"alias":"Title","name":"TITLE","length":50,"type":"esriFieldTypeString","editable":True},{"alias":"Visible","name":"VISIBLE","type":"esriFieldTypeInteger","editable":True},{"alias":"Description","name":"DESCRIPTION","length":1073741822,"type":"esriFieldTypeString","editable":True},{"alias":"Type ID","name":"TYPEID","type":"esriFieldTypeInteger","editable":True}]},"featureSet":{"features":[{"geometry":{"rings":[[[-13142888.028645039,4052820.2251285184],[-13142716.045331398,4046858.1369222826],[-13154621.112486798,4046705.2628657124],[-13154238.927345373,4052189.6196451667],[-13154200.70883123,4052266.056673452],[-13142888.028645039,4052820.2251285184]]],"spatialReference":{"wkid":102100,"latestWkid":3857}},"attributes":{"description":"blayer desc","title":"blayer","OBJECTID":0,"VISIBLE":1},"symbol":{"color":[0,0,0,255],"outline":{"color":[0,0,0,255],"width":3,"type":"esriSLS","style":"esriSLSSolid"},"type":"esriSFS","style":"esriSFSNull"}}],"geometryType":"esriGeometryPolygon"},"nextObjectId":1,"name":"Drawn Boundaries"}

# %%
lyr = FeatureCollection(d)

# %%
from datetime import datetime
collision_hot_spots = find_hot_spots(collisions,
                                     bounding_polygon_layer=lyr,
                                     output_name='collision_hexagon_hot_spots' + str(datetime.now().microsecond),
                                     shape_type='hexagon'
                                    )

# %%
assert isinstance(collision_hot_spots, Item)
collision_hot_spots
# Out:
# <Item title:"collision_hexagon_hot_spots447552" type:Feature Layer Collection owner:demos_deldev>

# %%
collision_hot_spots.delete()
# Out:
# True

# %%
collision_hot_spots = find_hot_spots(collisions,
                                     #output_name='collision_hexagon_hot_spots' + str(datetime.now().microsecond),
                                     shape_type='hexagon')

# %%
collision_hot_spots
# Out:
# {'hot_spots_result_layer': <FeatureCollection>,
#  'process_info': ['{"messageCode": "SS_00002", "message": "The following report outlines the workflow used to optimize your Find Hot Spots result:", "params": {}, "style": "<b></b><br/>"}',
#   '{"message": "Initial Data Assessment", "messageCode": "SS_84428", "params": {}, "style": "<u><b></b></u><br/>"}',
#   '{"message": "There are ${NumFeatures} valid input features.", "messageCode": "SS_84485", "params": {"NumFeatures": "17031"}, "style": "<ul><li></li></ul>"}',
#   '{"message": "There were {numOutliers} outlier locations; these will not be used to compute the hexagon size.", "messageCode": "SS_84700_1", "params": {"numOutliers": "130"}, "style": "<ul><li></li></ul>"}',
#   '{"message": "Incident Aggregation", "messageCode": "SS_84444", "params": {}, "style": "<u><b></b></u><br/>"}',
#   '{"message": "Using a hexagon of width ${HexWidth} and height ${HexHeight}", "messageCode": "SS_84698", "params": {"HexWidth": "136.2547 Meters", "HexHeight": "118.0000 Meters"}, "style": "<ul><li></li></ul>"}',
#   '{"message": "The aggregation process resulted in ${AggNumFeatures} weighted polygons.", "messageCode": "SS_84490", "params": {"AggNumFeatures": "2243"}, "style": "<ul><li></li></ul>"}',
#   '{"message": "${VarName} Properties:", "messageCode": "SS_84446", "params": {"VarName": "Incident Count"}, "style": "<ul><li></li></ul>"}',
#   '{"message": ["Min:", "${MinValue}"], "messageCode": "SS_84271", "params": {"MinValue": "1.0000"}, "style": "<table style=\'width: 200px;margin-left: 2.5em;border: none;\' class=\'table-plain\'><tbody><tr><td style=\'border: none;\'></td><td style=\'float:right;border: none;\'></td></tr>"}',
#   '{"message": ["Max:", "${MaxValue}"], "messageCode": "SS_84272", "params": {"MaxValue": "128.0000"}, "style": "<tr><td style=\'border: none;\'></td><td style=\'float: right;border: none;\'></td></tr>"}',
#   '{"message": ["Mean:", "${AvgValue}"], "messageCode": "SS_84261", "params": {"AvgValue": "7.5930"}, "style": "<tr><td style=\'border: none;\'></td><td style=\'float: right;border: none;\'></td></tr>"}',
#   '{"message": ["Std. Dev.:", "${StdValue}"], "messageCode": "SS_84262", "params": {"StdValue": "13.5367"}, "style": "<tr><td style=\'border: none;\'></td><td style=\'float: right;border: none;\'></td></tr></tbody></table>"}',
#   '{"message": "Scale of Analysis", "messageCode": "SS_84459", "params": {}, "style": "<u><b></b></u><br/>"}',
#   '{"message": "The optimal fixed distance band is based on the average distance to ${NumNeighs} nearest neighbors: ${DistanceInfo}", "messageCode": "SS_84464", "params": {"NumNeighs": "30", "DistanceInfo": "486.0000 Meters"}, "style": "<ul><li></li></ul><br/>"}',
#   '{"message": "Hot Spot Analysis", "messageCode": "SS_84466", "params": {}, "style": "<u><b></b></u><br/>"}',
#   '{"message": "There are ${NumSignificant} output features statistically significant based on an FDR correction for multiple testing and spatial dependence.", "messageCode": "SS_84470", "params": {"NumSignificant": "263"}, "style": "<ul><li></li></ul><br/>"}',
#   '{"message": "Output", "messageCode": "SS_84471", "params": {}, "style": "<u><b></b></u><br/>"}',
#   '{"message": "Red output features represent hot spots where high incident counts cluster.", "messageCode": "SS_84469_0", "params": {}, "style": "<ul><li></li></ul>"}',
#   '{"message": "Blue output features represent cold spots where low incident counts cluster.", "messageCode": "SS_84469_1", "params": {}, "style": "<ul><li></li></ul><br/>"}']}

# %%
assert isinstance(collision_hot_spots, dict)
collision_hot_spots
# Out:
# {'hot_spots_result_layer': <FeatureCollection>,
#  'process_info': ['{"messageCode": "SS_00002", "message": "The following report outlines the workflow used to optimize your Find Hot Spots result:", "params": {}, "style": "<b></b><br/>"}',
#   '{"message": "Initial Data Assessment", "messageCode": "SS_84428", "params": {}, "style": "<u><b></b></u><br/>"}',
#   '{"message": "There are ${NumFeatures} valid input features.", "messageCode": "SS_84485", "params": {"NumFeatures": "17031"}, "style": "<ul><li></li></ul>"}',
#   '{"message": "There were {numOutliers} outlier locations; these will not be used to compute the hexagon size.", "messageCode": "SS_84700_1", "params": {"numOutliers": "130"}, "style": "<ul><li></li></ul>"}',
#   '{"message": "Incident Aggregation", "messageCode": "SS_84444", "params": {}, "style": "<u><b></b></u><br/>"}',
#   '{"message": "Using a hexagon of width ${HexWidth} and height ${HexHeight}", "messageCode": "SS_84698", "params": {"HexWidth": "136.2547 Meters", "HexHeight": "118.0000 Meters"}, "style": "<ul><li></li></ul>"}',
#   '{"message": "The aggregation process resulted in ${AggNumFeatures} weighted polygons.", "messageCode": "SS_84490", "params": {"AggNumFeatures": "2243"}, "style": "<ul><li></li></ul>"}',
#   '{"message": "${VarName} Properties:", "messageCode": "SS_84446", "params": {"VarName": "Incident Count"}, "style": "<ul><li></li></ul>"}',
#   '{"message": ["Min:", "${MinValue}"], "messageCode": "SS_84271", "params": {"MinValue": "1.0000"}, "style": "<table style=\'width: 200px;margin-left: 2.5em;border: none;\' class=\'table-plain\'><tbody><tr><td style=\'border: none;\'></td><td style=\'float:right;border: none;\'></td></tr>"}',
#   '{"message": ["Max:", "${MaxValue}"], "messageCode": "SS_84272", "params": {"MaxValue": "128.0000"}, "style": "<tr><td style=\'border: none;\'></td><td style=\'float: right;border: none;\'></td></tr>"}',
#   '{"message": ["Mean:", "${AvgValue}"], "messageCode": "SS_84261", "params": {"AvgValue": "7.5930"}, "style": "<tr><td style=\'border: none;\'></td><td style=\'float: right;border: none;\'></td></tr>"}',
#   '{"message": ["Std. Dev.:", "${StdValue}"], "messageCode": "SS_84262", "params": {"StdValue": "13.5367"}, "style": "<tr><td style=\'border: none;\'></td><td style=\'float: right;border: none;\'></td></tr></tbody></table>"}',
#   '{"message": "Scale of Analysis", "messageCode": "SS_84459", "params": {}, "style": "<u><b></b></u><br/>"}',
#   '{"message": "The optimal fixed distance band is based on the average distance to ${NumNeighs} nearest neighbors: ${DistanceInfo}", "messageCode": "SS_84464", "params": {"NumNeighs": "30", "DistanceInfo": "486.0000 Meters"}, "style": "<ul><li></li></ul><br/>"}',
#   '{"message": "Hot Spot Analysis", "messageCode": "SS_84466", "params": {}, "style": "<u><b></b></u><br/>"}',
#   '{"message": "There are ${NumSignificant} output features statistically significant based on an FDR correction for multiple testing and spatial dependence.", "messageCode": "SS_84470", "params": {"NumSignificant": "263"}, "style": "<ul><li></li></ul><br/>"}',
#   '{"message": "Output", "messageCode": "SS_84471", "params": {}, "style": "<u><b></b></u><br/>"}',
#   '{"message": "Red output features represent hot spots where high incident counts cluster.", "messageCode": "SS_84469_0", "params": {}, "style": "<ul><li></li></ul>"}',
#   '{"message": "Blue output features represent cold spots where low incident counts cluster.", "messageCode": "SS_84469_1", "params": {}, "style": "<ul><li></li></ul><br/>"}']}

# %%
gpjob = find_hot_spots(collisions, shape_type='hexagon',future=True)
gpjob.task
# Out:
# 'FindHotSpots'

# %%
assert isinstance(gpjob.result(), dict)

# %% [markdown]
# #### Test Overwrite

# %%
import sys
sys.path.insert(0, r"C:\\ipython_workfolder\\geosaurus\\src")
from arcgis.gis import GIS

portal = GIS(profile="your_portal_profile", verify_cert=False,)

# %%
fl_to_overwrite = portal.content.get(test.id).layers[0]
print(fl_to_overwrite)
print(test.id)

# %%
print(overwrite.layers)
print(overwrite.id)

# %%
overwrite.delete()

# %%
from datetime import datetime
from arcgis.features import FeatureCollection, FeatureSet
from arcgis.gis import Item
from arcgis.geoprocessing._job import GPJob

# %%
from arcgis.gis import GIS, ProfileManager

# %%
gis = GIS("https://deldev.maps.arcgis.com", "demos_deldev", "DelDevs12")

# %%
from arcgis.features.find_locations import find_centroids

# %%
line_item = gis.content.get('61f41a3533f646068eb2293eb4af1dcd')

# %%
line_item

# %%
from datetime import datetime
tst1 = find_centroids(input_layer=line_item.layers[0],
                      point_location=True,
                      output_name='tst_cntr_' + str(datetime.now().microsecond))

# %%
tst2 = find_centroids(input_layer=line_item.layers[0],
                      point_location=True)

# %%
assert isinstance(tst2, FeatureCollection)

# %%
assert isinstance(tst1, Item)
tst1.delete()

# %% [markdown]
# #### Test Overwrite

# %%
import sys
sys.path.insert(0, r"C:\\ipython_workfolder\\geosaurus\\src")
from arcgis.gis import GIS

portal = GIS(profile="your_portal_profile", verify_cert=False,)

# %%
fl_to_overwrite = portal.content.get(test.id).layers[0]
print(fl_to_overwrite)
print(test.id)

# %%
print(overwrite.layers)
print(overwrite.id)

# %%
overwrite.delete()

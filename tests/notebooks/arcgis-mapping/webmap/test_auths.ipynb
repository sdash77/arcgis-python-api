# %% [markdown]
# # Test Different Authentications with Lab Widget
#
# #### The purpose of this lab is to test the different auth schemes that can be used to initialize the GIS object. We then use each gis instance to initialize a widget.
# #### Need to make sure each widget renders as well as no other errors come up.

# %%
import arcgis

arcgis.__version__

# %%
from arcgis.gis import GIS
from IPython.display import display
from arcgis.map import Map

credentials = [
    {"url": "https://rqawinbi01pt.ags.esri.com/gis"},
    {
        "url": "https://rqawinbi01pt.ags.esri.com/gis",
        "username": "creator2",
        "password": "portalaccount1",
        "verify": False,
    },
    {
        "url": "https://rqawiniwa02pt.ags.esri.com/gis",
        "username": "avworld\\creator2",
        "password": "portalaccount1",
        "verify": False,
    },
    {"url": "https://rqawiniwa02pt.ags.esri.com/gis", "verify": False},
    {
        "url": "https://rqawinmiwa05pt.ags.esri.com/gis",
        "verify": False,
        "username": "avworld\\creator2",
        "password": "portalaccount1",
    },
    {
        "url": "https://rqawinkb08pt.ags.esri.com/gis",
        "verify": False,
        "username": "avworld\\creator2",
        "password": "portalaccount1",
    },
    {
        "url": "https://rqawinplt07pt.ags.esri.com/gis",
        "verify": False,
        "username": "avworld\\creator2",
        "password": "portalaccount1",
    },
    {
        "url": "https://rqalnxldap02pt.esri.com/gis",
        "verify": False,
        "username": "creator2",
        "password": "portalaccount1",
    },
    # https://rqalnxpki03pt.esri.com/gis/home/
    # https://rqawinpki03pt.ags.esri.com/gis/home/
]
for cred in credentials:
    gis = GIS(**cred)

    m = Map(gis=gis)
    display(m)

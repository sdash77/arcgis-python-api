# %% [markdown]
# # Demo Notebook

# %%
from arcgis.gis import GIS
from arcgis.map import Map
from arcgis.features import FeatureLayer

# %%
gis = GIS()
gis

# %%
m = Map()
m

# %%
m.zoom = 6

# %%
m.extent

# %%
m.extent = {
    "spatialReference": {"wkid": 102100},
    "xmin": -13681742.203186732,
    "ymin": 6090104.78905295,
    "xmax": -10506853.796334494,
    "ymax": 7313097.241615444,
}

# %%
m.extent

# %% [markdown]
# ### Work with map content

# %%
content = m.content
content

# %%
fl = FeatureLayer(
    "https://services.arcgis.com/zmLUiqh7X11gGV2d/arcgis/rest/services/lcd_000b16a_ceag16_Crops/FeatureServer/0"
)
fl

# %%
content.add(fl)

# %%
content.layers

# %% [markdown]
# ### Turn on widgets

# %%
m.legend.enabled = True
m.layer_list.enabled = True

# %% [markdown]
# # Work with Basemap

# %%
m1 = Map()
m1

# %%
bm = m1.basemap
bm

# %%
bm.basemap

# %%
bm.basemaps

# %%
vtl = gis.content.get("f240fe360b434afc87dd989bf0c0b825")
vtl.type

# %%
m1.content.add(vtl)

# %%
bm.move_to_basemap(0)

# %%
bm.basemap

# %% [markdown]
# # Create from Existing

# %%
m2 = Map(item="45e6bb0c0960449cb29031f590af9a59")
m2

# %%
m2.content.layers

# %%
lv = m2.content.layer_visibility(0)
lv

# %%
lv.visibility

# %%
lv.legend_visibility

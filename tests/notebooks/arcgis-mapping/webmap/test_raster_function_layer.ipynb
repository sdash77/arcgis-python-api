# %%
from arcgis.map.map_widget import Map
from arcgis.raster import ImageryLayer, Raster
from arcgis.gis import GIS
# Out:
# C:\Users\rhea9381\Anaconda3\envs\geosaurus_dev_env\Lib\site-packages\dask\dataframe\_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 11.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(

# %%
gis = GIS('https://sha-arcgis-ra.esri.com/portal', '', '', verify_cert=False)
# Out:
# Setting `verify_cert` to False is a security risk, use at your own risk.

# %% [markdown]
# #Testing add RFT output layer to map widget

# %%
webmap = Map('Amberg')
webmap.basemap.basemap = "topo-vector"
webmap
# Out:
# Map(center=[6350271.759746118, 1319790.4131866735], extent={'xmin': 1313667.8411930436, 'ymin': 6340860.758021…

# %%
# Imagery Layer
layer = ImageryLayer(
    "https://sha-arcgis-ra.esri.com/server/rest/services/090160_tif/ImageServer", gis=gis
)
webmap.content.add(layer)

# %%
from arcgis.raster.functions import RFT
rft_item =  gis.content.get('870941f10ff843d38d54e53d514c3974')
rft_item
# Out:
# <Item title:"Grayscale_Pro" type:Raster function template owner:admin>

# %%
rft_obj = RFT(gis.content.get('870941f10ff843d38d54e53d514c3974'))
ras = rft_obj(Raster=layer)
ras
# Out:
# <ImageryLayer url:"https://sha-arcgis-ra.esri.com/server/rest/services/090160_tif/ImageServer">

# %%
webmap.content.add(ras)

# %% [markdown]
# #Testing adding raster function applied output layer to map widget

# %%
webmap = Map('Amberg')
webmap.basemap.basemap = "topo-vector"
webmap
# Out:
# Map(center=[6350271.759746118, 1319790.4131866735], extent={'xmin': 1313667.8411930436, 'ymin': 6340860.758021…

# %%
# Imagery Layer
layer = ImageryLayer(
    "https://sha-arcgis-ra.esri.com/server/rest/services/090160_tif/ImageServer", gis=gis
)
webmap.content.add(layer)

# %%
from arcgis.raster.functions import grayscale
op = grayscale(layer)
op
# Out:
# <ImageryLayer url:"https://sha-arcgis-ra.esri.com/server/rest/services/090160_tif/ImageServer">

# %%
webmap.content.add(op)

# %% [markdown]
# #Testing adding raster function applied output layer to map widget

# %%
webmap = Map('Amberg')
webmap.basemap.basemap = "topo-vector"
webmap
# Out:
# Map(center=[6350271.759746118, 1319790.4131866735], extent={'xmin': 1313667.8411930436, 'ymin': 6340860.758021…

# %%
# Imagery Layer
layer = ImageryLayer(
    "https://sha-arcgis-ra.esri.com/server/rest/services/amberg/ImageServer", gis=gis
)
#webmap.content.add(layer)

# %%
nl = layer.filter_by("OBJECTID=1")
nl
# Out:
# <ImageryLayer url:"https://sha-arcgis-ra.esri.com/server/rest/services/amberg/ImageServer">

# %%
webmap.content.add(nl)

# %%
from arcgis.raster.functions import grayscale
op = grayscale(nl)
op
# Out:
# <ImageryLayer url:"https://sha-arcgis-ra.esri.com/server/rest/services/amberg/ImageServer">

# %%
webmap.content.add(op)

# %% [markdown]
# #Testing adding Raster object to map widget

# %%
webmap = Map('Amberg')
webmap.basemap.basemap = "topo-vector"
webmap
# Out:
# Map(center=[6350271.759746118, 1319790.4131866735], extent={'xmin': 1313667.8411930436, 'ymin': 6340860.758021…

# %%
# Imagery Layer
layer = Raster(
    "https://sha-arcgis-ra.esri.com/server/rest/services/090160_tif/ImageServer", gis=gis
)
webmap.content.add(layer)

# %%
from arcgis.raster.functions import grayscale
op = grayscale(layer)
op

# %%
webmap.content.add(op)

# %%
# Test adding datastore raster constructed from ImageryLayer object to map widget

# %%
import arcgis
ras =  arcgis.raster.ImageryLayer("/fileShares/amberg/090160.tif", gis=gis)
ras
# Out:
# <ImageryLayer url:"https://sha-arcgis-ra.esri.com/server/rest/services/System/RasterRendering/ImageServer">

# %%
from arcgis.raster.functions import grayscale
op = grayscale(ras)
op
# Out:
# <ImageryLayer url:"https://sha-arcgis-ra.esri.com/server/rest/services/System/RasterRendering/ImageServer">

# %%
webmap = Map('Amberg')
webmap.basemap.basemap = "topo-vector"
webmap
# Out:
# Map(center=[6350271.759746118, 1319790.4131866735], extent={'xmin': 1313667.8411930436, 'ymin': 6340860.758021…

# %%
webmap.content.add(ras)

# %%
webmap.content.add(op)

# %%
# Test adding datastore raster constructed from Raster object to map widget

# %%
import arcgis
ras =  arcgis.raster.Raster("/fileShares/amberg/090160.tif", gis=gis)
ras

# %%
from arcgis.raster.functions import grayscale
op = grayscale(ras)
op

# %%
webmap = Map('Amberg')
webmap.basemap.basemap = "topo-vector"
webmap
# Out:
# Map(center=[6350271.759746118, 1319790.4131866735], extent={'xmin': 1313667.8411930436, 'ymin': 6340860.758021…

# %%
webmap.content.add(ras)

# %%
webmap.content.add(op)

# %%
# Test adding cloud datastore raster constructed from Raster object to map widget

# %%
import arcgis
ras =  arcgis.raster.Raster("https://naipeuwest.blob.core.windows.net/naip/v002/pr/2022/pr_030cm_2022/18065/51/m_1806551_nw_20_030_20221212_20230329.tif", gis=gis)
ras

# %%
from arcgis.raster.functions import grayscale
op = grayscale(ras)
op

# %%
webmap = Map()
webmap.basemap.basemap = "topo-vector"
webmap
# Out:
# Map(extent={'spatialReference': {'latestWkid': 3857, 'wkid': 102100}, 'xmin': -13034068.816148141, 'ymin': 402…

# %%
webmap.content.add(ras)

# %%
webmap.zoom_to_layer(ras)

# %%
webmap.content.add(op)

# %%
#Adding tiles only service to map widget

# %%
gis = GIS('https://esri-rasterdev.maps.arcgis.com/', '', '', verify_cert=False)
# Out:
# Setting `verify_cert` to False is a security risk, use at your own risk.

# %%
lyr_item = gis.content.get('1cb7ef4076d946a88b1ac111480403f7')
lyr = lyr_item.layers[0]

# %%
webmap = Map('Amberg')
webmap.basemap.basemap = "topo-vector"
webmap
# Out:
# Map(center=[6350271.759746118, 1319790.4131866735], extent={'xmin': 1313667.8411930436, 'ymin': 6340860.758021…

# %%
webmap.content.add(lyr)

# %%
webmap.zoom_to_layer(lyr)

# %%
from arcgis.raster.functions import grayscale
op = grayscale(lyr)
#op

# %%
webmap.content.add(op)

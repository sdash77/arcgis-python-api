# %% [markdown]
# ## Editing Maps
#
# This test is used for editing maps in a story map. As more properties get added for editing, add the tests to this notebook.

# %%
import sys

sys.path.insert(0, r"C:\\ipython_workfolder\\geosaurus_main\\src")

from arcgis.gis import GIS
from arcgis.apps.storymap.story import StoryMap
from arcgis.apps.storymap import Map

# %%
gis = GIS(profile="your_online_profile", verify_cert=False)

# %% [markdown]
# ### Get your exisitng Story

# %% [markdown]
# ##### This Story contains: A sidecar, A Map(webmap), A Text, A Map(webmap), A Text, and A Map(webscene)

# %%
story = StoryMap("c30b8cf0a6c04b26a0103f877119981f")

# %%
story

# %% [markdown]
# ### Different ways to see your nodes

# %%
story.nodes

# %%
story.get(type="webscene")

# %%
story.get(type="webmap")

# %% [markdown]
# ### Choose a node to edit

# %%
scene_map = story.get("n-rQUzP2")

# %% [markdown]
# ### Look at the node properties and edit

# %%
scene_map.map

# %%
original_map = gis.content.get("820f39b68481432baed056113dacc422")
original_map

# %%
gis.content.get("b04e44630e4d4f788b4fec3f2d8c9ace")

# %%
scene_map.map ="b04e44630e4d4f788b4fec3f2d8c9ace"

# %%
scene_map.caption = "Hamburg 3D Map"

# %%
scene_map.map

# %% [markdown]
# ### Move nodes around

# %% [markdown]
# #### Method 1: Add a new map at a certain position

# %%
new_map = Map("867895a71a1840399476fc717e76bb43")

story.add(new_map, caption="A cool new map", position=1)

# %%
story.nodes

# %% [markdown]
# #### Method 2: Use the move method

# %%
story.move("n-23e10c", 6) #move map
story.move("n-53sxxi", 5) #move subheading

# %%
story.nodes

# %% [markdown]
# ### Save the Story

# %%
story.save(publish = True)

# %% [markdown]
# # Test New Story Map with Python API

# %%
import sys

sys.path.insert(0, r"C:\\ipython_workfolder\\geosaurus_main\\src")

from arcgis.gis import GIS
from arcgis.apps.storymap.story import StoryMap, Themes
from arcgis.apps.storymap import (
    Image,
    Audio,
    Map,
    Video,
    Embed,
    Button,
    Text,
    TextStyles,
    Gallery,
    Sidecar
)

# %%
# Folder path for content (insert your own path)
content = r"C:\ipython_workfolder\Content"

# %%
gis = GIS(profile="your_online_profile", verify_cert=False)

# %% [markdown]
# ## Creating A New Story

# %% [markdown]
# Create a new story by calling StoryMap without passing an item or itemid

# %%
my_story = StoryMap()

# %% [markdown]
# ### Adding Basics

# %% [markdown]
# Change story theme by using the enumerated Themes class and choosing a type of theme.
# Update story cover by assigning a title, style, summary, by_line, and an image of type Image.

# %%
#set the theme
my_story.theme("a5f192a0c2cd401b8a3efb0f36311f92")

# image for story cover
river = Image("https://www.nps.gov/npgallery/GetAsset/0022D3FF-1DD8-B71B-0BE3AD4C48F96FF9/proxy/hires")

# Edit story cover
my_story.story_cover(
    "My First Story",
    type="minimal",
    summary="Testing the Python API",
    by_line="Python Tester",
    image=river
)
# Out:
# {'type': 'storycover',
#  'data': {'type': 'minimal',
#   'title': 'My First Story',
#   'summary': 'Testing the Python API',
#   'byline': 'Python Tester',
#   'titlePanelPosition': 'start'},
#  'children': ['n-bba530']}

# %% [markdown]
# Save the story. Pass the title the first time a story is saved. Not necessary for saves after unless user wants to change the name.

# %%
my_story.save("My Test Story")
# Out:
# True

# %% [markdown]
# ## Adding Items
#
# Many items come from the National Park Services:
# https://www.nps.gov/media/multimedia-search.htm#sort=Date_Last_Modified+desc

# %% [markdown]
# ### Create Images and Add
# Create an instance of Image with the url, then add to the story with a caption and alt text.
# To add a separator to the story call the add method without passing an item.

# %%
trees = Image("https://www.nps.gov/npgallery/GetAsset/69680c29-caa3-42da-93d9-32925e9ed409/proxy/hires")

my_story.add(trees, "Some trees with a deer", "Sequoia trees in the distance")
my_story.add()  # separator
# Out:
# 'dfbcac'

# %% [markdown]
# To see the properties of the image

# %%
trees.properties
# Out:
# {'node_dict': {'type': 'image',
#   'data': {'image': 'r-40f208',
#    'caption': 'Some trees with a deer',
#    'alt': 'Sequoia trees in the distance'},
#   'config': {'size': None}},
#  'resource_dict': {'type': 'image',
#   'data': {'src': 'https://www.nps.gov/npgallery/GetAsset/69680c29-caa3-42da-93d9-32925e9ed409/proxy/hires',
#    'provider': 'uri',
#    'height': 1688,
#    'width': 3000}}}

# %%
trees.image
# Out:
# 'https://www.nps.gov/npgallery/GetAsset/69680c29-caa3-42da-93d9-32925e9ed409/proxy/hires'

# %%
trees.caption
# Out:
# 'Some trees with a deer'

# %%
trees.alt_text
# Out:
# 'Sequoia trees in the distance'

# %% [markdown]
# Create an instance of Image from a file path and add to story.
# Notice how png takes a lot longer due to the size of the image.

# %%
canyon = Image(content + r"\canyon.png")
my_story.add(canyon)
# Out:
# 'n-d64f52'

# %% [markdown]
# To see the properties of the image when it is a file path.
# Notice the properties are different than when image is added by url

# %%
canyon.properties
# Out:
# {'node_dict': {'type': 'image',
#   'data': {'image': 'r-60c3fe', 'caption': None, 'alt': None},
#   'config': {'size': None}},
#  'resource_dict': {'type': 'image',
#   'data': {'resourceId': 'canyon.png',
#    'provider': 'item-resource',
#    'height': 3854,
#    'width': 5828}}}

# %% [markdown]
# ### Create Video and Audio then Add to Story
#
# Create an instance of video and audio.
# Observe the node order before adding audio to the story.
# Once audio is added, see node order again and notice the position was respected.

# %%
my_video = Video(content + r"\bear.mp4")
video = my_story.add(my_video)

# %%
# Node order before adding audio
craine = Audio(content + r"\craine.mp3")
print("Node Order Before Adding Audio:")
print(my_story.nodes)
print("------------------------------------")
# Add audio at a certain position
my_story.add(craine, position=2)
separator = my_story.add()

# See node order after audio was added
print("Node Order After Adding Audio:")
print(my_story.nodes)
# Out:
# Node Order Before Adding Audio:
# [{'n-aTn8ak': 'storycover'}, {'n-1AItUD': 'navigation'}, {'40e587': <arcgis.apps.storymap.story_content.Text object at 0x000002018D5B4348>}, {'n-9e6450': <arcgis.apps.storymap.story_content.Audio object at 0x000002018D5B49C8>}, {'860a95': <arcgis.apps.storymap.story_content.Text object at 0x000002018D5B4B08>}, {'n-413033': <arcgis.apps.storymap.story_content.Image object at 0x000002018D5B4588>}, {'9a69c3': 'separator'}, {'n-a6c7d1': <arcgis.apps.storymap.story_content.Image object at 0x000002018D5B4FC8>}, {'n-772bc8': <arcgis.apps.storymap.story_content.Video object at 0x000002018D5B4C88>}, {'0c590f': 'separator'}, {'n-555932': <arcgis.apps.storymap.story_content.Embed object at 0x000002018D5B48C8>}, {'0dfe4e': <arcgis.apps.storymap.story_content.Button object at 0x000002018D5B4F08>}, {'n-3ce4e7': <arcgis.apps.storymap.story_content.Map object at 0x000002018D5B4608>}, {'n-694687': <arcgis.apps.storymap.story_content.Image object at 0x000002018D5B42C8>}, {'dfbcac': 'separator'}, {'n-d64f52': <arcgis.apps.storymap.story_content.Image object at 0x000002018D5B4288>}, {'n-aff8c6': <arcgis.apps.storymap.story_content.Video object at 0x000002018D5B4D08>}, {'n-cOeTah': 'credits'}]
# ------------------------------------
# Node Order After Adding Audio:
# [{'n-aTn8ak': 'storycover'}, {'n-1AItUD': 'navigation'}, {'n-cda468': <arcgis.apps.storymap.story_content.Audio object at 0x000002018DA65088>}, {'40e587': <arcgis.apps.storymap.story_content.Text object at 0x000002018A028388>}, {'n-9e6450': <arcgis.apps.storymap.story_content.Audio object at 0x000002018D5B4B08>}, {'860a95': <arcgis.apps.storymap.story_content.Text object at 0x000002018D5B4588>}, {'n-413033': <arcgis.apps.storymap.story_content.Image object at 0x000002018D5B4C88>}, {'9a69c3': 'separator'}, {'n-a6c7d1': <arcgis.apps.storymap.story_content.Image object at 0x000002018D5B4648>}, {'n-772bc8': <arcgis.apps.storymap.story_content.Video object at 0x000002018D5B4308>}, {'0c590f': 'separator'}, {'n-555932': <arcgis.apps.storymap.story_content.Embed object at 0x000002018D5B4988>}, {'0dfe4e': <arcgis.apps.storymap.story_content.Button object at 0x000002018D5B4288>}, {'n-3ce4e7': <arcgis.apps.storymap.story_content.Map object at 0x000002018D5B4708>}, {'n-694687': <arcgis.apps.storymap.story_content.Image object at 0x000002018D5B4608>}, {'dfbcac': 'separator'}, {'n-d64f52': <arcgis.apps.storymap.story_content.Image object at 0x000002018D5B4848>}, {'n-aff8c6': <arcgis.apps.storymap.story_content.Video object at 0x000002018D5B4F08>}, {'a219ef': 'separator'}, {'n-cOeTah': 'credits'}]

# %%
my_story.save()
# Out:
# True

# %% [markdown]
# ### Create Embed, Button, Map, and Texts
#
# Embed can be created with a url.
# Button can be created with a text and a link.
# Map is created from an exisiting map item or item id of type webmap.
# Text is created from text and a style of text.

# %%
# Create Embed from a link
park_media = Embed(
    "https://www.nps.gov/media/multimedia-search.htm#sort=Date_Last_Modified+desc"
)
web_page = my_story.add(park_media)

# Create a Button
leaves = Button(
    link="https://www.nps.gov/subjects/forests/leaf-peeping.htm",
    text="Autumn Colors"
)
leaf_button = my_story.add(leaves)

# Create a Map from an exisiting webmap
covid_map = Map("006c10be294f4f64a5c9e5202cfa64c3")
covid = my_story.add(
    covid_map, caption="This has nothing to do with parks but I needed a map"
)

# Create two types of Text and add to certain position in the story.
welcome = Text(
    text="Welcome to a New Story About Some National Park Information",
    style=TextStyles.HEADING,
)
my_story.add(welcome, position=2)
quote = Text(
    text="I encourage everybody to hop on Google and type in ‘national park’ in whatever state they live in and see the beauty that lies in their own backyard. It’s that simple.",
    style=TextStyles.QUOTE,
)
my_story.add(quote, position=4)
# Out:
# '82facb'

# %%
my_story.nodes
# Out:
# [{'n-aTn8ak': 'storycover'},
#  {'n-1AItUD': 'navigation'},
#  {'e65453': <arcgis.apps.storymap.story_content.Text at 0x2018d5b8748>},
#  {'n-cda468': <arcgis.apps.storymap.story_content.Audio at 0x2018d5b8b88>},
#  {'82facb': <arcgis.apps.storymap.story_content.Text at 0x2018d5b8bc8>},
#  {'40e587': <arcgis.apps.storymap.story_content.Text at 0x2018d5b8c48>},
#  {'n-9e6450': <arcgis.apps.storymap.story_content.Audio at 0x2018d5b8b08>},
#  {'860a95': <arcgis.apps.storymap.story_content.Text at 0x2018d5b8848>},
#  {'n-413033': <arcgis.apps.storymap.story_content.Image at 0x2018d5b8c88>},
#  {'9a69c3': 'separator'},
#  {'n-a6c7d1': <arcgis.apps.storymap.story_content.Image at 0x2018d5b8c08>},
#  {'n-772bc8': <arcgis.apps.storymap.story_content.Video at 0x2018d5b8cc8>},
#  {'0c590f': 'separator'},
#  {'n-555932': <arcgis.apps.storymap.story_content.Embed at 0x2018d5b8dc8>},
#  {'0dfe4e': <arcgis.apps.storymap.story_content.Button at 0x2018d5b8e08>},
#  {'n-3ce4e7': <arcgis.apps.storymap.story_content.Map at 0x2018d5b8d88>},
#  {'n-694687': <arcgis.apps.storymap.story_content.Image at 0x2018d5b8d08>},
#  {'dfbcac': 'separator'},
#  {'n-d64f52': <arcgis.apps.storymap.story_content.Image at 0x2018d5b8d48>},
#  {'n-aff8c6': <arcgis.apps.storymap.story_content.Video at 0x2018d5b8e48>},
#  {'a219ef': 'separator'},
#  {'n-4f509b': <arcgis.apps.storymap.story_content.Embed at 0x2018d5b8ec8>},
#  {'de42af': <arcgis.apps.storymap.story_content.Button at 0x2018d5b8f48>},
#  {'n-bc617d': <arcgis.apps.storymap.story_content.Map at 0x2018d5b8f88>},
#  {'n-cOeTah': 'credits'}]

# %% [markdown]
# Save story. Don't need to pass title again if I don't want to change it.

# %%
my_story.save()
# Out:
# True

# %% [markdown]
# ##### Go check out the story before proceeding and making changes!

# %% [markdown]
# ## Look at Story Properties and Methods

# %% [markdown]
# #### nodes: Property to see all nodes of the story in order of appearance. Will show node ids and their type.

# %%
my_story.nodes

# %%
# Look at a certain node
my_story.nodes[4]

# %% [markdown]
# #### get(): Use list method to get a certain node by id or to get all nodes of a certain type

# %%
text_node = my_story.get(node_id="0a70a4")

# %%
text_node.properties

# %%
my_story.get("text")

# %% [markdown]
# #### delete(): Delete a node from a story

# %%
# Audio through URL
thunder = Audio("https://freesound.org/embed/sound/iframe/436076/simple/large/")
my_story.add(thunder)
thunder.properties
# Out:
# {'node_dict': {'type': 'embed',
#   'data': {'url': 'https://freesound.org/embed/sound/iframe/436076/simple/large/',
#    'embedType': 'link',
#    'caption': None,
#    'alt': None,
#    'display': 'inline',
#    'providerUrl': 'large',
#    'embedSrc': 'https://freesound.org/embed/sound/iframe/436076/simple/large/',
#    'addedAsEmbedCode': True}}}

# %%
thunder.delete()
# Out:
# True

# %%
my_story.save(publish=True)
# Out:
# True

# %% [markdown]
# #### Change specific item properties for a webpage

# %%
national_parks = "https://www.nps.gov/index.htm"
park_media.properties

# %%
park_media.link = national_parks
park_media.caption = "I updated the webpage"
park_media.properties

# %% [markdown]
# #### Change a video from a file path to an embed url

# %%
new_video = "https://www.youtube.com/embed/G6b7Kgvd0iA"
my_video.properties

# %%
my_video.caption = "This is now a url"
my_video.video = new_video
my_video.properties

# %%
my_video._url

# %% [markdown]
# #### Save story and go check it out to see the changes

# %%
my_story.save()

# %% [markdown]
# #### Duplicate the Story and give it a Title

# %%
story_copy = my_story.duplicate("National Parks Copy")
story_copy

# %%
story_copy.delete_story()

# %% [markdown]
# ## Edit an Existing Story
#
# To recreate this sample story:
# 1. Create a new story
# 2. Add what you want to the story but must have at least one Sidecar
# 3. In Sidecar have at minimum three slides. The third slide in the sample story can be a map like in the example.
# 4. Publish the story or save it then copy the item id and replace the one below.

# %%
# Pass in item id for an exisitng story
sample_story = StoryMap("eb906f06ef4d4df1a790b07d9cb2bd5d")

# %%
# See node order of the sample
sample_story.nodes
# Out:
# [{'n-PwqjoK': 'storycover'},
#  {'n-spz9AR': 'navigation'},
#  {'n-f2a66y': <arcgis.apps.storymap.story_content.Swipe at 0x2018cf6ba88>},
#  {'n-dFZBcv': <arcgis.apps.storymap.story_content.Embed at 0x2018cf6bcc8>},
#  {'n-fUiVTG': <arcgis.apps.storymap.story_content.Embed at 0x2018cf6b808>},
#  {'n-cLYkFv': <arcgis.apps.storymap.story_content.Sidecar at 0x2018cf6bc88>},
#  {'n-HMBaiI': <arcgis.apps.storymap.story_content.Gallery at 0x2018cf6b048>},
#  {'n-RDQuMe': 'credits'}]

# %%
sample_story.properties["nodes"]["n-dFZBcv"]
# Out:
# {'type': 'embed',
#  'data': {'url': 'https://freesound.org/embed/sound/iframe/436076/simple/large/',
#   'embedType': 'link',
#   'providerUrl': 'https://freesound.org',
#   'aspectRatio': 3.7551,
#   'useSmartEmbed': False,
#   'display': 'inline',
#   'embedSrc': 'https://freesound.org/embed/sound/iframe/436076/simple/large/',
#   'addedAsEmbedCode': True}}

# %% [markdown]
# ### Edit a slide of Sidecar

# %%
# Create an instance of image
image1 = Image(content + r"\wolf.jpg")

# %%
# Create an instance of Sidecar from an exisitng node
sidecar = Sidecar("<Node id for the sidecar node>", sample_story)

# %%
# Properties shows each slide and their content nodes.
sidecar.properties

# %%
# Edit map on the third slide to the new image created above
sidecar.edit(image1, 3)

# %%
# Notice the third media item node has now changed.
sidecar.properties

# %%
sample_story.save()

# %%
sample_story.properties

# %% [markdown]
# ### Edit Gallery

# %%
gallery = sample_story.get(node="n-HMBaiI")

# %%
gallery.images
# Out:
# ['n-S3lbFp',
#  'n-kPA7mU',
#  'n-JhNkGw',
#  'n-Iid9RV',
#  'n-n4ePrh',
#  'n-t64Z1Q',
#  'n-brdwlO',
#  'n-qzCHX5',
#  'n-jLWNs6',
#  'n-uq6Aaw',
#  'n-r0k9m8',
#  'n-4ufKCd']

# %%
gallery.delete_image("n-4ufKCd")
# Out:
# ['n-S3lbFp',
#  'n-kPA7mU',
#  'n-JhNkGw',
#  'n-Iid9RV',
#  'n-n4ePrh',
#  'n-t64Z1Q',
#  'n-brdwlO',
#  'n-qzCHX5',
#  'n-jLWNs6',
#  'n-uq6Aaw',
#  'n-r0k9m8']

# %%
gallery.add_images([image1])
# Out:
# ['n-S3lbFp',
#  'n-kPA7mU',
#  'n-JhNkGw',
#  'n-Iid9RV',
#  'n-n4ePrh',
#  'n-t64Z1Q',
#  'n-brdwlO',
#  'n-qzCHX5',
#  'n-jLWNs6',
#  'n-uq6Aaw',
#  'n-r0k9m8',
#  'n-578154']

# %%
sample_story.save()
# Out:
# True

# %% [markdown]
# ### Add a Gallery

# %%
my_gallery = Gallery()

# %%
#Notice before adding the gallery to the story you cannot see anything about it
my_gallery.properties

# %%
sample_story.add(my_gallery)
# Out:
# 'n-76c5c7'

# %%
#The gallery has now been added to the end
sample_story.nodes
# Out:
# [{'n-PwqjoK': 'storycover'},
#  {'n-spz9AR': 'navigation'},
#  {'n-f2a66y': <arcgis.apps.storymap.story_content.Swipe at 0x2018de427c8>},
#  {'n-dFZBcv': <arcgis.apps.storymap.story_content.Embed at 0x2018de429c8>},
#  {'n-fUiVTG': <arcgis.apps.storymap.story_content.Embed at 0x2018de42a08>},
#  {'n-cLYkFv': <arcgis.apps.storymap.story_content.Sidecar at 0x2018de42a88>},
#  {'n-HMBaiI': <arcgis.apps.storymap.story_content.Gallery at 0x2018de42ac8>},
#  {'n-76c5c7': <arcgis.apps.storymap.story_content.Gallery at 0x2018de42b08>},
#  {'n-RDQuMe': 'credits'}]

# %%
#Now we can see gallery properties
my_gallery.properties
# Out:
# {'node_dict': {'type': 'gallery',
#   'data': {'galleryLayout': 'jigsaw', 'caption': None, 'alt': None},
#   'children': []}}

# %%
# Create Images to add to gallery
i1 = Image("https://www.nps.gov/npgallery/GetAsset/003805FB-155D-451F-6760BEF19A9F5039/proxy/hires")
i2 = Image("https://www.nps.gov/npgallery/GetAsset/002E571C-155D-451F-6729E4B9B3830C6A/proxy/hires")
i3 = Image("https://www.nps.gov/npgallery/GetAsset/003BA5FF-155D-451F-678D49A2F0585330/proxy/hires")
i4 = Image("https://www.nps.gov/npgallery/GetAsset/00450151-155D-451F-67AF679D111DAD36/proxy/hires")
i5 = Image("https://www.nps.gov/npgallery/GetAsset/01F027E0-155D-451F-6764618F430E66A5/proxy/hires")
i6 = Image("https://www.nps.gov/npgallery/GetAsset/0028500C-155D-451F-67EDBAC2A005F5E2/proxy/hires")
i7 = Image("https://www.nps.gov/npgallery/GetAsset/00462DF3-155D-451F-67E26E1B6264A192/proxy/hires")
i8 = Image("https://www.nps.gov/npgallery/GetAsset/0057F115-155D-451F-6706A5E4F5F66B2F/proxy/hires")
i9 = Image("https://www.nps.gov/npgallery/GetAsset/005FAF65-155D-451F-67296249C4617197/proxy/hires")
i10 = Image("https://www.nps.gov/npgallery/GetAsset/59730DB1-155D-451F-67D9014549FDA56E/proxy/hires")

# %%
# Add all the images to the gallery by passing in a list of images
# Notice this can take some time since each image has to be added to the story resources
my_gallery.add_images([i1,i2,i3,i4,i5,i6,i7,i8,i9,i10])

# %%
sample_story.save()
# Out:
# True

# %% [markdown]
# #### Testing Speed
#
# If we create a gallery and add the same amount of images but it is all the same notice that the speed is faster since only one resource is added to the story.
# We don't save so this will not show in the sample story.

# %%
samp_gall = Gallery()

# %%
sample_story.add(samp_gall)
# Out:
# 'n-eca475'

# %%
#Fast!
samp_gall.add_images([i1,i1,i1,i1,i1,i1,i1,i1,i1,i1])
# Out:
# ['n-42530a',
#  'n-42530a',
#  'n-42530a',
#  'n-42530a',
#  'n-42530a',
#  'n-42530a',
#  'n-42530a',
#  'n-42530a',
#  'n-42530a',
#  'n-42530a']

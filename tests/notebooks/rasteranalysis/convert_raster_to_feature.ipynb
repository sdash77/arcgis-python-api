# %%
from datetime import datetime

# %%
import arcgis
from arcgis.gis import GIS

#gis = GIS("https://sha-imgcl-d01.esri.com/portal", "admin", "adminadmin")

profile = 'your_enterprise_profile'
gis = GIS(profile=profile, verify_cert=False)
gis
# Out:
# GIS @ https://sha-imgcl-d01.esri.com/portal version:7.3

# %%
arcgis.env.verbose=True

# %%
elevcond8 = gis.content.search("title:elevcond8")[0].layers[0]
elevcond8.url
# Out:
# 'https://SHA-IMGCL-D01.esri.com/server/rest/services/PyUnitRaster/elevcond8/ImageServer'

# %%
zone_int = gis.content.search("title:zone_int")[0].layers[0]
zone_int.url
# Out:
# 'https://SHA-IMGCL-D01.esri.com/server/rest/services/PyUnitRaster/zone_int/ImageServer'

# %% [markdown]
# Convert raster to line features using to_features()

# %%
convert_raster_to_feature_1 = elevcond8.to_features(field='Value', output_type='Line', simplify=False, gis=gis)
convert_raster_to_feature_1
# Out:
# Submitted.
# Executing...
# Start Time: Thursday, October 10, 2019 3:54:54 PM
# Running script ConvertRasterToFeature...
# Publishing Privilege Check: OK
# Using full extent of input dataset.
# Converting raster to polyline...
# Creating drawing info for output feature layer.
# Create popup info for output feature layer.
# ConvertRasterToFeature GP Job: j8d84665af95f4cd6a3d9771dab067ca0 finished successfully.
# <Item title:"RasterToFeature_A6W0P1" type:Feature Layer Collection owner:admin>

# %% [markdown]
# Convert raster to polygon features using to_features()

# %%
convert_raster_to_feature_2 = zone_int.to_features(future=True)
convert_raster_to_feature_2.result()
# Out:
# Submitted.
# Executing...
# Start Time: Thursday, October 10, 2019 3:55:18 PM
# Running script ConvertRasterToFeature...
# Publishing Privilege Check: OK
# Using full extent of input dataset.
# Converting raster to polygon...
# Creating drawing info for output feature layer.
# Create popup info for output feature layer.
# ConvertRasterToFeature GP Job: j1f31cf75532a461295930bd90e0b5cac finished successfully.
# <Item title:"RasterToFeature_7PEE3T" type:Feature Layer Collection owner:admin>

# %% [markdown]
# Set context param for convert raster to polygon feature.

# %%
aoi = {"xmin": 483443.37822144,"ymin": 208728.88678416,"xmax": 494094.61662144,"ymax": 219724.680012852,"spatialReference": {"wkt": "PROJCS[\"NAD_1983_Transverse_Mercator\",GEOGCS[\"GCS_North_American_1983\",DATUM[\"D_North_American_1983\",SPHEROID[\"GRS_1980\",6378137.0,298.257222101]],PRIMEM[\"Greenwich\",0.0],UNIT[\"Degree\",0.0174532925199433]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"False_Easting\",500000.0],PARAMETER[\"False_Northing\",0.0],PARAMETER[\"Central_Meridian\",-72.5],PARAMETER[\"Scale_Factor\",0.999964286],PARAMETER[\"Latitude_Of_Origin\",42.5],UNIT[\"Meter\",1.0]]"}}

# %%
convert_raster_to_feature_3 = arcgis.raster.analytics.convert_raster_to_feature(input_raster=zone_int,
                                                                                field='Value', 
                                                                                output_type='Polygon',
                                                                                simplify=False,
                                                                                output_name="convert_raster_to_feature_" +str(datetime.now().strftime('%Y%m%d%H%M%S')),
                                                                                context={"extent":aoi},
                                                                                future=False,
                                                                                gis=gis)
convert_raster_to_feature_3
# Out:
# Submitted.
# Executing...
# Start Time: Thursday, October 10, 2019 3:55:39 PM
# Running script ConvertRasterToFeature...
# Publishing Privilege Check: OK
# Converting raster to polygon...
# Creating drawing info for output feature layer.
# Create popup info for output feature layer.
# Completed script ConvertRasterToFeature...
# Succeeded at Thursday, October 10, 2019 3:55:54 PM (Elapsed Time: 15.10 seconds)
# ConvertRasterToFeature GP Job: j0be5d77f88fa40c0be345c1f35350343 finished successfully.
# <Item title:"convert_raster_to_feature_20191010155533" type:Feature Layer Collection owner:admin>

# %% [markdown]
# Set environment variable analysis_extent for convert raster to polygon Feature

# %%
arcgis.env.analysis_extent = aoi
convert_raster_to_feature_4 = arcgis.raster.analytics.convert_raster_to_feature(input_raster=zone_int,
                                                                                field='Value', 
                                                                                output_type='Polygon',
                                                                                simplify=True,
                                                                                output_name="convert_raster_to_feature_" +str(datetime.now().strftime('%Y%m%d%H%M%S')),
                                                                                future=True,
                                                                                gis=gis)
convert_raster_to_feature_4.result()
# Out:
# Submitted.
# Executing...
# Start Time: Thursday, October 10, 2019 3:56:01 PM
# Running script ConvertRasterToFeature...
# Publishing Privilege Check: OK
# Converting raster to polygon...
# Creating drawing info for output feature layer.
# Create popup info for output feature layer.
# Completed script ConvertRasterToFeature...
# Succeeded at Thursday, October 10, 2019 3:56:15 PM (Elapsed Time: 14.15 seconds)
# ConvertRasterToFeature GP Job: jc00c5cee2ffd4f668116179aa9e8dae6 finished successfully.
# <Item title:"convert_raster_to_feature_20191010155556" type:Feature Layer Collection owner:admin>

# %% [markdown]
# <h4> Clean Up

# %%
convert_raster_to_feature_1.delete()
# Out:
# True

# %%
convert_raster_to_feature_2.result().delete()
# Out:
# True

# %%
convert_raster_to_feature_3.delete()
# Out:
# True

# %%
convert_raster_to_feature_4.result().delete()
# Out:
# True

# %%
from datetime import datetime

# %%
import arcgis
from arcgis.gis import GIS

gis = GIS("https://pythonapi.playground.esri.com/portal", "arcgis_python", "amazing_arcgis_123")
gis
# Out:
# GIS @ https://pythonapi.playground.esri.com/portal version:7.1

# %%
arcgis.env.verbose=True

# %%
amberg_seg_default=gis.content.search("amberg_seg_default")[0].layers[0]
amberg_seg_default.url
# Out:
# 'https://pythonapi.playground.esri.com/server/rest/services/amberg_seg_default/ImageServer'

# %%
amberg_090160=gis.content.search("090160")[0].layers[0]
amberg_090160.url
# Out:
# 'https://pythonapi.playground.esri.com/server/rest/services/090160/ImageServer'

# %%
classifier_definition={ "EsriClassifierDefinitionFile" : 0, "FileVersion" : 3, "NumberDefinitions" : 1, "Definitions" : [ { "Classifier" : "MaximumLikelihood", "NumberClasses" : 3, "RasterIsSegmented" : True, "NumberSegmBands" : 3, "NumberExtraBands" : 3, "Size" : True, "Color" : True, "Mean" : True, "Sigma" : True, "Compactness" : True, "Rectangular" : True, "Classes" : [ { "ClassValue" : 1, "ClassName" : "orange buildings", "Red" : 230, "Green" : 152, "Blue" : 0 }, { "ClassValue" : 29, "ClassName" : "roads/grey buildings", "Red" : 130, "Green" : 130, "Blue" : 130 }, { "ClassValue" : 53, "ClassName" : "Vegetation", "Red" : 22, "Green" : 75, "Blue" : 133 } ], "MLC_Stats" : [ { "Count" : 87, "LnDet" : 34.729813724474276, "Means" : [ 8951.1839080459777, 167.49425287356323, 136.48275862068965, 100.54022988505747, 163.82386051723293, 133.37120656661918, 97.947337147967872, 12.984165633453125, 12.549486557002378, 11.864425560556709, 0.72591751346127553, 0.62892804777860989 ], "InvCovarMat" : [ 8.611887816243566e-009, 2.8952551497264147e-005, -1.7044823552923385e-005, -5.7837632544016091e-006, -2.9586563286382088e-005, 1.9435182713144673e-005, 3.6176823569654698e-006, -3.7583495263457858e-005, 6.1958241365324461e-005, -3.0874649455319056e-005, 9.812607782786579e-005, -0.00012621510389634709, 1.5079961430334781, -1.7958911965959989, 0.44608750499526018, -1.4781665119712359, 1.7696723170290172, -0.44382351483059052, -0.061482445594184587, 0.18823460448951027, -0.15476487280386753, -0.69196945765953677, -0.016187089240233543, 2.7976819441314031, -1.1692367134780324, 1.7644398796892986, -2.7679309264169296, 1.1591539037537044, -0.0083291535896460392, -0.070837329928680942, 0.07157716655900323, 0.71849553837015079, -1.060612193769054, 0.78226238575484774, -0.44439413414613366, 1.1652235793215393, -0.77297301069694524, 0.045120665772304183, -0.048975834715182784, 0.013680962103072881, -0.23986904194266639, 1.1601473543224028, 1.4834401879341972, -1.7969404492460461, 0.47068756842549392, 0.12283732919148992, -0.29772983772621142, 0.
522, 94.780237807348868, 57.990878505589293, 13.622336415768796, 13.838485735347495, 12.872019615571485, 0.79432891572353082, 0.52719251180626547 ], "InvCovarMat" : [ 1.0835622414057817e-010, -1.1174467805480125e-007, 1.9269137013268642e-007, -7.4216363718580455e-008, 2.1363821275793752e-007, -2.8585795816964349e-007, 5.3384016367558236e-008, -2.210041290534765e-006, 1.3169622388102688e-006, 3.0188956595935134e-007, 1.0108105947705321e-005, -2.179721827809964e-006, 0.94011993528844406, -0.71048822156624147, -0.22347302574362107, -0.90248646115296127, 0.68688727483727208, 0.21117600082961391, 0.061711756830790714, -0.091853569712986735, 0.010416811428908383, -0.40276512799948877, 0.74402013330058459, 0.77122810299673938, -0.068999799127192493, 0.68610115447989795, -0.74945858751272887, 0.068525723600391192, -0.062559993007230419, 0.074962701884968244, -0.0040073262407332279, -0.36198755965320883, -0.51029237102947278, 0.34115086148395318, 0.20862698858573264, 0.066763093264583073, -0.3204315688033913, 0.032427002022775674, -0.0085561543548533445, -0.0184895596406781, 0.47794364159020969, -0.065066050759297445, 0.90571361278692064, -0.69174572137344614, -0.20830439563043027, -0.050520724659546129, 0.055426832307504406, 0.0085127844085272301, 0.38729476802032853, -0.71758674787244292, 0.75817708074867096, -0.069101161868770911, 0.049396050867410946, -0.055481228334307547, -0.00047225507594598419, 0.32890050341429283, 0.46375473771174774, 0.31839275669452294, -0.024180782349191181, 0.03144895754484895, -0.012943349002354746, -0.49598521256359834, 0.10492861721444334, 1.3663408084242099, -0.96536148168263392, -0.38408938899335598, 1.489876986925541, -0.96248758625650666, 0.94595697339827933, 0.0050004033529704754, -1.5125169743939355, 1.2544694648827546, 0.44511997292340488, 0.32540509188542877, -0.15885156626796024, 114.6362025338892, -43.185785361922683, 47.183741597339079 ] } ] } ] }

# %% [markdown]
# Classify synchronous

# %%
op_folder_name = "classify" + str(datetime.now().strftime('%Y%m%d%H%M%S'))

# %%
classify_1 = arcgis.raster.analytics.classify(input_raster=amberg_090160 ,
                                              additional_input_raster=amberg_seg_default,
                                              input_classifier_definition=classifier_definition,
                                              folder=op_folder_name,
                                              gis=gis)
# Out:
# Submitted.
# Executing...
# Classify GP Job: j9350f5cfe9d347718582ac8772828060 finished successfully.

# %%
classify_1.layers[0]
# Out:
# <ImageryLayer url:"https://pythonapi.playground.esri.com/ra/rest/services/Hosted/Classify_FXTXDG/ImageServer">

# %% [markdown]
# Classify with output name and analysis extent

# %%
arcgis.env.analysis_extent = {"xmin": 4488850.32185313,"ymin": 5478975.0547895,"xmax": 4489418.19075938,"ymax": 5479401.0592695,"spatialReference": {"wkt": "PROJCS[\"Deutsches_Hauptdreiecksnetz_Transverse_Mercator\",GEOGCS[\"GCS_Deutsches_Hauptdreiecksnetz\",DATUM[\"D_Deutsches_Hauptdreiecksnetz\",SPHEROID[\"Bessel_1841\",6377397.155,299.1528128]],PRIMEM[\"Greenwich\",0.0],UNIT[\"Degree\",0.0174532925199433]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"false_easting\",4500000.0],PARAMETER[\"false_northing\",0.0],PARAMETER[\"central_meridian\",12.0],PARAMETER[\"scale_factor\",1.0],PARAMETER[\"latitude_of_origin\",0.0],UNIT[\"Meter\",1.0]]"}}

classify_2 = arcgis.raster.analytics.classify(input_raster=amberg_090160 ,
                                              additional_input_raster=amberg_seg_default,
                                              input_classifier_definition=classifier_definition,
                                              output_name="classify" + str(datetime.now().strftime('%Y%m%d%H%M%S')),
                                              folder=op_folder_name,
                                              gis=gis)
# Out:
# Submitted.
# Executing...
# Classify GP Job: ja6b2445b1f594ba3af24ce5abbb402bc finished successfully.

# %%
classify_2.layers[0]
# Out:
# <ImageryLayer url:"https://pythonapi.playground.esri.com/ra/rest/services/Hosted/classify20191010202305/ImageServer">

# %% [markdown]
# Classify with analysis extent context param set

# %%
arcgis.env.analysis_extent = {"xmin": 4488850.32185313,"ymin": 5478975.0547895,"xmax": 4489418.19075938,"ymax": 5479401.0592695,"spatialReference": {"wkt": "PROJCS[\"Deutsches_Hauptdreiecksnetz_Transverse_Mercator\",GEOGCS[\"GCS_Deutsches_Hauptdreiecksnetz\",DATUM[\"D_Deutsches_Hauptdreiecksnetz\",SPHEROID[\"Bessel_1841\",6377397.155,299.1528128]],PRIMEM[\"Greenwich\",0.0],UNIT[\"Degree\",0.0174532925199433]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"false_easting\",4500000.0],PARAMETER[\"false_northing\",0.0],PARAMETER[\"central_meridian\",12.0],PARAMETER[\"scale_factor\",1.0],PARAMETER[\"latitude_of_origin\",0.0],UNIT[\"Meter\",1.0]]"}}

classify_3 = arcgis.raster.analytics.classify(input_raster=amberg_090160 ,
                                      additional_input_raster=amberg_seg_default,
                                      input_classifier_definition=classifier_definition,
                                      output_name="classify" + str(datetime.now().strftime('%Y%m%d%H%M%S')),
                                      future=True,
                                      gis=gis)

# %%
print(classify_3.status)
classify_3.result().layers[0]
# Out:
# esriJobExecuting
# Submitted.
# Executing...
# Classify GP Job: ja26829cd4a4e410988dc04e6510ef698 finished successfully.
# <ImageryLayer url:"https://pythonapi.playground.esri.com/ra/rest/services/Hosted/classify20191010202440/ImageServer">

# %% [markdown]
# <h4> Clean Up

# %%
gis.content.delete_folder(op_folder_name)
# Out:
# True

# %%
classify_3.result().delete()
# Out:
# True

# %% [markdown]
# # Performing Data Enrichment

# %%
# connect to Enterprise GIS
from arcgis.gis import GIS
import arcgis.geoanalytics

portal_gis = GIS("https://ndhwks6.esri.com/portal", "admin", 'esri.agp', verify_cert=False)

# %%
search_result1 = portal_gis.content.search("bigDataFileShares_ServiceCallsOrleans", item_type = "big data file share")[0]
search_result1
# Out:
# <Item title:"bigDataFileShares_ServiceCallsOrleans" type:Big Data File Share owner:admin>

# %%
calls = search_result.layers[0]

# %%
search_result2 = portal_gis.content.search("bigDataFileShares_all_hurricanes", item_type = "big data file share")[0]
search_result2
# Out:
# <Item title:"bigDataFileShares_all_hurricanes" type:Big Data File Share owner:admin>

# %%
hurricanes = search_result.layers[0]

# %%
grid_item = portal_gis.content.search('build_multivariable_grid')
grid_item
# Out:
# [<Item title:"build_multivariable_grid" type:Feature Layer Collection owner:admin>]

# %%
grid_lyr = grid_item[0].layers[0]

# %% [markdown]
# ## Enrich From Grid

# %%
from arcgis.geoanalytics.data_enrichment import enrich_from_grid

# %%
enrich_from_grid(calls, grid_lyr, output_name='enrich from grid test')
# Out:
# {"messageCode":"BD_101051","message":"Possible issues were found while reading 'inputFeatures'.","params":{"paramName":"inputFeatures"}}
# {"messageCode":"BD_101052","message":"Some records have either missing or invalid time values."}
# {"messageCode":"BD_101054","message":"Some records have either missing or invalid geometries."}
# <Item title:"enrich_from_grid_test" type:Feature Layer Collection owner:admin>

# %% [markdown]
# ## Calculate Motion Statistics

# %%
from arcgis.geoanalytics.data_enrichment import calculate_motion_statistics

# %%
res = calculate_motion_statistics(hurricanes, track_fields='track_type', future=True)

# %%
res.result()
# Out:
# <Item title:"Calculate_Motion_Stats_2K440L" type:Feature Layer Collection owner:admin>

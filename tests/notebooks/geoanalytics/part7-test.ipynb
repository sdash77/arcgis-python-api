# %% [markdown]
# # Use Proximity

# %%
# connect to Enterprise GIS
from arcgis.gis import GIS
import arcgis.geoanalytics

portal_gis = GIS("https://ndhwks6.esri.com/portal", "admin", 'esri.agp', verify_cert=False)

# %%
search_result = portal_gis.content.search("bigDataFileShares_all_hurricanes", item_type = "big data file share")[0]
search_result
# Out:
# <Item title:"bigDataFileShares_all_hurricanes" type:Big Data File Share owner:admin>

# %%
search_result.layers
# Out:
# [<Layer url:"https://ndhwks6.esri.com/server/rest/services/DataStoreCatalogs/bigDataFileShares_all_hurricanes/BigDataCatalogServer/hurricanes">]

# %%
hurricanes = search_result.layers[0]

# %%
hurricanes.properties
# Out:
# {
#   "dataStoreID": "2d305bf2-3bd4-4e33-ac95-7bb5d987b494",
#   "fields": [
#     {
#       "name": "serial_num",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "season",
#       "type": "esriFieldTypeInteger"
#     },
#     {
#       "name": "num",
#       "type": "esriFieldTypeInteger"
#     },
#     {
#       "name": "basin",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "sub_basin",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "name",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "iso_time",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "nature",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "latitude",
#       "type": "esriFieldTypeDouble"
#     },
#     {
#       "name": "longitude",
#       "type": "esriFieldTypeDouble"
#     },
#     {
#       "name": "wind_wmo_",
#       "type": "esriFieldTypeDouble"
#     },
#     {
#       "name": "pres_wmo_",
#       "type": "esriFieldTypeInteger"
#     },
#     {
#       "name": "center",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "wind_wmo1",
#       "type": "esriFieldTypeDouble"
#     },
#     {
#       "name": "pres_wmo1",
#       "type": "esriFieldTypeDouble"
#     },
#     {
#       "name": "track_type",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "size",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "Wind",
#       "type": "esriFieldTypeInteger"
#     }
#   ],
#   "name": "hurricanes",
#   "geometryType": "esriGeometryPoint",
#   "type": "featureClass",
#   "spatialReference": {
#     "wkid": 4326
#   },
#   "geometry": {},
#   "time": {
#     "timeType": "instant",
#     "timeReference": {
#       "timeZone": "UTC"
#     },
#     "fields": [
#       {
#         "name": "iso_time",
#         "formats": [
#           "yyyy-MM-dd HH:mm:ss"
#         ]
#       }
#     ]
#   },
#   "currentVersion": 10.91,
#   "children": []
# }

# %% [markdown]
# ## Create Buffers

# %%
from arcgis.geoanalytics.use_proximity import create_buffers

# %%
create_buffers(input_layer=hurricanes, output_name='buffered_hurricanes')
# Out:
# {"messageCode":"BD_101024","message":"Using geodesic method for geographic coordinate system."}
# {"messageCode":"BD_101051","message":"Possible issues were found while reading 'inputLayer'.","params":{"paramName":"inputLayer"}}
# {"messageCode":"BD_101052","message":"Some records have either missing or invalid time values."}
# <Item title:"buffered_hurricanes" type:Feature Layer Collection owner:admin>

# %% [markdown]
# ## Trace Proximity Events

# %%
from arcgis.geoanalytics.use_proximity import trace_proximity_events

# %%
trace_proximity_events(input_points=hurricanes,
                       spatial_search_distance=1,
                       spatial_search_distance_unit='Miles',
                       temporal_search_distance=1,
                       temporal_search_distance_unit='Days',
                       entity_id_field='serial_num',
                       entities_of_interest_ids={})
# Out:
# ERROR 000735: Entity ID Field: Value is required
# Failed.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-12-bc65ab02be3a> in <module>
#       3                        spatial_search_distance_unit='Miles',
#       4                        temporal_search_distance=1,
# ----> 5                        temporal_search_distance_unit='Days')
#
# ~\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\arcgis\geoanalytics\use_proximity.py in trace_proximity_events(input_points, spatial_search_distance, spatial_search_distance_unit, temporal_search_distance, temporal_search_distance_unit, entity_id_field, entities_of_interest_ids, entities_of_interest_layer, distance_method, include_tracks_layer, max_trace_depth, attribute_match_criteria, output_name, context, gis, future)
#     206         if future:
#     207             return GAJob(gpjob=gpjob, return_service=output_service)
# --> 208         gpjob.result()
#     209         return output_service
#     210     except:
#
# ~\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\arcgis\geoprocessing\_job.py in result(self)
#     219         elif self._is_ortho:
#     220             return self._process_ortho(self._future.result())
# --> 221         return self._future.result()
#     222
#     223     def _process_ortho(self, result):
#
# ~\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\concurrent\futures\_base.py in result(self, timeout)
#     433                 raise CancelledError()
#     434             elif self._state == FINISHED:
# --> 435                 return self.__get_result()
#     436             else:
#     437                 raise TimeoutError()
#
# ~\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\concurrent\futures\_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# ~\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\concurrent\futures\thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# ~\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\arcgis\geoprocessing\_support.py in _future_op(gptool, task_url, job_info, job_id, param_db, return_values, return_messages)
#     317 ):
#     318
# --> 319     job_info = _analysis_job_status(gptool, task_url, job_info)
#     320     resp = _analysis_job_results(gptool, task_url, job_info, job_id)
#     321
#
# ~\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\arcgis\geoprocessing\_support.py in _analysis_job_status(gptool, task_url, job_info)
#     242
#     243                     if job_response.get("jobStatus") == "esriJobFailed":
# --> 244                         raise Exception("Job failed.")
#     245                     elif job_response.get("jobStatus") == "esriJobCancelled":
#     246                         raise Exception("Job cancelled.")
#
# Exception: Job failed.

# %% [markdown]
# # Test get_travel_modes

# %%
import sys
import datetime
#sys.path.insert(0, r"C:\SVN\achapkowski_geosaurus_fork\src")
#sys.path.insert(0, r"C:\ipython_working_folder\issue testing\fajobs")

# %%
from arcgis.gis import GIS
try:
    gis = GIS(profile='your_online_profile', verify_cert=False) 
except:
    gis = GIS(username="arcgis_python", password="amazing_arcgis_123", profile='your_online_profile', verify_cert=False)

# %%
import arcgis.network as network
import arcgis.features as features

# %%
network.analysis.get_travel_modes().supported_travel_modes.sdf
# Out:
#                   AltName                    Name  ObjectID  \
# 0            Walking Time            Walking Time         1
# 1        Walking Distance        Walking Distance         2
# 2  Rural Driving Distance  Rural Driving Distance         3
# 3            Driving Time            Driving Time         4
# 4        Driving Distance        Driving Distance         5
# 5           Trucking Time           Trucking Time         6
# 6      Rural Driving Time      Rural Driving Time         7
# 7                  werewr                  werewr         8
#
#                                           TravelMode      TravelModeId
# 0  {"attributeParameterValues": [{"parameterName"...  caFAgoThrvUpkFBW
# 1  {"attributeParameterValues": [{"parameterName"...  yFuMFwIYblqKEefX
# 2  {"attributeParameterValues": [{"parameterName"...  Yzk3NjI1NTU5NjVj
# 3  {"attributeParameterValues": [{"parameterName"...  FEgifRtFndKNcJMJ
# 4  {"attributeParameterValues": [{"parameterName"...  iKjmHuBSIqdEfOVr
# 5  {"attributeParameterValues": [{"parameterName"...  ZzzRtYcPLjXFBKwr
# 6  {"attributeParameterValues": [{"parameterName"...  NmNhNDUwZmE1YTlj
# 7  {"name": "werewr", "description": "werwe", "ty...  bSTaBYsMHUVQlCXQ

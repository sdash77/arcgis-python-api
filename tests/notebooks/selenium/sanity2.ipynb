# %%
import os
import sys
sys.path.append(os.path.join("..", ".."))
from utils._common import *

# %%
expected_arcgis_file = \
    os.path.join(GEOSAURUS_SRC_ARCGIS_DIR, "__init__.py").lower()
expected_arcgis_file

# %%
import arcgis
actual_arcgis_file = arcgis.__file__.lower()
actual_arcgis_file

# %%
assert actual_arcgis_file == expected_arcgis_file

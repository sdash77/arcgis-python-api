# %%
import os
import sys
sys.path.append(os.path.join("..", ".."))
from utils._common import *

# %%
import arcgis
arcgis.__file__

# %%
expected_arcgis_file = \
    os.path.join(GEOSAURUS_SRC_ARCGIS_DIR, "__init__.py")
expected_arcgis_file

# %%
assert arcgis.__file__ == expected_arcgis_file

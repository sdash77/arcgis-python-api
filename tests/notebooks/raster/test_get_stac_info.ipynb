# %%
from arcgis.raster.utils import get_stac_info
# Out:
# C:\Users\par97462\AppData\Local\Anaconda3\envs\geosaurus_dev_env\Lib\site-packages\dask\dataframe\_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 11.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(

# %% [markdown]
# STAC API

# %%
stac_info = get_stac_info("https://planetarycomputer.microsoft.com/api/stac/v1", verbose=True)
stac_info
# Out:
# {'type': 'Catalog',
#  'title': 'Microsoft Planetary Computer STAC API',
#  'collections': [{'id': 'daymet-annual-pr',
#    'type': 'Collection',
#    'links': [{'rel': 'items',
#      'type': 'application/geo+json',
#      'href': 'https://planetarycomputer.microsoft.com/api/stac/v1/collections/daymet-annual-pr/items'},
#     {'rel': 'parent',
#      'type': 'application/json',
#      'href': 'https://planetarycomputer.microsoft.com/api/stac/v1/'},
#     {'rel': 'root',
#      'type': 'application/json',
#      'href': 'https://planetarycomputer.microsoft.com/api/stac/v1/'},
#     {'rel': 'self',
#      'type': 'application/json',
#      'href': 'https://planetarycomputer.microsoft.com/api/stac/v1/collections/daymet-annual-pr'},
#     {'rel': 'license',
#      'href': 'https://science.nasa.gov/earth-science/earth-science-data/data-information-policy',
#      'title': 'EOSDIS Data Use Policy'},
#     {'rel': 'cite-as', 'href': 'https://doi.org/10.3334/ORNLDAAC/1852'},
# ...

# %% [markdown]
# STAC API collections endpoint

# %%
stac_info = get_stac_info("https://gpt.geocloud.com/sentinel/stac/collections", verbose=False)
stac_info
# Out:
# {'type': 'Catalog',
#  'title': None,
#  'collections': ['metadata'],
#  'links': ['https://gpt.geocloud.com/sentinel/stac',
#   'https://gpt.geocloud.com/sentinel/stac/collections']}

# %% [markdown]
# STAC Collection

# %%
stac_info = get_stac_info("https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2", verbose=True)
stac_info
# Out:
# {'type': 'Collection',
#  'id': 'landsat-c2-l2',
#  'title': 'Landsat Collection 2 Level-2',
# ...

# %% [markdown]
# STAC Collection (Static)

# %%
stac_info = get_stac_info("https://storage.googleapis.com/cfo-public/wildfire/collection.json", verbose=False)
stac_info
# Out:
# {'type': 'Collection',
#  'id': 'wildfire',
#  'title': 'Wildfire likelihood, intensity, and severity metrics',
#  'item_assets': [],
#  'assets': [],
#  'links': ['https://storage.googleapis.com/cfo-public/catalog.json',
#   'https://storage.googleapis.com/cfo-public/wildfire/California-Wildfire-BurnProbability-2020-Summer-00010m.json',
#   'https://storage.googleapis.com/cfo-public/wildfire/California-Wildfire-BurnSeverity-2016-Fall-00010m.json',
#   'https://storage.googleapis.com/cfo-public/wildfire/California-Wildfire-BurnSeverity-2017-Fall-00010m.json',
#   'https://storage.googleapis.com/cfo-public/wildfire/California-Wildfire-BurnSeverity-2018-Fall-00010m.json',
#   'https://storage.googleapis.com/cfo-public/wildfire/California-Wildfire-BurnSeverity-2019-Fall-00010m.json',
#   'https://storage.googleapis.com/cfo-public/wildfire/California-Wildfire-BurnSeverity-2020-Fall-00010m.json',
# ...

# %% [markdown]
# STAC Catalog (Static)

# %%
stac_info = get_stac_info("https://storage.googleapis.com/cfo-public/catalog.json", verbose=True)
stac_info
# Out:
# {'type': 'Catalog',
#  'title': 'California Forest Observatory',
#  'collections': [],
#  'links': ['https://storage.googleapis.com/cfo-public/catalog.json',
#   'https://storage.googleapis.com/cfo-public/catalog.json',
#   'https://storage.googleapis.com/cfo-public/vegetation/collection.json',
#   'https://storage.googleapis.com/cfo-public/wildfire/collection.json']}

# %% [markdown]
# STAC Item (Static Catalog)

# %%
stac_info = get_stac_info("https://storage.googleapis.com/cfo-public/wildfire/California-Wildfire-SpreadRate-2020-Summer-00010m.json", verbose=False)
stac_info
# Out:
# {'type': 'Item',
#  'id': 'California-Wildfire-SpreadRate-2020-Summer-00010m',
#  'title': None,
#  'bbox': [32.3622708084737,
#   -124.518229214556,
#   42.0242173371539,
#   -113.191354530481],
#  'properties': ['metric',
#   'sci:rmse',
#   'sci:mae',
#   'sci:rsquared',
#   'units',
#   'gsd',
#   'datetime'],
#  'assets': ['SpreadRate'],
#  'links': ['https://storage.googleapis.com/cfo-public/wildfire/collection.json',
#   'https://storage.googleapis.com/cfo-public/wildfire/collection.json',
#   'https://storage.googleapis.com/cfo-public/wildfire/California-Wildfire-SpreadRate-2020-Summer-00010m.json',
#   'https://storage.googleapis.com/cfo-public/wildfire/collection.json']}

# %% [markdown]
# STAC Item (STAC API)

# %%
stac_info = get_stac_info("https://planetarycomputer.microsoft.com/api/stac/v1/collections/naip/items/wa_m_4712125_sw_10_060_20191029_20191217", verbose=True)
stac_info
# Out:
# {'type': 'Item',
#  'id': 'wa_m_4712125_sw_10_060_20191029_20191217',
#  'title': None,
#  'bbox': [-122.003898, 47.497629, -121.93349, 47.564914],
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-121.934841, 47.497629],
#     [-121.93349, 47.564292],
#     [-122.002635, 47.564914],
#     [-122.003898, 47.498249],
#     [-121.934841, 47.497629]]]},
#  'properties': {'gsd': 0.6,
#   'datetime': '2019-10-29T00:00:00Z',
#   'naip:year': '2019',
#   'proj:bbox': [575022.0, 5261016.0, 580224.0, 5268426.0],
#   'proj:epsg': 26910,
#   'naip:state': 'wa',
#   'proj:shape': [12350, 8670],
#   'proj:transform': [0.6, 0.0, 575022.0, 0.0, -0.6, 5268426.0, 0.0, 0.0, 1.0]},
#  'assets': {'image': {'href': 'https://naipeuwest.blob.core.windows.net/naip/v002/wa/2019/wa_60cm_2019/47121/m_4712125_sw_10_060_20191029.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'RGBIR COG tile',
# ...

# %% [markdown]
# STAC ItemCollection (search results)

# %%
stac_info = get_stac_info("https://planetarycomputer.microsoft.com/api/stac/v1/search?collections=naip&naip:state=ny&limit=5", verbose=False)
stac_info
# Out:
# {'type': 'FeatureCollection',
#  'title': None,
#  'features': [{'id': 'pr_m_1806551_nw_20_030_20221212_20230329',
#    'bbox': [-65.75386, 18.183872, -65.683663, 18.253643],
#    'assets': ['image', 'thumbnail', 'tilejson', 'rendered_preview']},
#   {'id': 'pr_m_1806550_ne_20_030_20221212_20230329',
#    'bbox': [-65.816382, 18.183852, -65.746142, 18.253666],
#    'assets': ['image', 'thumbnail', 'tilejson', 'rendered_preview']},
#   {'id': 'pr_m_1806544_nw_20_030_20221212_20230329',
#    'bbox': [-65.628821, 18.30891, -65.558704, 18.378606],
#    'assets': ['image', 'thumbnail', 'tilejson', 'rendered_preview']},
#   {'id': 'pr_m_1806544_ne_20_030_20221212_20230329',
#    'bbox': [-65.566297, 18.308929, -65.496227, 18.378583],
#    'assets': ['image', 'thumbnail', 'tilejson', 'rendered_preview']},
#   {'id': 'pr_m_1806661_ne_19_030_20221127_20230329',
#    'bbox': [-66.44128, 18.058921, -66.371197, 18.128597],
#    'assets': ['image', 'thumbnail', 'tilejson', 'rendered_preview']}],
# ...

# %% [markdown]
# STAC ItemCollection (items endpoint)

# %%
stac_info = get_stac_info("https://earth-search.aws.element84.com/v1/collections/naip/items", verbose=False)
stac_info
# Out:
# {'type': 'FeatureCollection',
#  'title': None,
#  'features': [{'id': 'ny_m_4307759_sw_18_060_20221126',
#    'bbox': [-77.755324, 42.996658, -77.682233, 43.065841],
#    'assets': ['image', 'metadata']},
#   {'id': 'ny_m_4307759_nw_18_060_20221126',
#    'bbox': [-77.755327, 43.059167, -77.682232, 43.128348],
#    'assets': ['image', 'metadata']},
#   {'id': 'ny_m_4307758_sw_18_060_20221126',
#    'bbox': [-77.880437, 42.996554, -77.807137, 43.065916],
#    'assets': ['image', 'metadata']},
#   {'id': 'ny_m_4307758_se_18_060_20221126',
#    'bbox': [-77.81788, 42.996596, -77.744648, 43.065869],
#    'assets': ['image', 'metadata']},
#   {'id': 'ny_m_4307758_nw_18_060_20221126',
#    'bbox': [-77.880494, 43.05906, -77.807116, 43.128423],
#    'assets': ['image', 'metadata']},
#   {'id': 'ny_m_4307758_ne_18_060_20221126',
#    'bbox': [-77.817947, 43.059103, -77.744637, 43.128377],
#    'assets': ['image', 'metadata']},
#   {'id': 'ny_m_4307755_nw_18_060_20221126',
# ...

# %%
import sys
sys.path.insert(0, r"C:\ipython_workfolder\geosaurus\src")

from arcgis.gis import GIS

# %%
gis = GIS(profile="your_online_profile")
gis

# %%
image_item = gis.content.search("*", "Imagery Layer", outside_org=True)[0]
image_item

# %%
op_map = gis.map()
op_map

# %%
op_map.content.add(image_item.layers[0], options={"opacity": 0.3})
